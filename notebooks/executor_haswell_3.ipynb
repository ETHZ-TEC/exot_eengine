# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %%
SHORT = False
UPDATE = True
RESUME = False

# %%
environments_to_execute = [
#     'ARMv8',
#     'Haswell',
#     "Haswell_2",
    "Haswell_3"
]

phases_cache = {
    'ARMv8':{'short':['trainShortARMv8','evalShortARMv8'],
               'normal':['trainARMv8','evalARMv8']},
    'Haswell':{'short':['trainShortHaswell','evalShortHaswell'],
               'normal':['trainHaswell','evalHaswell']}
}
phases_thermal_cap = {
    'ARMv8':{'short':['sweepShortARMv8'],
               'normal':['sweepARMv8']},
    'Haswell':{'short':['sweepShortHaswell'],
               'normal':['sweepHaswell']},
    'Haswell_2':{'short':['sweepShortHaswell'],
               'normal':['sweepHaswell']},
    'Haswell_3':{'short':['sweepShortHaswell'],
               'normal':['sweepHaswell']}
}
phases_thermal = {
    'ARMv8':{'short':['trainShortARMv8','evalShortARMv8'],
               'normal':['trainARMv8','evalARMv8']},
    'Haswell':{'short':['trainShortHaswell','evalShortHaswell'],
               'normal':['trainHaswell','evalHaswell']}
}

# %% [markdown]
# ### Cache performance
# Status: executed

# %%
for _experiment in [
    "flush+flush-cc_performance",
    "flush+reload-cc_performance",
    "flush+prefetch-cc_performance",
    "flush+flush-cc_interference",
    "flush+reload-cc_interference",
    "flush+prefetch-cc_interference",
]:
    for _platform, _phase_mapping in phases_cache.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0], "logs:", _logs[0], sep=" ")

# %% [markdown]
# - Execution

# %%
SHORT = False

for experiment_cache_path in [
    "data/flush+flush-cc_performance/_experiment.pickle",
    "data/flush+reload-cc_performance/_experiment.pickle",
    "data/flush+prefetch-cc_performance/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_cache_path)
        experiment_cache = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_cache.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_cache.config.experiment_exists_action = "update"
            experiment_cache._update_mode = True
        for env in environments_to_execute:
            experiment_cache.execute_in_environment(
                env,
                phases_cache[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_cache.write()
    except Exception as e:
        print("ERROR - ", experiment_cache_path, str(e))
        raise e

# %%
SHORT = False

for experiment_cache_path in [
    "data/flush+flush-cc_interference/_experiment.pickle",
    "data/flush+reload-cc_interference/_experiment.pickle",
#     "data/flush+prefetch-cc_interference/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_cache_path)
        experiment_cache = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        experiment_cache.config.EXPERIMENT.GENERAL.active_wait=True
        try:
            experiment_cache.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_cache.config.experiment_exists_action = "update"
            experiment_cache._update_mode = True
        for env in environments_to_execute:
            experiment_cache.execute_in_environment(
                env,
                phases_cache[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_cache.write()
    except Exception as e:
        print("ERROR - ", experiment_cache_path, str(e))
        raise e

# %% [markdown]
# ### Thermal capacity
# Status: executed

# %%
for _experiment in ["thermal-cc_capacity"]:
    for _platform, _phase_mapping in phases_thermal_cap.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0], "logs:", _logs[0], sep=" ")
# Out:
# experiment: thermal-cc_capacity platform: ARMv8 phase: sweepShortARMv8 folders: 1 logs: 0
# experiment: thermal-cc_capacity platform: ARMv8 phase: sweepARMv8 folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell phase: sweepShortHaswell folders: 1 logs: 0
# experiment: thermal-cc_capacity platform: Haswell phase: sweepHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_2 phase: sweepShortHaswell folders: 1 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_2 phase: sweepHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_3 phase: sweepShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_3 phase: sweepHaswell folders: 0 logs: 0

# %% [markdown]
# - Execution

# %%
SHORT = True

for experiment_thermal_path in [
    "data/thermal-cc_capacity/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = FrequencySweepExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal_cap[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
#         experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e
# Out:
# 2019-09-12 12:23:05 :: unpicked an experiment instance <FrequencySweepExperiment at 0x7f6a66a42780 with Thermal channel, configured>
# 2019-09-12 12:23:06 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2019-09-12 12:23:20 :: Haswell_3->host: connected: SSHUnixDriver
# 2019-09-12 12:23:20 :: Haswell_3->host: sending experiment
# 2019-09-12 12:23:21 :: Haswell_3->host: experiment sent!
# 2019-09-12 12:23:21 :: executing phases: ['sweepShortHaswell'] in env 'Haswell_3'
# 2019-09-12 12:23:21 :: Haswell_3->host: configuring to {'latency': 10, 'fan': True, 'governors': 'userspace', 'frequencies': 'max', 'sampling_period': 0.001, 'delay_after_spawn': 30.0, 'delay_after_auxiliary': 1.0, 'active_wait': False, 'ARMv8': {'fan': '255', 'delay_after_spawn': 120.0}}
# 2019-09-12 12:23:24 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a46afc518 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 12:23:24 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a46afc518 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 12:26:58 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:26:58 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4810eb70 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 12:26:58 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4810eb70 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 12:30:31 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:30:31 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a484910b8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 12:30:31 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a484910b8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 12:34:04 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:34:04 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a480cc748 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 12:34:04 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a480cc748 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 12:41:11 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:41:11 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a47ef6240 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 8.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 12:41:11 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a47ef6240 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 8.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 12:44:44 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:44:44 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a48829cc0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 12:44:44 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a48829cc0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 12:48:17 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:48:17 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a473f0630 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 20.0, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 12:48:17 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a473f0630 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 20.0, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 12:51:51 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:51:51 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a47411ac8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 25.0, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 12:51:51 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a47411ac8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 25.0, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 12:55:24 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:55:24 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a483a5f60 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 12:55:24 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a483a5f60 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 12:58:57 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 12:58:57 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a47476b00 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 12:58:57 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a47476b00 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 13:02:30 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:02:30 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a48563630 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 13:02:30 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a48563630 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 13:06:04 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:06:04 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a46b26438 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 13:06:04 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a46b26438 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 13:09:37 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:09:37 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a481463c8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 13:09:37 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a481463c8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 13:13:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:13:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a483527f0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 13:13:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a483527f0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 13:16:44 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:16:44 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a47476f98 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 13:16:44 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a47476f98 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 13:20:17 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:20:17 :: Haswell_3->host: cleaning up
# 2019-09-12 13:20:25 :: Haswell_3->host: successfully deleted remote data directory
# 2019-09-12 13:20:25 :: Haswell_3->host: disconnected

# %%
SHORT = False

for experiment_thermal_path in [
    "data/thermal-cc_capacity/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = FrequencySweepExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal_cap[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
#         experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e
# Out:
# 2019-09-12 13:20:25 :: unpicked an experiment instance <FrequencySweepExperiment at 0x7f6a6415fbe0 with Thermal channel, configured>
# 2019-09-12 13:20:26 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2019-09-12 13:20:39 :: Haswell_3->host: connected: SSHUnixDriver
# 2019-09-12 13:20:39 :: Haswell_3->host: sending experiment
# 2019-09-12 13:20:40 :: Haswell_3->host: experiment sent!
# 2019-09-12 13:20:40 :: executing phases: ['sweepHaswell'] in env 'Haswell_3'
# 2019-09-12 13:20:40 :: Haswell_3->host: configuring to {'latency': 10, 'fan': True, 'governors': 'userspace', 'frequencies': 'max', 'sampling_period': 0.001, 'delay_after_spawn': 30.0, 'delay_after_auxiliary': 1.0, 'active_wait': False, 'ARMv8': {'fan': '255', 'delay_after_spawn': 120.0}}
# 2019-09-12 13:20:44 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378ff0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 13:20:44 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378ff0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 13:24:17 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:24:17 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4407b8d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.6, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 13:24:17 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4407b8d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.6, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 13:27:50 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:27:50 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4696dda0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.7, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 13:27:50 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4696dda0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.7, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 13:31:24 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:31:24 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44255cf8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.8, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 13:31:24 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44255cf8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.8, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 13:34:57 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:34:57 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4428a400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.9, 'frequency_id': 4, 'repetitions': 1})>
# 2019-09-12 13:34:57 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4428a400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.9, 'frequency_id': 4, 'repetitions': 1})>
# 2019-09-12 13:38:30 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:38:30 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378bb898 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 13:38:30 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378bb898 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 13:42:04 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:42:04 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442ff2e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.1, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 13:42:04 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442ff2e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.1, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 13:45:37 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:45:37 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a440debe0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.2, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 13:45:37 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a440debe0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.2, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 13:49:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:49:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442ec7b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.3, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 13:49:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442ec7b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.3, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 13:52:43 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:52:44 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37827898 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.4, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 13:52:44 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37827898 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.4, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 13:56:17 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:56:17 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442732e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.5, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 13:56:17 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442732e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.5, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 13:59:50 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 13:59:50 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4408a780 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.6, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 13:59:50 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4408a780 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.6, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 14:03:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:03:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378f1c88 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.7, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 14:03:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378f1c88 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.7, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 14:06:57 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:06:57 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fb17b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.8, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 14:06:57 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fb17b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.8, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 14:10:30 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:10:30 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37a22ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.9, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 14:10:30 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37a22ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.9, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 14:14:04 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:14:04 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a46b370b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 14:14:04 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a46b370b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 14:17:37 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:17:37 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378bbc18 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.1, 'frequency_id': 16, 'repetitions': 1})>
# 2019-09-12 14:17:37 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378bbc18 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.1, 'frequency_id': 16, 'repetitions': 1})>
# 2019-09-12 14:21:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:21:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442cf4a8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.2, 'frequency_id': 17, 'repetitions': 1})>
# 2019-09-12 14:21:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442cf4a8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.2, 'frequency_id': 17, 'repetitions': 1})>
# 2019-09-12 14:24:44 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:24:44 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442ec5f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.3, 'frequency_id': 18, 'repetitions': 1})>
# 2019-09-12 14:24:44 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442ec5f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.3, 'frequency_id': 18, 'repetitions': 1})>
# 2019-09-12 14:28:17 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:28:17 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a641b7748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.4, 'frequency_id': 19, 'repetitions': 1})>
# 2019-09-12 14:28:17 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a641b7748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.4, 'frequency_id': 19, 'repetitions': 1})>
# 2019-09-12 14:31:50 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:31:50 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44358dd8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.5, 'frequency_id': 20, 'repetitions': 1})>
# 2019-09-12 14:31:50 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44358dd8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.5, 'frequency_id': 20, 'repetitions': 1})>
# 2019-09-12 14:35:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:35:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a440b5080 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.6, 'frequency_id': 21, 'repetitions': 1})>
# 2019-09-12 14:35:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a440b5080 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.6, 'frequency_id': 21, 'repetitions': 1})>
# 2019-09-12 14:38:57 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:38:57 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a3794f828 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.7, 'frequency_id': 22, 'repetitions': 1})>
# 2019-09-12 14:38:57 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a3794f828 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.7, 'frequency_id': 22, 'repetitions': 1})>
# 2019-09-12 14:42:30 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:42:30 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a641b16d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.8, 'frequency_id': 23, 'repetitions': 1})>
# 2019-09-12 14:42:30 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a641b16d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.8, 'frequency_id': 23, 'repetitions': 1})>
# 2019-09-12 14:46:03 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:46:03 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44099358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.9, 'frequency_id': 24, 'repetitions': 1})>
# 2019-09-12 14:46:03 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44099358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.9, 'frequency_id': 24, 'repetitions': 1})>
# 2019-09-12 14:49:36 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:49:36 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37d17c88 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.0, 'frequency_id': 25, 'repetitions': 1})>
# 2019-09-12 14:49:36 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37d17c88 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.0, 'frequency_id': 25, 'repetitions': 1})>
# 2019-09-12 14:53:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:53:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379684e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.1, 'frequency_id': 26, 'repetitions': 1})>
# 2019-09-12 14:53:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379684e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.1, 'frequency_id': 26, 'repetitions': 1})>
# 2019-09-12 14:56:43 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 14:56:43 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a441a5e48 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.2, 'frequency_id': 27, 'repetitions': 1})>
# 2019-09-12 14:56:43 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a441a5e48 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.2, 'frequency_id': 27, 'repetitions': 1})>
# 2019-09-12 15:00:16 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:00:16 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a64163f98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.4, 'frequency_id': 28, 'repetitions': 1})>
# 2019-09-12 15:00:16 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a64163f98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.4, 'frequency_id': 28, 'repetitions': 1})>
# 2019-09-12 15:03:49 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:03:49 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44298cc0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.5, 'frequency_id': 29, 'repetitions': 1})>
# 2019-09-12 15:03:49 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44298cc0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.5, 'frequency_id': 29, 'repetitions': 1})>
# 2019-09-12 15:07:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:07:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44234f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.6, 'frequency_id': 30, 'repetitions': 1})>
# 2019-09-12 15:07:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44234f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.6, 'frequency_id': 30, 'repetitions': 1})>
# 2019-09-12 15:10:56 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:10:56 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a3798c0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.7, 'frequency_id': 31, 'repetitions': 1})>
# 2019-09-12 15:10:56 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a3798c0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.7, 'frequency_id': 31, 'repetitions': 1})>
# 2019-09-12 15:18:03 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:18:03 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44145be0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.9, 'frequency_id': 33, 'repetitions': 1})>
# 2019-09-12 15:18:03 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44145be0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.9, 'frequency_id': 33, 'repetitions': 1})>
# 2019-09-12 15:21:37 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:21:37 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378ff128 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 34, 'repetitions': 1})>
# 2019-09-12 15:21:37 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378ff128 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 34, 'repetitions': 1})>
# 2019-09-12 15:25:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:25:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37930978 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.1, 'frequency_id': 35, 'repetitions': 1})>
# 2019-09-12 15:25:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37930978 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.1, 'frequency_id': 35, 'repetitions': 1})>
# 2019-09-12 15:28:43 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:28:44 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44164518 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.2, 'frequency_id': 36, 'repetitions': 1})>
# 2019-09-12 15:28:44 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44164518 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.2, 'frequency_id': 36, 'repetitions': 1})>
# 2019-09-12 15:32:17 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:32:17 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37918588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.3, 'frequency_id': 37, 'repetitions': 1})>
# 2019-09-12 15:32:17 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37918588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.3, 'frequency_id': 37, 'repetitions': 1})>
# 2019-09-12 15:35:50 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:35:50 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a64101eb8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.4, 'frequency_id': 38, 'repetitions': 1})>
# 2019-09-12 15:35:50 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a64101eb8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.4, 'frequency_id': 38, 'repetitions': 1})>
# 2019-09-12 15:39:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:39:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a443317b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.5, 'frequency_id': 39, 'repetitions': 1})>
# 2019-09-12 15:39:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a443317b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.5, 'frequency_id': 39, 'repetitions': 1})>
# 2019-09-12 15:42:57 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:42:57 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6402f7b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.7, 'frequency_id': 40, 'repetitions': 1})>
# 2019-09-12 15:42:57 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6402f7b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.7, 'frequency_id': 40, 'repetitions': 1})>
# 2019-09-12 15:46:30 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:46:30 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44164630 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.8, 'frequency_id': 41, 'repetitions': 1})>
# 2019-09-12 15:46:30 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44164630 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.8, 'frequency_id': 41, 'repetitions': 1})>
# 2019-09-12 15:50:03 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:50:03 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fc9668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.9, 'frequency_id': 42, 'repetitions': 1})>
# 2019-09-12 15:50:03 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fc9668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.9, 'frequency_id': 42, 'repetitions': 1})>
# 2019-09-12 15:53:37 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:53:37 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a64123320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.0, 'frequency_id': 43, 'repetitions': 1})>
# 2019-09-12 15:53:37 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a64123320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.0, 'frequency_id': 43, 'repetitions': 1})>
# 2019-09-12 15:57:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 15:57:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a640815c0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.1, 'frequency_id': 44, 'repetitions': 1})>
# 2019-09-12 15:57:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a640815c0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.1, 'frequency_id': 44, 'repetitions': 1})>
# 2019-09-12 16:00:43 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:00:43 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a441b46a0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.2, 'frequency_id': 45, 'repetitions': 1})>
# 2019-09-12 16:00:43 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a441b46a0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.2, 'frequency_id': 45, 'repetitions': 1})>
# 2019-09-12 16:04:16 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:04:16 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4428aa20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.3, 'frequency_id': 46, 'repetitions': 1})>
# 2019-09-12 16:04:16 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4428aa20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.3, 'frequency_id': 46, 'repetitions': 1})>
# 2019-09-12 16:07:50 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:07:50 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a441db278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.4, 'frequency_id': 47, 'repetitions': 1})>
# 2019-09-12 16:07:50 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a441db278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.4, 'frequency_id': 47, 'repetitions': 1})>
# 2019-09-12 16:11:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:11:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44174748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.6, 'frequency_id': 48, 'repetitions': 1})>
# 2019-09-12 16:11:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44174748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.6, 'frequency_id': 48, 'repetitions': 1})>
# 2019-09-12 16:14:56 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:14:56 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a3788d6d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.7, 'frequency_id': 49, 'repetitions': 1})>
# 2019-09-12 16:14:56 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a3788d6d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.7, 'frequency_id': 49, 'repetitions': 1})>
# 2019-09-12 16:18:29 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:18:29 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6412d0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.8, 'frequency_id': 50, 'repetitions': 1})>
# 2019-09-12 16:18:29 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6412d0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.8, 'frequency_id': 50, 'repetitions': 1})>
# 2019-09-12 16:25:36 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:25:36 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a640384e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.0, 'frequency_id': 52, 'repetitions': 1})>
# 2019-09-12 16:25:36 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a640384e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.0, 'frequency_id': 52, 'repetitions': 1})>
# 2019-09-12 16:29:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:29:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6400ea20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.1, 'frequency_id': 53, 'repetitions': 1})>
# 2019-09-12 16:29:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6400ea20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.1, 'frequency_id': 53, 'repetitions': 1})>
# 2019-09-12 16:32:43 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:32:43 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a440554e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.2, 'frequency_id': 54, 'repetitions': 1})>
# 2019-09-12 16:32:43 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a440554e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.2, 'frequency_id': 54, 'repetitions': 1})>
# 2019-09-12 16:36:16 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:36:16 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442014e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.4, 'frequency_id': 55, 'repetitions': 1})>
# 2019-09-12 16:36:16 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442014e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.4, 'frequency_id': 55, 'repetitions': 1})>
# 2019-09-12 16:39:50 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:39:50 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a640bf2e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.5, 'frequency_id': 56, 'repetitions': 1})>
# 2019-09-12 16:39:50 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a640bf2e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.5, 'frequency_id': 56, 'repetitions': 1})>
# 2019-09-12 16:43:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:43:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a440bf588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.6, 'frequency_id': 57, 'repetitions': 1})>
# 2019-09-12 16:43:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a440bf588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.6, 'frequency_id': 57, 'repetitions': 1})>
# 2019-09-12 16:46:56 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:46:56 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a3785d780 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.8, 'frequency_id': 58, 'repetitions': 1})>
# 2019-09-12 16:46:56 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a3785d780 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.8, 'frequency_id': 58, 'repetitions': 1})>
# 2019-09-12 16:50:30 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:50:30 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378f1668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.9, 'frequency_id': 59, 'repetitions': 1})>
# 2019-09-12 16:50:30 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378f1668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.9, 'frequency_id': 59, 'repetitions': 1})>
# 2019-09-12 16:54:03 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:54:03 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44213438 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.0, 'frequency_id': 60, 'repetitions': 1})>
# 2019-09-12 16:54:03 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44213438 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.0, 'frequency_id': 60, 'repetitions': 1})>
# 2019-09-12 16:57:36 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 16:57:36 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379bcc50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.1, 'frequency_id': 61, 'repetitions': 1})>
# 2019-09-12 16:57:36 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379bcc50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.1, 'frequency_id': 61, 'repetitions': 1})>
# 2019-09-12 17:01:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:01:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379fdd68 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.2, 'frequency_id': 62, 'repetitions': 1})>
# 2019-09-12 17:01:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379fdd68 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.2, 'frequency_id': 62, 'repetitions': 1})>
# 2019-09-12 17:04:43 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:04:43 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a441a5198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.4, 'frequency_id': 63, 'repetitions': 1})>
# 2019-09-12 17:04:43 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a441a5198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.4, 'frequency_id': 63, 'repetitions': 1})>
# 2019-09-12 17:08:16 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:08:16 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a640ea940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.5, 'frequency_id': 64, 'repetitions': 1})>
# 2019-09-12 17:08:16 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a640ea940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.5, 'frequency_id': 64, 'repetitions': 1})>
# 2019-09-12 17:11:49 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:11:49 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a443649b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.6, 'frequency_id': 65, 'repetitions': 1})>
# 2019-09-12 17:11:49 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a443649b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.6, 'frequency_id': 65, 'repetitions': 1})>
# 2019-09-12 17:15:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:15:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379240b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.7, 'frequency_id': 66, 'repetitions': 1})>
# 2019-09-12 17:15:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379240b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.7, 'frequency_id': 66, 'repetitions': 1})>
# 2019-09-12 17:18:56 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:18:56 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442ff748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.8, 'frequency_id': 67, 'repetitions': 1})>
# 2019-09-12 17:18:56 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442ff748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.8, 'frequency_id': 67, 'repetitions': 1})>
# 2019-09-12 17:22:29 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:22:29 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a64081908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.9, 'frequency_id': 68, 'repetitions': 1})>
# 2019-09-12 17:22:29 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a64081908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.9, 'frequency_id': 68, 'repetitions': 1})>
# 2019-09-12 17:26:03 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:26:03 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6406eac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.1, 'frequency_id': 69, 'repetitions': 1})>
# 2019-09-12 17:26:03 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6406eac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.1, 'frequency_id': 69, 'repetitions': 1})>
# 2019-09-12 17:29:36 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:29:36 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a64056518 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.2, 'frequency_id': 70, 'repetitions': 1})>
# 2019-09-12 17:29:36 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a64056518 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.2, 'frequency_id': 70, 'repetitions': 1})>
# 2019-09-12 17:33:10 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:33:10 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442396a0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.3, 'frequency_id': 71, 'repetitions': 1})>
# 2019-09-12 17:33:10 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442396a0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.3, 'frequency_id': 71, 'repetitions': 1})>
# 2019-09-12 17:36:43 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:36:43 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4408ac50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.5, 'frequency_id': 72, 'repetitions': 1})>
# 2019-09-12 17:36:43 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4408ac50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.5, 'frequency_id': 72, 'repetitions': 1})>
# 2019-09-12 17:40:16 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:40:16 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fbb278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.6, 'frequency_id': 73, 'repetitions': 1})>
# 2019-09-12 17:40:16 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fbb278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.6, 'frequency_id': 73, 'repetitions': 1})>
# 2019-09-12 17:43:50 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:43:50 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fc9320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.8, 'frequency_id': 74, 'repetitions': 1})>
# 2019-09-12 17:43:50 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fc9320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.8, 'frequency_id': 74, 'repetitions': 1})>
# 2019-09-12 17:47:23 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:47:23 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fd4b38 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.9, 'frequency_id': 75, 'repetitions': 1})>
# 2019-09-12 17:47:23 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fd4b38 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.9, 'frequency_id': 75, 'repetitions': 1})>
# 2019-09-12 17:50:56 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:50:56 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37d17668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.1, 'frequency_id': 76, 'repetitions': 1})>
# 2019-09-12 17:50:56 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37d17668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.1, 'frequency_id': 76, 'repetitions': 1})>
# 2019-09-12 17:54:29 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:54:29 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4410b588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.3, 'frequency_id': 77, 'repetitions': 1})>
# 2019-09-12 17:54:29 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4410b588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.3, 'frequency_id': 77, 'repetitions': 1})>
# 2019-09-12 17:58:03 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 17:58:03 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44255128 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.4, 'frequency_id': 78, 'repetitions': 1})>
# 2019-09-12 17:58:03 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44255128 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.4, 'frequency_id': 78, 'repetitions': 1})>
# 2019-09-12 18:01:36 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:01:36 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63f86470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.6, 'frequency_id': 79, 'repetitions': 1})>
# 2019-09-12 18:01:36 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63f86470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.6, 'frequency_id': 79, 'repetitions': 1})>
# 2019-09-12 18:05:09 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:05:09 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44245f98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.8, 'frequency_id': 80, 'repetitions': 1})>
# 2019-09-12 18:05:09 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44245f98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.8, 'frequency_id': 80, 'repetitions': 1})>
# 2019-09-12 18:08:42 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:08:42 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6402f828 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 81, 'repetitions': 1})>
# 2019-09-12 18:08:42 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6402f828 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 81, 'repetitions': 1})>
# 2019-09-12 18:12:16 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:12:16 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a64038940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.1, 'frequency_id': 82, 'repetitions': 1})>
# 2019-09-12 18:12:16 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a64038940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.1, 'frequency_id': 82, 'repetitions': 1})>
# 2019-09-12 18:15:49 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:15:49 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6406ecf8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.2, 'frequency_id': 83, 'repetitions': 1})>
# 2019-09-12 18:15:49 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6406ecf8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.2, 'frequency_id': 83, 'repetitions': 1})>
# 2019-09-12 18:19:22 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:19:22 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a440461d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.3, 'frequency_id': 84, 'repetitions': 1})>
# 2019-09-12 18:19:22 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a440461d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.3, 'frequency_id': 84, 'repetitions': 1})>
# 2019-09-12 18:22:56 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:22:56 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44364048 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.4, 'frequency_id': 85, 'repetitions': 1})>
# 2019-09-12 18:22:56 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44364048 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.4, 'frequency_id': 85, 'repetitions': 1})>
# 2019-09-12 18:26:29 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:26:29 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44152f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.5, 'frequency_id': 86, 'repetitions': 1})>
# 2019-09-12 18:26:29 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44152f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.5, 'frequency_id': 86, 'repetitions': 1})>
# 2019-09-12 18:30:02 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:30:02 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442396d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.6, 'frequency_id': 87, 'repetitions': 1})>
# 2019-09-12 18:30:02 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442396d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.6, 'frequency_id': 87, 'repetitions': 1})>
# 2019-09-12 18:33:35 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:33:35 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a640df9b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.8, 'frequency_id': 88, 'repetitions': 1})>
# 2019-09-12 18:33:35 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a640df9b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.8, 'frequency_id': 88, 'repetitions': 1})>
# 2019-09-12 18:37:09 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 18:37:09 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379bc9e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.9, 'frequency_id': 89, 'repetitions': 1})>
# 2019-09-12 18:37:09 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379bc9e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.9, 'frequency_id': 89, 'repetitions': 1})>
# ...
# 2019-09-12 22:17:34 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:17:34 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4b5005c0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 33.3, 'frequency_id': 151, 'repetitions': 1})>
# 2019-09-12 22:17:34 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4b5005c0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 33.3, 'frequency_id': 151, 'repetitions': 1})>
# 2019-09-12 22:21:07 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:21:07 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a3794fdd8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 34.5, 'frequency_id': 152, 'repetitions': 1})>
# 2019-09-12 22:21:07 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a3794fdd8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 34.5, 'frequency_id': 152, 'repetitions': 1})>
# 2019-09-12 22:24:41 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:24:41 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a4407bf28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 35.7, 'frequency_id': 153, 'repetitions': 1})>
# 2019-09-12 22:24:41 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a4407bf28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 35.7, 'frequency_id': 153, 'repetitions': 1})>
# 2019-09-12 22:28:14 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:28:14 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a443647f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 37.0, 'frequency_id': 154, 'repetitions': 1})>
# 2019-09-12 22:28:14 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a443647f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 37.0, 'frequency_id': 154, 'repetitions': 1})>
# 2019-09-12 22:31:47 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:31:47 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44222940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 38.5, 'frequency_id': 155, 'repetitions': 1})>
# 2019-09-12 22:31:47 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44222940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 38.5, 'frequency_id': 155, 'repetitions': 1})>
# 2019-09-12 22:35:21 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:35:21 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a442450b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 156, 'repetitions': 1})>
# 2019-09-12 22:35:21 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a442450b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 156, 'repetitions': 1})>
# 2019-09-12 22:38:54 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:38:54 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6402f278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 41.7, 'frequency_id': 157, 'repetitions': 1})>
# 2019-09-12 22:38:54 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6402f278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 41.7, 'frequency_id': 157, 'repetitions': 1})>
# 2019-09-12 22:42:27 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:42:27 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379f02e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 43.5, 'frequency_id': 158, 'repetitions': 1})>
# 2019-09-12 22:42:27 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379f02e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 43.5, 'frequency_id': 158, 'repetitions': 1})>
# 2019-09-12 22:46:01 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:46:01 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fe6d30 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 45.5, 'frequency_id': 159, 'repetitions': 1})>
# 2019-09-12 22:46:01 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fe6d30 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 45.5, 'frequency_id': 159, 'repetitions': 1})>
# 2019-09-12 22:49:34 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:49:34 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fbb198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 47.6, 'frequency_id': 160, 'repetitions': 1})>
# 2019-09-12 22:49:34 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fbb198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 47.6, 'frequency_id': 160, 'repetitions': 1})>
# 2019-09-12 22:53:07 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:53:07 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fb1550 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 161, 'repetitions': 1})>
# 2019-09-12 22:53:07 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fb1550 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 161, 'repetitions': 1})>
# 2019-09-12 22:56:40 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 22:56:40 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379d4b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 52.6, 'frequency_id': 162, 'repetitions': 1})>
# 2019-09-12 22:56:40 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379d4b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 52.6, 'frequency_id': 162, 'repetitions': 1})>
# 2019-09-12 23:00:14 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:00:14 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37968f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 55.6, 'frequency_id': 163, 'repetitions': 1})>
# 2019-09-12 23:00:14 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37968f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 55.6, 'frequency_id': 163, 'repetitions': 1})>
# 2019-09-12 23:03:47 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:03:47 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379d45f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 58.8, 'frequency_id': 164, 'repetitions': 1})>
# 2019-09-12 23:03:47 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379d45f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 58.8, 'frequency_id': 164, 'repetitions': 1})>
# 2019-09-12 23:07:20 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:07:20 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fd44a8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 62.5, 'frequency_id': 165, 'repetitions': 1})>
# 2019-09-12 23:07:20 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fd44a8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 62.5, 'frequency_id': 165, 'repetitions': 1})>
# 2019-09-12 23:10:54 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:10:54 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44267b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 66.7, 'frequency_id': 166, 'repetitions': 1})>
# 2019-09-12 23:10:54 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44267b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 66.7, 'frequency_id': 166, 'repetitions': 1})>
# 2019-09-12 23:14:27 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:14:27 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378bb9e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 71.4, 'frequency_id': 167, 'repetitions': 1})>
# 2019-09-12 23:14:27 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378bb9e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 71.4, 'frequency_id': 167, 'repetitions': 1})>
# 2019-09-12 23:18:00 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:18:00 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37a07a90 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 76.9, 'frequency_id': 168, 'repetitions': 1})>
# 2019-09-12 23:18:00 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37a07a90 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 76.9, 'frequency_id': 168, 'repetitions': 1})>
# 2019-09-12 23:21:34 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:21:34 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a641019e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 83.3, 'frequency_id': 169, 'repetitions': 1})>
# 2019-09-12 23:21:34 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a641019e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 83.3, 'frequency_id': 169, 'repetitions': 1})>
# 2019-09-12 23:25:07 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:25:07 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a441648d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 90.9, 'frequency_id': 170, 'repetitions': 1})>
# 2019-09-12 23:25:07 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a441648d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 90.9, 'frequency_id': 170, 'repetitions': 1})>
# 2019-09-12 23:28:41 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:28:41 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6408ebe0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 171, 'repetitions': 1})>
# 2019-09-12 23:28:41 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6408ebe0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 171, 'repetitions': 1})>
# 2019-09-12 23:32:14 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:32:14 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63fb1c50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 111.1, 'frequency_id': 172, 'repetitions': 1})>
# 2019-09-12 23:32:14 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63fb1c50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 111.1, 'frequency_id': 172, 'repetitions': 1})>
# 2019-09-12 23:35:47 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:35:47 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a37d177f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 173, 'repetitions': 1})>
# 2019-09-12 23:35:47 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a37d177f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 173, 'repetitions': 1})>
# 2019-09-12 23:39:21 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:39:21 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a6408eb70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 142.9, 'frequency_id': 174, 'repetitions': 1})>
# 2019-09-12 23:39:21 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a6408eb70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 142.9, 'frequency_id': 174, 'repetitions': 1})>
# 2019-09-12 23:42:54 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:42:54 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a378ff320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 166.7, 'frequency_id': 175, 'repetitions': 1})>
# 2019-09-12 23:42:54 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a378ff320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 166.7, 'frequency_id': 175, 'repetitions': 1})>
# 2019-09-12 23:46:27 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:46:27 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a379d40b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 176, 'repetitions': 1})>
# 2019-09-12 23:46:27 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a379d40b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 176, 'repetitions': 1})>
# 2019-09-12 23:50:01 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:50:01 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a44213860 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 177, 'repetitions': 1})>
# 2019-09-12 23:50:01 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a44213860 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 177, 'repetitions': 1})>
# 2019-09-12 23:53:34 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:53:34 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a63f95080 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 333.3, 'frequency_id': 178, 'repetitions': 1})>
# 2019-09-12 23:53:34 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a63f95080 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 333.3, 'frequency_id': 178, 'repetitions': 1})>
# 2019-09-12 23:57:07 :: Haswell_3->host: experiment logs fetched!
# 2019-09-12 23:57:07 :: executing in env: 'Haswell_3', resume: False, reps: [0], run: <Run at 0x7f6a441d0e10 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 179, 'repetitions': 1})>
# 2019-09-12 23:57:07 :: executing in env: Haswell_3, rep: 0, estimated duration: 120s, run: <Run at 0x7f6a441d0e10 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 179, 'repetitions': 1})>
# 2019-09-13 00:00:41 :: Haswell_3->host: experiment logs fetched!
# 2019-09-13 00:00:41 :: Haswell_3->host: cleaning up
# 2019-09-13 00:01:44 :: Haswell_3->host: successfully deleted remote data directory
# 2019-09-13 00:01:44 :: Haswell_3->host: disconnected

# %% [markdown]
# ### Thermal performance
# Status: executed performance, executed interference (SHORT only)

# %%
for _experiment in ["thermal-cc_performance", "thermal-cc_interference"]:
    for _platform, _phase_mapping in phases_thermal.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0], "logs:", _logs[0], sep=" ")

# %% [markdown]
# - Execution (Performance)

# %%
SHORT = False

for experiment_thermal_path in [ 
    "data/thermal-cc_performance/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e

# %% [markdown]
# - Execution (Interference)

# %%
SHORT = False

for experiment_thermal_path in [ 
    "data/thermal-cc_interference/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e
