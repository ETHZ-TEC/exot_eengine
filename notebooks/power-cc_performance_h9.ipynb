# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM
import sklearn.ensemble             # RandomForestClassifier, VotingClassifier

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Tensorflow not available - excluding packets relying on it!

# %% [markdown]
# __Notebook config__

# %%
NB_EXPERIMENT = "power-cc_performance_h9"

environments_to_execute = [
    "Sandy"
]

phases = {
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = experiment._execution_status

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    for phase in phases[env].items():
         experiment.execute_in_environment(env, phase, resume=False)
experiment.write()

# %% [markdown]
# # Demo
# With the following cell you can visualise a single run from either platform and also have a look on the data histogram, to check whether the quantisation thresholds are defined correctly.

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)

DEMO_PHASE = "eval"
DEMO_ID = 0

ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io=(
        {
            "env": "Sandy",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
    ),
)

demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream()
    plotter.plot_rdpstream(end=10)
    plotter.plot_slicing()
    plotter.plot_symstream()

quantisation_thresholds = experiment.environments_apps_zones[
    ingest_args['io']['env']]['snk']['zone_config'].power_thresholds[
    demo_run.i_rdpstream.columns[-1].split(':')[-2]]

plt.figure()
plt.hist(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'], bins='auto')
plt.xticks(np.arange(0, max(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'])+1, 1.0))
for threshold in quantisation_thresholds[1:]:
    plt.axvline(x=threshold, color='red', linestyle='--')
plt.xlim([0,70])
# Out:
# 2020-03-30 18:43:47 :: unpicked an experiment instance <PerformanceExperiment at 0x7f4ea3046dd8 with PowerCC channel, configured>
# 2020-03-30 18:43:47 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:43:47 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:43:48 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:43:48 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:43:48 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:43:48 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:43:48 :: bootstrapped layer 'io' with TimeValue
# (0, 70)

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# ## Analyse
#
# 1. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)
# Out:
# 2020-03-30 18:44:49 :: unpicked an experiment instance <PerformanceExperiment at 0x7f4e9eebb278 with PowerCC channel, configured>
# 2020-03-30 18:44:49 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:44:49 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:44:49 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:44:49 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:44:49 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:44:49 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:44:49 :: bootstrapped layer 'io' with TimeValue

# %% [markdown]
# 2. Display histogram to verify whether the quantisation thresholds fitting

# %%
THRESHOLD_PHASE = "eval"
THRESHOLD_ID = 0

ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io={
            "env": "Sandy",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
       },
)

hist_run = experiment.phases[THRESHOLD_PHASE][THRESHOLD_ID]
hist_run.ingest(**ingest_args)

quantisation_thresholds = experiment.environments_apps_zones[
    ingest_args['io']['env']]['snk']['zone_config'].power_thresholds[
    hist_run.i_rdpstream.columns[-1].split(':')[-2]]

import scipy.interpolate

t_min = 50
t_max = 90

to_plot = copy(hist_run.i_rdpstream['power_msr:rapl_domain:pp0:W'].to_numpy())
# Median filter
window = 9
to_plot = scipy.signal.medfilt(to_plot, kernel_size=window)

plt.figure()
threshold_histogram = plt.hist(to_plot, bins='auto')
plt.xticks(np.arange(0, max(to_plot)+1, 1.0))
for threshold in quantisation_thresholds[1:]:
    plt.axvline(x=threshold, color='red', linestyle='--')
plt.xlim([0,70])

ideal_values_interpolator  = scipy.interpolate.interp1d(
    hist_run.o_rdpstream.iloc[:,0].cumsum(),
    hist_run.o_rdpstream.iloc[:,1],
    axis=0,
    kind='next',
    bounds_error=False,
    fill_value="extrapolate",
)

resampled_ideal_values = ideal_values_interpolator(hist_run.i_rdpstream.iloc[:,0])
maskvals = np.unique(resampled_ideal_values)
for idx in range(len(quantisation_thresholds)):
    if idx == len(quantisation_thresholds)-1:
        quantval = quantisation_thresholds[idx] + (
            quantisation_thresholds[idx-1]-quantisation_thresholds[idx-2]) 
    else:
        quantval = (
            (quantisation_thresholds[idx+1] - quantisation_thresholds[idx]) / 2 + quantisation_thresholds[idx]
        )
    resampled_ideal_values[maskvals[idx] == resampled_ideal_values] = quantval

#fig, (ax1, ax2) = plt.subplots(2,1, sharex=True)
plt.figure()
plt.plot(hist_run.i_rdpstream.iloc[:,0], to_plot, label='rdpstream')
plt.plot(hist_run.i_rdpstream.iloc[:,0], resampled_ideal_values, label='ideal rdpstream')
for threshold in quantisation_thresholds[1:]:
    plt.axhline(y=threshold, color='red', linestyle='--')
plt.ylim([0,70])
plt.xlim([t_min,t_max])
plt.ylabel('Power [W]')
plt.xlabel('Time [s]')

idx_min = np.where(hist_run.i_rdpstream.iloc[:,0] >= t_min)[0][0]
idx_max = np.where(hist_run.i_rdpstream.iloc[:,0] <= t_max)[0][-1]+1

pd.DataFrame({"bin_center": threshold_histogram[1][:-1] + np.diff(threshold_histogram[1]), 
              "density": threshold_histogram[0] / threshold_histogram[0].max()}).to_csv(
    experiment.path.joinpath("thresholds_hist_sandy.dat"),
    sep=",",
    encoding="utf-8",
    index=False,
)

pd.DataFrame({"time [s]": hist_run.i_rdpstream.iloc[idx_min:idx_max,0], 
              "raw": to_plot[idx_min:idx_max],
              "ideal": resampled_ideal_values[idx_min:idx_max],
             }).to_csv(
    experiment.path.joinpath("thresholds_trace_sandy.dat"),
    sep=",",
    encoding="utf-8",
    index=False,
)

# %% [markdown]
# 3. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "normal"

analysis_args = {
    "Sandy": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(),
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)]
        },
    ),
}

phase_mappings = {
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %% [markdown]
# 4. Calculate the performance metrics

# %%
del experiment.performance_metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        use_levensthein=True,
        **analysis_args[env],
    )
# Out:
# 2020-03-30 18:45:09 :: analysing performance for phases: train -> eval, environments ['Sandy']

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#    phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  train                    Sandy  3.222222            1           0
# 1   eval        train       Sandy  3.222222            1           0
# 2  train                    Sandy  3.222222            1           1
# 3   eval        train       Sandy  3.222222            1           1
# 4  train                    Sandy  3.222222            1           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.078966      0.159329  <Matcher quantity='power', method='msr', value...
# 1   0.079883      0.167503  <Matcher quantity='power', method='msr', value...
# 2   0.070580      0.144654  <Matcher quantity='power', method='msr', value...
# 3   0.093685      0.211418  <Matcher quantity='power', method='msr', value...
# 4   0.069881      0.142558  <Matcher quantity='power', method='msr', value...
#
#     variable
# 0  power_msr
# 1  power_msr
# 2  power_msr
# 3  power_msr
# 4  power_msr

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#      phase trained_with environment     bit_rate  symbol_rate  \
# 0     eval        train       Sandy     3.222222            1
# 1     eval        train       Sandy    32.222222           10
# 2     eval        train       Sandy    64.444444           20
# 3     eval        train       Sandy    96.666667           30
# 4     eval        train       Sandy   128.888889           40
# 5     eval        train       Sandy   161.111111           50
# 6     eval        train       Sandy   193.333333           60
# 7     eval        train       Sandy   225.555556           70
# 8     eval        train       Sandy   257.777778           80
# 9     eval        train       Sandy   290.000000           90
# 10    eval        train       Sandy   322.222222          100
# 11    eval        train       Sandy   354.444444          110
# 12    eval        train       Sandy   386.666667          120
# 13    eval        train       Sandy   418.888889          130
# 14    eval        train       Sandy   451.111111          140
# 15    eval        train       Sandy   483.333333          150
# 16    eval        train       Sandy   515.555556          160
# 17    eval        train       Sandy   547.777778          170
# 18    eval        train       Sandy   580.000000          180
# 19    eval        train       Sandy   612.222222          190
# 20    eval        train       Sandy   644.444444          200
# 21    eval        train       Sandy   676.666667          210
# 22    eval        train       Sandy   708.888889          220
# 23    eval        train       Sandy   741.111111          230
# 24    eval        train       Sandy   773.333333          240
# 25    eval        train       Sandy   805.555556          250
# 26    eval        train       Sandy   837.777778          260
# 27    eval        train       Sandy   870.000000          270
# 28    eval        train       Sandy   902.222222          280
# 29    eval        train       Sandy   934.444444          290
# ..     ...          ...         ...          ...          ...
# 172  train                    Sandy  2287.777778          710
# 173  train                    Sandy  2320.000000          720
# 174  train                    Sandy  2352.222222          730
# 175  train                    Sandy  2384.444444          740
# 176  train                    Sandy  2416.666667          750
# 177  train                    Sandy  2448.888889          760
# 178  train                    Sandy  2481.111111          770
# 179  train                    Sandy  2513.333333          780
# 180  train                    Sandy  2545.555556          790
# 181  train                    Sandy  2577.777778          800
# 182  train                    Sandy  2610.000000          810
# 183  train                    Sandy  2642.222222          820
# 184  train                    Sandy  2674.444444          830
# 185  train                    Sandy  2706.666667          840
# 186  train                    Sandy  2738.888889          850
# 187  train                    Sandy  2771.111111          860
# 188  train                    Sandy  2803.333333          870
# 189  train                    Sandy  2835.555556          880
# 190  train                    Sandy  2867.777778          890
# 191  train                    Sandy  2900.000000          900
# 192  train                    Sandy  2932.222222          910
# 193  train                    Sandy  2964.444444          920
# 194  train                    Sandy  2996.666667          930
# 195  train                    Sandy  3028.888889          940
# 196  train                    Sandy  3061.111111          950
# 197  train                    Sandy  3093.333333          960
# 198  train                    Sandy  3125.555556          970
# 199  train                    Sandy  3157.777778          980
# 200  train                    Sandy  3190.000000          990
# 201  train                    Sandy  3222.222222         1000
#
#                                                matcher   variable  bit_error  \
# 0    <Matcher quantity='power', method='msr', value...  power_msr   0.087829
# 1    <Matcher quantity='power', method='msr', value...  power_msr   0.063016
# 2    <Matcher quantity='power', method='msr', value...  power_msr   0.253807
# 3    <Matcher quantity='power', method='msr', value...  power_msr   0.306223
# 4    <Matcher quantity='power', method='msr', value...  power_msr   1.660112
# 5    <Matcher quantity='power', method='msr', value...  power_msr   0.326502
# 6    <Matcher quantity='power', method='msr', value...  power_msr   0.118827
# 7    <Matcher quantity='power', method='msr', value...  power_msr   0.102646
# 8    <Matcher quantity='power', method='msr', value...  power_msr   0.286713
# 9    <Matcher quantity='power', method='msr', value...  power_msr   2.230043
# 10   <Matcher quantity='power', method='msr', value...  power_msr   0.114390
# 11   <Matcher quantity='power', method='msr', value...  power_msr   0.105890
# 12   <Matcher quantity='power', method='msr', value...  power_msr   0.131335
# 13   <Matcher quantity='power', method='msr', value...  power_msr   1.204538
# 14   <Matcher quantity='power', method='msr', value...  power_msr   0.131612
# 15   <Matcher quantity='power', method='msr', value...  power_msr   0.117315
# 16   <Matcher quantity='power', method='msr', value...  power_msr   0.134736
# 17   <Matcher quantity='power', method='msr', value...  power_msr   0.280002
# 18   <Matcher quantity='power', method='msr', value...  power_msr   0.131508
# 19   <Matcher quantity='power', method='msr', value...  power_msr   0.311540
# 20   <Matcher quantity='power', method='msr', value...  power_msr   0.153334
# 21   <Matcher quantity='power', method='msr', value...  power_msr   0.466498
# 22   <Matcher quantity='power', method='msr', value...  power_msr   0.296420
# 23   <Matcher quantity='power', method='msr', value...  power_msr   0.296228
# 24   <Matcher quantity='power', method='msr', value...  power_msr   0.132772
# 25   <Matcher quantity='power', method='msr', value...  power_msr   0.137900
# 26   <Matcher quantity='power', method='msr', value...  power_msr   0.890618
# 27   <Matcher quantity='power', method='msr', value...  power_msr   0.135429
# 28   <Matcher quantity='power', method='msr', value...  power_msr   0.284514
# 29   <Matcher quantity='power', method='msr', value...  power_msr   0.152326
# ..                                                 ...        ...        ...
# 172  <Matcher quantity='power', method='msr', value...  power_msr   0.286330
# 173  <Matcher quantity='power', method='msr', value...  power_msr   0.192464
# 174  <Matcher quantity='power', method='msr', value...  power_msr   0.211279
# 175  <Matcher quantity='power', method='msr', value...  power_msr   0.319370
# 176  <Matcher quantity='power', method='msr', value...  power_msr   0.208818
# 177  <Matcher quantity='power', method='msr', value...  power_msr   0.291257
# 178  <Matcher quantity='power', method='msr', value...  power_msr   0.244892
# 179  <Matcher quantity='power', method='msr', value...  power_msr   0.315890
# 180  <Matcher quantity='power', method='msr', value...  power_msr   0.325242
# 181  <Matcher quantity='power', method='msr', value...  power_msr   0.234845
# 182  <Matcher quantity='power', method='msr', value...  power_msr   0.228272
# 183  <Matcher quantity='power', method='msr', value...  power_msr   0.305196
# 184  <Matcher quantity='power', method='msr', value...  power_msr   0.218032
# 185  <Matcher quantity='power', method='msr', value...  power_msr   0.266269
# 186  <Matcher quantity='power', method='msr', value...  power_msr   0.235923
# 187  <Matcher quantity='power', method='msr', value...  power_msr   0.343839
# 188  <Matcher quantity='power', method='msr', value...  power_msr   0.262175
# 189  <Matcher quantity='power', method='msr', value...  power_msr   0.223933
# 190  <Matcher quantity='power', method='msr', value...  power_msr   0.280037
# 191  <Matcher quantity='power', method='msr', value...  power_msr   0.220724
# 192  <Matcher quantity='power', method='msr', value...  power_msr   0.222403
# 193  <Matcher quantity='power', method='msr', value...  power_msr   0.257102
# 194  <Matcher quantity='power', method='msr', value...  power_msr   0.252723
# 195  <Matcher quantity='power', method='msr', value...  power_msr   0.326635
# 196  <Matcher quantity='power', method='msr', value...  power_msr   0.443632
# 197  <Matcher quantity='power', method='msr', value...  power_msr   0.216290
# 198  <Matcher quantity='power', method='msr', value...  power_msr   0.219058
# 199  <Matcher quantity='power', method='msr', value...  power_msr   0.282946
# 200  <Matcher quantity='power', method='msr', value...  power_msr   0.201769
# 201  <Matcher quantity='power', method='msr', value...  power_msr   0.279550
#
#      symbol_error
# 0        0.192179
# 1        0.126379
# 2        0.789869
# 3        0.367920
# 4        1.924472
# 5        0.545507
# 6        0.243862
# 7        0.211686
# 8        0.750627
# 9        2.564576
# 10       0.254068
# 11       0.270677
# 12       0.301109
# 13       1.557293
# 14       0.301914
# 15       0.295582
# 16       0.313125
# 17       0.650665
# 18       0.297828
# 19       0.730792
# 20       0.397004
# 21       0.728759
# 22       0.711655
# 23       0.696638
# 24       0.317936
# 25       0.336449
# 26       1.401283
# 27       0.362382
# 28       0.744167
# 29       0.347509
# ..            ...
# 172      0.695080
# 173      0.475694
# 174      0.529123
# 175      0.737500
# 176      0.487448
# 177      0.743590
# 178      0.603472
# 179      0.776854
# 180      0.733894
# 181      0.533058
# 182      0.535565
# 183      0.784273
# 184      0.509028
# 185      0.698047
# 186      0.559028
# 187      0.768267
# 188      0.665284
# 189      0.559748
# 190      0.699862
# 191      0.541494
# 192      0.523810
# 193      0.616287
# 194      0.612725
# 195      0.804003
# 196      0.794386
# 197      0.538354
# 198      0.545392
# 199      0.708160
# 200      0.474623
# 201      0.705475
#
# [202 rows x 9 columns]

# %% [markdown]
# 5. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 6. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = ("interference" if "interference" in NB_EXPERIMENT else "baseline")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        experiment.path.joinpath("performance_{}_{}_{}.dat".format(PREFIX, NB_EXPERIMENT.split('_')[-1], 
                                                             env)),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 7. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
