# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %%
SHORT = False
UPDATE = True
RESUME = False

# %%
environments_to_execute = [
#     'ARMv8',
    'Haswell',
#     "Haswell_2",
#     "Haswell_3",
]

phases_cache = {
    'ARMv8':{'short':['trainShortARMv8','evalShortARMv8'],
               'normal':['trainARMv8','evalARMv8']},
    'Haswell':{'short':['trainShortHaswell','evalShortHaswell'],
               'normal':['trainHaswell','evalHaswell']}
}
phases_thermal_cap = {
    'ARMv8':{'short':['sweepShortARMv8'],
               'normal':['sweepARMv8']},
    'Haswell':{'short':['sweepShortHaswell'],
               'normal':['sweepHaswell']},
    'Haswell_2':{'short':['sweepShortHaswell'],
               'normal':['sweepHaswell']},
    'Haswell_3':{'short':['sweepShortHaswell'],
               'normal':['sweepHaswell']}
}
phases_thermal = {
    'ARMv8':{'short':['trainShortARMv8','evalShortARMv8'],
               'normal':['trainARMv8','evalARMv8']},
    'Haswell':{'short':['trainShortHaswell','evalShortHaswell'],
               'normal':['trainHaswell','evalHaswell']}
}

# %% [markdown]
# ### Cache performance
# Status: executed

# %%
for _experiment in [
    "flush+flush-cc_performance",
    "flush+reload-cc_performance",
    "flush+prefetch-cc_performance",
    "flush+flush-cc_interference",
    "flush+reload-cc_interference",
    "flush+prefetch-cc_interference",
]:
    for _platform, _phase_mapping in phases_cache.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0], "logs:", _logs[0], sep=" ")

# %% [markdown]
# - Execution

# %%
SHORT = False

for experiment_cache_path in [
    "data/flush+flush-cc_performance/_experiment.pickle",
    "data/flush+reload-cc_performance/_experiment.pickle",
    "data/flush+prefetch-cc_performance/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_cache_path)
        experiment_cache = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_cache.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_cache.config.experiment_exists_action = "update"
            experiment_cache._update_mode = True
        for env in environments_to_execute:
            experiment_cache.execute_in_environment(
                env,
                phases_cache[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_cache.write()
    except Exception as e:
        print("ERROR - ", experiment_cache_path, str(e))
        raise e

# %%
SHORT = False

for experiment_cache_path in [
    "data/flush+flush-cc_interference/_experiment.pickle",
    "data/flush+reload-cc_interference/_experiment.pickle",
#     "data/flush+prefetch-cc_interference/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_cache_path)
        experiment_cache = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        experiment_cache.config.EXPERIMENT.GENERAL.active_wait=True
        try:
            experiment_cache.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_cache.config.experiment_exists_action = "update"
            experiment_cache._update_mode = True
        for env in environments_to_execute:
            experiment_cache.execute_in_environment(
                env,
                phases_cache[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_cache.write()
    except Exception as e:
        print("ERROR - ", experiment_cache_path, str(e))
        raise e

# %% [markdown]
# ### Thermal capacity
# Status: executed

# %%
for _experiment in ["thermal-cc_capacity"]:
    for _platform, _phase_mapping in phases_thermal_cap.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0], "logs:", _logs[0], sep=" ")
# Out:
# experiment: thermal-cc_capacity platform: ARMv8 phase: sweepShortARMv8 folders: 1 logs: 0
# experiment: thermal-cc_capacity platform: ARMv8 phase: sweepARMv8 folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell phase: sweepShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell phase: sweepHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_2 phase: sweepShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_2 phase: sweepHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_3 phase: sweepShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_capacity platform: Haswell_3 phase: sweepHaswell folders: 0 logs: 0

# %% [markdown]
# - Execution

# %%
SHORT = True

for experiment_thermal_path in [
    "data/thermal-cc_capacity/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = FrequencySweepExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal_cap[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
#         experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e
# Out:
# 2019-09-12 12:21:55 :: unpicked an experiment instance <FrequencySweepExperiment at 0x7fd16b5235c0 with Thermal channel, configured>
# 2019-09-12 12:21:56 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2019-09-12 12:22:09 :: Haswell->host: connected: SSHUnixDriver
# 2019-09-12 12:22:09 :: Haswell->host: sending experiment
# 2019-09-12 12:22:10 :: Haswell->host: experiment sent!
# 2019-09-12 12:22:10 :: executing phases: ['sweepShortHaswell'] in env 'Haswell'
# 2019-09-12 12:22:10 :: Haswell->host: configuring to {'latency': 10, 'fan': True, 'governors': 'userspace', 'frequencies': 'max', 'sampling_period': 0.001, 'delay_after_spawn': 30.0, 'delay_after_auxiliary': 1.0, 'active_wait': False, 'ARMv8': {'fan': '255', 'delay_after_spawn': 120.0}}
# 2019-09-12 12:22:13 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14bea0be0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 12:22:13 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14bea0be0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 12:25:47 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:25:47 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14cc47208 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 12:25:47 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14cc47208 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 12:29:20 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:29:20 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14cfdbac8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 12:29:20 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14cfdbac8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 12:32:53 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:32:54 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14cbf3f98 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 12:32:54 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14cbf3f98 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 12:40:01 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:40:01 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14ca0a128 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 8.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 12:40:01 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14ca0a128 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 8.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 12:43:34 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:43:34 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14d2ffd68 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 12:43:34 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14d2ffd68 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 12:47:07 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:47:07 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14beb6860 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 20.0, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 12:47:07 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14beb6860 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 20.0, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 12:50:40 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:50:40 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14bf4ca58 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 25.0, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 12:50:40 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14bf4ca58 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 25.0, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 12:54:14 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:54:14 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14ce41c18 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 12:54:14 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14ce41c18 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 12:57:47 :: Haswell->host: experiment logs fetched!
# 2019-09-12 12:57:47 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14bf290b8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 12:57:47 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14bf290b8 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 13:01:20 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:01:20 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14d023f98 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 13:01:20 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14d023f98 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 13:04:53 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:04:53 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14b607668 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 13:04:53 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14b607668 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 13:08:27 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:08:27 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14cc13908 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 13:08:27 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14cc13908 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 13:12:00 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:12:00 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14ce93908 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 13:12:00 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14ce93908 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 13:15:34 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:15:34 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14c7c30f0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 13:15:34 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14c7c30f0 (digested, config={'phase': 'sweepShortHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 13:19:07 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:19:07 :: Haswell->host: cleaning up
# 2019-09-12 13:19:15 :: Haswell->host: successfully deleted remote data directory
# 2019-09-12 13:19:15 :: Haswell->host: disconnected

# %%
SHORT = False

for experiment_thermal_path in [
    "data/thermal-cc_capacity/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = FrequencySweepExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal_cap[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
#         experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e
# Out:
# 2019-09-12 13:19:15 :: unpicked an experiment instance <FrequencySweepExperiment at 0x7fd168c662e8 with Thermal channel, configured>
# 2019-09-12 13:19:16 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2019-09-12 13:19:29 :: Haswell->host: connected: SSHUnixDriver
# 2019-09-12 13:19:29 :: Haswell->host: sending experiment
# 2019-09-12 13:19:30 :: Haswell->host: experiment sent!
# 2019-09-12 13:19:30 :: executing phases: ['sweepHaswell'] in env 'Haswell'
# 2019-09-12 13:19:30 :: Haswell->host: configuring to {'latency': 10, 'fan': True, 'governors': 'userspace', 'frequencies': 'max', 'sampling_period': 0.001, 'delay_after_spawn': 30.0, 'delay_after_auxiliary': 1.0, 'active_wait': False, 'ARMv8': {'fan': '255', 'delay_after_spawn': 120.0}}
# 2019-09-12 13:19:34 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494008d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 13:19:34 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494008d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.0, 'frequency_id': 0, 'repetitions': 1})>
# 2019-09-12 13:23:07 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:23:07 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1495f2198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.6, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 13:23:07 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1495f2198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.6, 'frequency_id': 1, 'repetitions': 1})>
# 2019-09-12 13:26:40 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:26:41 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168c82c18 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.7, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 13:26:41 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168c82c18 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.7, 'frequency_id': 2, 'repetitions': 1})>
# 2019-09-12 13:30:14 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:30:14 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a37be0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.8, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 13:30:14 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a37be0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.8, 'frequency_id': 3, 'repetitions': 1})>
# 2019-09-12 13:33:47 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:33:47 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149ac0860 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.9, 'frequency_id': 4, 'repetitions': 1})>
# 2019-09-12 13:33:47 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149ac0860 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 0.9, 'frequency_id': 4, 'repetitions': 1})>
# 2019-09-12 13:37:21 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:37:21 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149387a20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 13:37:21 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149387a20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.0, 'frequency_id': 5, 'repetitions': 1})>
# 2019-09-12 13:40:54 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:40:54 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168afea20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.1, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 13:40:54 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168afea20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.1, 'frequency_id': 6, 'repetitions': 1})>
# 2019-09-12 13:44:27 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:44:27 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1495d29e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.2, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 13:44:27 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1495d29e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.2, 'frequency_id': 7, 'repetitions': 1})>
# 2019-09-12 13:48:00 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:48:00 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a91f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.3, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 13:48:00 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a91f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.3, 'frequency_id': 8, 'repetitions': 1})>
# 2019-09-12 13:51:34 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:51:34 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd148364b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.4, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 13:51:34 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd148364b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.4, 'frequency_id': 9, 'repetitions': 1})>
# 2019-09-12 13:55:07 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:55:07 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a291d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.5, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 13:55:07 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a291d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.5, 'frequency_id': 10, 'repetitions': 1})>
# 2019-09-12 13:58:41 :: Haswell->host: experiment logs fetched!
# 2019-09-12 13:58:41 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149584400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.6, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 13:58:41 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149584400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.6, 'frequency_id': 11, 'repetitions': 1})>
# 2019-09-12 14:02:14 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:02:14 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14936a0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.7, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 14:02:14 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14936a0f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.7, 'frequency_id': 12, 'repetitions': 1})>
# 2019-09-12 14:05:47 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:05:47 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149b0d470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.8, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 14:05:47 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149b0d470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.8, 'frequency_id': 13, 'repetitions': 1})>
# 2019-09-12 14:09:21 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:09:21 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494e12b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.9, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 14:09:21 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494e12b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 1.9, 'frequency_id': 14, 'repetitions': 1})>
# 2019-09-12 14:12:54 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:12:54 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168be7908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 14:12:54 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168be7908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.0, 'frequency_id': 15, 'repetitions': 1})>
# 2019-09-12 14:16:27 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:16:27 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149376320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.1, 'frequency_id': 16, 'repetitions': 1})>
# 2019-09-12 14:16:27 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149376320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.1, 'frequency_id': 16, 'repetitions': 1})>
# 2019-09-12 14:20:01 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:20:01 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1499f4e10 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.2, 'frequency_id': 17, 'repetitions': 1})>
# 2019-09-12 14:20:01 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1499f4e10 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.2, 'frequency_id': 17, 'repetitions': 1})>
# 2019-09-12 14:23:34 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:23:34 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a5d940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.3, 'frequency_id': 18, 'repetitions': 1})>
# 2019-09-12 14:23:34 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a5d940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.3, 'frequency_id': 18, 'repetitions': 1})>
# 2019-09-12 14:27:08 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:27:08 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168be7e48 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.4, 'frequency_id': 19, 'repetitions': 1})>
# 2019-09-12 14:27:08 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168be7e48 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.4, 'frequency_id': 19, 'repetitions': 1})>
# 2019-09-12 14:30:41 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:30:41 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149af02e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.5, 'frequency_id': 20, 'repetitions': 1})>
# 2019-09-12 14:30:41 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149af02e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.5, 'frequency_id': 20, 'repetitions': 1})>
# 2019-09-12 14:34:14 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:34:14 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149605b00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.6, 'frequency_id': 21, 'repetitions': 1})>
# 2019-09-12 14:34:14 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149605b00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.6, 'frequency_id': 21, 'repetitions': 1})>
# 2019-09-12 14:37:48 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:37:48 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149459c50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.7, 'frequency_id': 22, 'repetitions': 1})>
# 2019-09-12 14:37:48 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149459c50 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.7, 'frequency_id': 22, 'repetitions': 1})>
# 2019-09-12 14:41:21 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:41:21 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168c82ef0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.8, 'frequency_id': 23, 'repetitions': 1})>
# 2019-09-12 14:41:21 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168c82ef0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.8, 'frequency_id': 23, 'repetitions': 1})>
# 2019-09-12 14:44:54 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:44:54 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1495919b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.9, 'frequency_id': 24, 'repetitions': 1})>
# 2019-09-12 14:44:54 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1495919b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 2.9, 'frequency_id': 24, 'repetitions': 1})>
# 2019-09-12 14:48:28 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:48:28 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149518e10 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.0, 'frequency_id': 25, 'repetitions': 1})>
# 2019-09-12 14:48:28 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149518e10 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.0, 'frequency_id': 25, 'repetitions': 1})>
# 2019-09-12 14:52:01 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:52:01 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494675f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.1, 'frequency_id': 26, 'repetitions': 1})>
# 2019-09-12 14:52:01 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494675f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.1, 'frequency_id': 26, 'repetitions': 1})>
# 2019-09-12 14:55:35 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:55:35 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14995cbe0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.2, 'frequency_id': 27, 'repetitions': 1})>
# 2019-09-12 14:55:35 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14995cbe0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.2, 'frequency_id': 27, 'repetitions': 1})>
# 2019-09-12 14:59:08 :: Haswell->host: experiment logs fetched!
# 2019-09-12 14:59:08 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168be30f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.4, 'frequency_id': 28, 'repetitions': 1})>
# 2019-09-12 14:59:08 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168be30f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.4, 'frequency_id': 28, 'repetitions': 1})>
# 2019-09-12 15:02:41 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:02:41 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a0fa90 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.5, 'frequency_id': 29, 'repetitions': 1})>
# 2019-09-12 15:02:41 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a0fa90 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.5, 'frequency_id': 29, 'repetitions': 1})>
# 2019-09-12 15:06:14 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:06:14 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14998beb8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.6, 'frequency_id': 30, 'repetitions': 1})>
# 2019-09-12 15:06:14 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14998beb8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.6, 'frequency_id': 30, 'repetitions': 1})>
# 2019-09-12 15:09:48 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:09:48 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149467ba8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.7, 'frequency_id': 31, 'repetitions': 1})>
# 2019-09-12 15:09:48 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149467ba8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.7, 'frequency_id': 31, 'repetitions': 1})>
# 2019-09-12 15:13:21 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:13:21 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1498e7358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.8, 'frequency_id': 32, 'repetitions': 1})>
# 2019-09-12 15:13:21 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1498e7358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.8, 'frequency_id': 32, 'repetitions': 1})>
# 2019-09-12 15:16:54 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:16:54 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14994fc18 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.9, 'frequency_id': 33, 'repetitions': 1})>
# 2019-09-12 15:16:54 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14994fc18 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 3.9, 'frequency_id': 33, 'repetitions': 1})>
# 2019-09-12 15:20:28 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:20:28 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14939b5f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 34, 'repetitions': 1})>
# 2019-09-12 15:20:28 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14939b5f8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.0, 'frequency_id': 34, 'repetitions': 1})>
# 2019-09-12 15:24:01 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:24:01 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149487d30 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.1, 'frequency_id': 35, 'repetitions': 1})>
# 2019-09-12 15:24:01 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149487d30 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.1, 'frequency_id': 35, 'repetitions': 1})>
# 2019-09-12 15:27:34 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:27:34 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14995cef0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.2, 'frequency_id': 36, 'repetitions': 1})>
# 2019-09-12 15:27:34 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14995cef0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.2, 'frequency_id': 36, 'repetitions': 1})>
# 2019-09-12 15:31:08 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:31:08 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494875c0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.3, 'frequency_id': 37, 'repetitions': 1})>
# 2019-09-12 15:31:08 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494875c0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.3, 'frequency_id': 37, 'repetitions': 1})>
# 2019-09-12 15:34:41 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:34:41 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168bf83c8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.4, 'frequency_id': 38, 'repetitions': 1})>
# 2019-09-12 15:34:41 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168bf83c8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.4, 'frequency_id': 38, 'repetitions': 1})>
# 2019-09-12 15:38:15 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:38:15 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a91400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.5, 'frequency_id': 39, 'repetitions': 1})>
# 2019-09-12 15:38:15 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a91400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.5, 'frequency_id': 39, 'repetitions': 1})>
# 2019-09-12 15:41:48 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:41:48 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168af27f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.7, 'frequency_id': 40, 'repetitions': 1})>
# 2019-09-12 15:41:48 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168af27f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.7, 'frequency_id': 40, 'repetitions': 1})>
# 2019-09-12 15:45:21 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:45:21 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149944320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.8, 'frequency_id': 41, 'repetitions': 1})>
# 2019-09-12 15:45:21 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149944320 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.8, 'frequency_id': 41, 'repetitions': 1})>
# 2019-09-12 15:48:55 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:48:55 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b7e9b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.9, 'frequency_id': 42, 'repetitions': 1})>
# 2019-09-12 15:48:55 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b7e9b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 4.9, 'frequency_id': 42, 'repetitions': 1})>
# 2019-09-12 15:52:28 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:52:28 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168bf14e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.0, 'frequency_id': 43, 'repetitions': 1})>
# 2019-09-12 15:52:28 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168bf14e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.0, 'frequency_id': 43, 'repetitions': 1})>
# 2019-09-12 15:56:02 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:56:02 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b5eb38 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.1, 'frequency_id': 44, 'repetitions': 1})>
# 2019-09-12 15:56:02 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b5eb38 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.1, 'frequency_id': 44, 'repetitions': 1})>
# 2019-09-12 15:59:35 :: Haswell->host: experiment logs fetched!
# 2019-09-12 15:59:35 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14994f048 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.2, 'frequency_id': 45, 'repetitions': 1})>
# 2019-09-12 15:59:35 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14994f048 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.2, 'frequency_id': 45, 'repetitions': 1})>
# 2019-09-12 16:03:08 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:03:08 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149ab3550 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.3, 'frequency_id': 46, 'repetitions': 1})>
# 2019-09-12 16:03:08 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149ab3550 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.3, 'frequency_id': 46, 'repetitions': 1})>
# 2019-09-12 16:06:42 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:06:42 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149993f98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.4, 'frequency_id': 47, 'repetitions': 1})>
# 2019-09-12 16:06:42 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149993f98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.4, 'frequency_id': 47, 'repetitions': 1})>
# 2019-09-12 16:10:15 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:10:15 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14996bf60 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.6, 'frequency_id': 48, 'repetitions': 1})>
# 2019-09-12 16:10:15 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14996bf60 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.6, 'frequency_id': 48, 'repetitions': 1})>
# 2019-09-12 16:13:48 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:13:49 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14936a940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.7, 'frequency_id': 49, 'repetitions': 1})>
# 2019-09-12 16:13:49 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14936a940 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.7, 'frequency_id': 49, 'repetitions': 1})>
# 2019-09-12 16:17:22 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:17:22 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168bf8908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.8, 'frequency_id': 50, 'repetitions': 1})>
# 2019-09-12 16:17:22 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168bf8908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.8, 'frequency_id': 50, 'repetitions': 1})>
# 2019-09-12 16:20:55 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:20:55 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149944470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.9, 'frequency_id': 51, 'repetitions': 1})>
# 2019-09-12 16:20:55 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149944470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 5.9, 'frequency_id': 51, 'repetitions': 1})>
# 2019-09-12 16:24:28 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:24:28 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b507b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.0, 'frequency_id': 52, 'repetitions': 1})>
# 2019-09-12 16:24:28 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b507b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.0, 'frequency_id': 52, 'repetitions': 1})>
# 2019-09-12 16:28:02 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:28:02 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b44048 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.1, 'frequency_id': 53, 'repetitions': 1})>
# 2019-09-12 16:28:02 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b44048 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.1, 'frequency_id': 53, 'repetitions': 1})>
# 2019-09-12 16:31:35 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:31:35 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494e1080 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.2, 'frequency_id': 54, 'repetitions': 1})>
# 2019-09-12 16:31:35 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494e1080 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.2, 'frequency_id': 54, 'repetitions': 1})>
# 2019-09-12 16:35:08 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:35:08 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a06198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.4, 'frequency_id': 55, 'repetitions': 1})>
# 2019-09-12 16:35:08 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a06198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.4, 'frequency_id': 55, 'repetitions': 1})>
# 2019-09-12 16:38:42 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:38:42 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b91ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.5, 'frequency_id': 56, 'repetitions': 1})>
# 2019-09-12 16:38:42 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b91ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.5, 'frequency_id': 56, 'repetitions': 1})>
# 2019-09-12 16:42:15 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:42:15 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149937b00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.6, 'frequency_id': 57, 'repetitions': 1})>
# 2019-09-12 16:42:15 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149937b00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.6, 'frequency_id': 57, 'repetitions': 1})>
# 2019-09-12 16:45:49 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:45:49 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1493878d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.8, 'frequency_id': 58, 'repetitions': 1})>
# 2019-09-12 16:45:49 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1493878d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.8, 'frequency_id': 58, 'repetitions': 1})>
# 2019-09-12 16:49:22 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:49:22 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14935df28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.9, 'frequency_id': 59, 'repetitions': 1})>
# 2019-09-12 16:49:22 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14935df28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 6.9, 'frequency_id': 59, 'repetitions': 1})>
# 2019-09-12 16:52:56 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:52:56 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149993eb8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.0, 'frequency_id': 60, 'repetitions': 1})>
# 2019-09-12 16:52:56 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149993eb8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.0, 'frequency_id': 60, 'repetitions': 1})>
# 2019-09-12 16:56:29 :: Haswell->host: experiment logs fetched!
# 2019-09-12 16:56:29 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494876d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.1, 'frequency_id': 61, 'repetitions': 1})>
# 2019-09-12 16:56:29 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494876d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.1, 'frequency_id': 61, 'repetitions': 1})>
# 2019-09-12 17:00:02 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:00:02 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14944df98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.2, 'frequency_id': 62, 'repetitions': 1})>
# 2019-09-12 17:00:02 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14944df98 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.2, 'frequency_id': 62, 'repetitions': 1})>
# 2019-09-12 17:03:36 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:03:36 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14998b748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.4, 'frequency_id': 63, 'repetitions': 1})>
# 2019-09-12 17:03:36 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14998b748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.4, 'frequency_id': 63, 'repetitions': 1})>
# 2019-09-12 17:07:09 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:07:10 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b9f8d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.5, 'frequency_id': 64, 'repetitions': 1})>
# 2019-09-12 17:07:10 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b9f8d0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.5, 'frequency_id': 64, 'repetitions': 1})>
# 2019-09-12 17:10:43 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:10:43 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149b2a7f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.6, 'frequency_id': 65, 'repetitions': 1})>
# 2019-09-12 17:10:43 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149b2a7f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.6, 'frequency_id': 65, 'repetitions': 1})>
# 2019-09-12 17:14:16 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:14:16 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14940ca20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.7, 'frequency_id': 66, 'repetitions': 1})>
# 2019-09-12 17:14:16 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14940ca20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.7, 'frequency_id': 66, 'repetitions': 1})>
# 2019-09-12 17:17:50 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:17:50 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149ad79b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.8, 'frequency_id': 67, 'repetitions': 1})>
# 2019-09-12 17:17:50 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149ad79b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.8, 'frequency_id': 67, 'repetitions': 1})>
# 2019-09-12 17:21:23 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:21:23 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168c047f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.9, 'frequency_id': 68, 'repetitions': 1})>
# 2019-09-12 17:21:23 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168c047f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 7.9, 'frequency_id': 68, 'repetitions': 1})>
# 2019-09-12 17:24:56 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:24:56 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168ad3f60 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.1, 'frequency_id': 69, 'repetitions': 1})>
# 2019-09-12 17:24:56 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168ad3f60 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.1, 'frequency_id': 69, 'repetitions': 1})>
# 2019-09-12 17:28:29 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:28:30 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b36f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.2, 'frequency_id': 70, 'repetitions': 1})>
# 2019-09-12 17:28:30 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b36f28 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.2, 'frequency_id': 70, 'repetitions': 1})>
# 2019-09-12 17:32:03 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:32:03 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a5d358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.3, 'frequency_id': 71, 'repetitions': 1})>
# 2019-09-12 17:32:03 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a5d358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.3, 'frequency_id': 71, 'repetitions': 1})>
# 2019-09-12 17:35:36 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:35:36 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1495756d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.5, 'frequency_id': 72, 'repetitions': 1})>
# 2019-09-12 17:35:36 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1495756d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.5, 'frequency_id': 72, 'repetitions': 1})>
# 2019-09-12 17:39:09 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:39:09 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b7e278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.6, 'frequency_id': 73, 'repetitions': 1})>
# 2019-09-12 17:39:09 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b7e278 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.6, 'frequency_id': 73, 'repetitions': 1})>
# 2019-09-12 17:42:43 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:42:43 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168a68198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.8, 'frequency_id': 74, 'repetitions': 1})>
# 2019-09-12 17:42:43 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168a68198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.8, 'frequency_id': 74, 'repetitions': 1})>
# 2019-09-12 17:46:16 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:46:16 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168aba6d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.9, 'frequency_id': 75, 'repetitions': 1})>
# 2019-09-12 17:46:16 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168aba6d8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 8.9, 'frequency_id': 75, 'repetitions': 1})>
# 2019-09-12 17:49:49 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:49:49 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149518e48 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.1, 'frequency_id': 76, 'repetitions': 1})>
# 2019-09-12 17:49:49 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149518e48 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.1, 'frequency_id': 76, 'repetitions': 1})>
# 2019-09-12 17:53:22 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:53:22 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1498d6dd8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.3, 'frequency_id': 77, 'repetitions': 1})>
# 2019-09-12 17:53:22 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1498d6dd8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.3, 'frequency_id': 77, 'repetitions': 1})>
# 2019-09-12 17:56:56 :: Haswell->host: experiment logs fetched!
# 2019-09-12 17:56:56 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a1fcc0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.4, 'frequency_id': 78, 'repetitions': 1})>
# 2019-09-12 17:56:56 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a1fcc0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.4, 'frequency_id': 78, 'repetitions': 1})>
# 2019-09-12 18:00:29 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:00:29 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168a58cc0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.6, 'frequency_id': 79, 'repetitions': 1})>
# 2019-09-12 18:00:29 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168a58cc0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.6, 'frequency_id': 79, 'repetitions': 1})>
# 2019-09-12 18:04:02 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:04:02 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a0f358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.8, 'frequency_id': 80, 'repetitions': 1})>
# 2019-09-12 18:04:02 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a0f358 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 9.8, 'frequency_id': 80, 'repetitions': 1})>
# 2019-09-12 18:07:36 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:07:36 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168ae7a90 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 81, 'repetitions': 1})>
# 2019-09-12 18:07:36 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168ae7a90 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.0, 'frequency_id': 81, 'repetitions': 1})>
# 2019-09-12 18:11:09 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:11:09 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b0d2b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.1, 'frequency_id': 82, 'repetitions': 1})>
# 2019-09-12 18:11:09 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b0d2b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.1, 'frequency_id': 82, 'repetitions': 1})>
# 2019-09-12 18:14:42 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:14:42 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b25208 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.2, 'frequency_id': 83, 'repetitions': 1})>
# 2019-09-12 18:14:42 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b25208 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.2, 'frequency_id': 83, 'repetitions': 1})>
# 2019-09-12 18:18:16 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:18:16 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1495bd908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.3, 'frequency_id': 84, 'repetitions': 1})>
# 2019-09-12 18:18:16 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1495bd908 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.3, 'frequency_id': 84, 'repetitions': 1})>
# 2019-09-12 18:21:49 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:21:49 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149b1db00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.4, 'frequency_id': 85, 'repetitions': 1})>
# 2019-09-12 18:21:49 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149b1db00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.4, 'frequency_id': 85, 'repetitions': 1})>
# 2019-09-12 18:25:23 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:25:23 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149919b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.5, 'frequency_id': 86, 'repetitions': 1})>
# 2019-09-12 18:25:23 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149919b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.5, 'frequency_id': 86, 'repetitions': 1})>
# 2019-09-12 18:28:56 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:28:56 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1499e3b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.6, 'frequency_id': 87, 'repetitions': 1})>
# 2019-09-12 18:28:56 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1499e3b70 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.6, 'frequency_id': 87, 'repetitions': 1})>
# 2019-09-12 18:32:29 :: Haswell->host: experiment logs fetched!
# 2019-09-12 18:32:29 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168bc32e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.8, 'frequency_id': 88, 'repetitions': 1})>
# 2019-09-12 18:32:29 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168bc32e8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 10.8, 'frequency_id': 88, 'repetitions': 1})>
# ...
# 2019-09-12 22:16:32 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:16:32 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168c1fd68 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 33.3, 'frequency_id': 151, 'repetitions': 1})>
# 2019-09-12 22:16:32 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168c1fd68 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 33.3, 'frequency_id': 151, 'repetitions': 1})>
# 2019-09-12 22:20:05 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:20:05 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494273c8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 34.5, 'frequency_id': 152, 'repetitions': 1})>
# 2019-09-12 22:20:05 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494273c8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 34.5, 'frequency_id': 152, 'repetitions': 1})>
# 2019-09-12 22:23:39 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:23:39 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149605ba8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 35.7, 'frequency_id': 153, 'repetitions': 1})>
# 2019-09-12 22:23:39 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149605ba8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 35.7, 'frequency_id': 153, 'repetitions': 1})>
# 2019-09-12 22:27:12 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:27:12 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168a58828 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 37.0, 'frequency_id': 154, 'repetitions': 1})>
# 2019-09-12 22:27:12 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168a58828 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 37.0, 'frequency_id': 154, 'repetitions': 1})>
# 2019-09-12 22:30:46 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:30:46 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149993588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 38.5, 'frequency_id': 155, 'repetitions': 1})>
# 2019-09-12 22:30:46 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149993588 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 38.5, 'frequency_id': 155, 'repetitions': 1})>
# 2019-09-12 22:34:19 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:34:19 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149a1f160 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 156, 'repetitions': 1})>
# 2019-09-12 22:34:19 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149a1f160 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 40.0, 'frequency_id': 156, 'repetitions': 1})>
# 2019-09-12 22:37:53 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:37:53 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168a91470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 41.7, 'frequency_id': 157, 'repetitions': 1})>
# 2019-09-12 22:37:53 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168a91470 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 41.7, 'frequency_id': 157, 'repetitions': 1})>
# 2019-09-12 22:41:26 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:41:26 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494e1b38 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 43.5, 'frequency_id': 158, 'repetitions': 1})>
# 2019-09-12 22:41:26 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494e1b38 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 43.5, 'frequency_id': 158, 'repetitions': 1})>
# 2019-09-12 22:45:00 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:45:00 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168a46898 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 45.5, 'frequency_id': 159, 'repetitions': 1})>
# 2019-09-12 22:45:00 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168a46898 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 45.5, 'frequency_id': 159, 'repetitions': 1})>
# 2019-09-12 22:48:33 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:48:33 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b44198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 47.6, 'frequency_id': 160, 'repetitions': 1})>
# 2019-09-12 22:48:33 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b44198 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 47.6, 'frequency_id': 160, 'repetitions': 1})>
# 2019-09-12 22:52:07 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:52:07 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168a91748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 161, 'repetitions': 1})>
# 2019-09-12 22:52:07 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168a91748 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 50.0, 'frequency_id': 161, 'repetitions': 1})>
# 2019-09-12 22:55:40 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:55:40 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494fdd68 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 52.6, 'frequency_id': 162, 'repetitions': 1})>
# 2019-09-12 22:55:40 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494fdd68 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 52.6, 'frequency_id': 162, 'repetitions': 1})>
# 2019-09-12 22:59:13 :: Haswell->host: experiment logs fetched!
# 2019-09-12 22:59:13 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149400400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 55.6, 'frequency_id': 163, 'repetitions': 1})>
# 2019-09-12 22:59:13 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149400400 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 55.6, 'frequency_id': 163, 'repetitions': 1})>
# 2019-09-12 23:02:47 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:02:47 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494597b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 58.8, 'frequency_id': 164, 'repetitions': 1})>
# 2019-09-12 23:02:47 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494597b8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 58.8, 'frequency_id': 164, 'repetitions': 1})>
# 2019-09-12 23:06:20 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:06:20 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168aa02b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 62.5, 'frequency_id': 165, 'repetitions': 1})>
# 2019-09-12 23:06:20 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168aa02b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 62.5, 'frequency_id': 165, 'repetitions': 1})>
# 2019-09-12 23:09:53 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:09:53 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd149993ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 66.7, 'frequency_id': 166, 'repetitions': 1})>
# 2019-09-12 23:09:53 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd149993ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 66.7, 'frequency_id': 166, 'repetitions': 1})>
# 2019-09-12 23:13:27 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:13:27 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd148364be0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 71.4, 'frequency_id': 167, 'repetitions': 1})>
# 2019-09-12 23:13:27 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd148364be0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 71.4, 'frequency_id': 167, 'repetitions': 1})>
# 2019-09-12 23:17:00 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:17:00 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14955a9b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 76.9, 'frequency_id': 168, 'repetitions': 1})>
# 2019-09-12 23:17:00 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14955a9b0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 76.9, 'frequency_id': 168, 'repetitions': 1})>
# 2019-09-12 23:20:33 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:20:33 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168be3da0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 83.3, 'frequency_id': 169, 'repetitions': 1})>
# 2019-09-12 23:20:33 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168be3da0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 83.3, 'frequency_id': 169, 'repetitions': 1})>
# 2019-09-12 23:24:07 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:24:07 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1499a2ba8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 90.9, 'frequency_id': 170, 'repetitions': 1})>
# 2019-09-12 23:24:07 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1499a2ba8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 90.9, 'frequency_id': 170, 'repetitions': 1})>
# 2019-09-12 23:27:40 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:27:40 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168b50ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 171, 'repetitions': 1})>
# 2019-09-12 23:27:40 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168b50ac8 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 100.0, 'frequency_id': 171, 'repetitions': 1})>
# 2019-09-12 23:31:13 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:31:13 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168abab00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 111.1, 'frequency_id': 172, 'repetitions': 1})>
# 2019-09-12 23:31:13 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168abab00 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 111.1, 'frequency_id': 172, 'repetitions': 1})>
# 2019-09-12 23:34:47 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:34:47 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1494ceda0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 173, 'repetitions': 1})>
# 2019-09-12 23:34:47 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1494ceda0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 125.0, 'frequency_id': 173, 'repetitions': 1})>
# 2019-09-12 23:38:20 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:38:20 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168bc3d30 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 142.9, 'frequency_id': 174, 'repetitions': 1})>
# 2019-09-12 23:38:20 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168bc3d30 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 142.9, 'frequency_id': 174, 'repetitions': 1})>
# 2019-09-12 23:41:53 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:41:53 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1493ad4e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 166.7, 'frequency_id': 175, 'repetitions': 1})>
# 2019-09-12 23:41:53 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1493ad4e0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 166.7, 'frequency_id': 175, 'repetitions': 1})>
# 2019-09-12 23:45:27 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:45:27 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14944da20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 176, 'repetitions': 1})>
# 2019-09-12 23:45:27 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14944da20 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 200.0, 'frequency_id': 176, 'repetitions': 1})>
# 2019-09-12 23:49:00 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:49:00 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd1499f4668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 177, 'repetitions': 1})>
# 2019-09-12 23:49:00 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd1499f4668 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 250.0, 'frequency_id': 177, 'repetitions': 1})>
# 2019-09-12 23:52:33 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:52:33 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd168a68240 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 333.3, 'frequency_id': 178, 'repetitions': 1})>
# 2019-09-12 23:52:33 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd168a68240 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 333.3, 'frequency_id': 178, 'repetitions': 1})>
# 2019-09-12 23:56:07 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:56:07 :: executing in env: 'Haswell', resume: False, reps: [0], run: <Run at 0x7fd14994f7f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 179, 'repetitions': 1})>
# 2019-09-12 23:56:07 :: executing in env: Haswell, rep: 0, estimated duration: 120s, run: <Run at 0x7fd14994f7f0 (digested, config={'phase': 'sweepHaswell', 'length_seconds': 120, 'frequency': 500.0, 'frequency_id': 179, 'repetitions': 1})>
# 2019-09-12 23:59:40 :: Haswell->host: experiment logs fetched!
# 2019-09-12 23:59:40 :: Haswell->host: cleaning up
# 2019-09-13 00:00:43 :: Haswell->host: successfully deleted remote data directory
# 2019-09-13 00:00:43 :: Haswell->host: disconnected

# %% [markdown]
# ### Thermal performance
# Status: executed performance, executed interference (SHORT only)

# %%
for _experiment in ["thermal-cc_performance", "thermal-cc_interference"]:
    for _platform, _phase_mapping in phases_thermal.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0], "logs:", _logs[0], sep=" ")

# %% [markdown]
# - Execution (Performance)

# %%
SHORT = False

for experiment_thermal_path in [ 
    "data/thermal-cc_performance/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e

# %% [markdown]
# - Execution (Interference)

# %%
SHORT = False

for experiment_thermal_path in [ 
    "data/thermal-cc_interference/_experiment.pickle"
]:
    try:
        path_to_serialised_experiment = PATH.Path(experiment_thermal_path)
        experiment_thermal = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
        try:
            experiment_thermal.logger.parent.handlers[0].setLevel(20)
        except:
            pass
        if UPDATE:
            experiment_thermal.config.experiment_exists_action = "update"
            experiment_thermal._update_mode = True
        for env in environments_to_execute:
            experiment_thermal.execute_in_environment(
                env,
                phases_thermal[env]['short' if SHORT else 'normal'],
                resume=UPDATE and RESUME
            )
        experiment_thermal.write()
    except Exception as e:
        print("ERROR - ", experiment_thermal_path, str(e))
        raise e
