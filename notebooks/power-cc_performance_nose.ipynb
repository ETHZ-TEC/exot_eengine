# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM
import sklearn.ensemble             # RandomForestClassifier, VotingClassifier

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Tensorflow not available - excluding packets relying on it!

# %% [markdown]
# __Notebook config__

# %%
NB_EXPERIMENT = "power-cc_performance_nose"

environments_to_execute = [
    "Haswell",
    "Sandy"
]

phases = {
    "Haswell": {
        "normal": ["train", "eval"],
    },
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = experiment._execution_status

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    for phase in phases[env].items():
         experiment.execute_in_environment(env, phase, resume=False)
experiment.write()

# %% [markdown]
# # Demo
# With the following cell you can visualise a single run from either platform and also have a look on the data histogram, to check whether the quantisation thresholds are defined correctly.

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)

DEMO_PHASE = "train"
DEMO_ID = 0
DEMO_SANDY = True #"" in DEMO_PHASE

ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io=(
        {
            "env": "Sandy",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
        if DEMO_SANDY
        else {
            "env": "Haswell",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
    ),
)

demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream()
    plotter.plot_rdpstream(end=10)
    plotter.plot_slicing()
    plotter.plot_symstream()

quantisation_thresholds = experiment.environments_apps_zones[
    ingest_args['io']['env']]['snk']['zone_config'].power_thresholds[
    demo_run.i_rdpstream.columns[-1].split(':')[-2]]

plt.figure()
plt.hist(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'], bins='auto')
plt.xticks(np.arange(0, max(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'])+1, 1.0))
for threshold in quantisation_thresholds[1:]:
    plt.axvline(x=threshold, color='red', linestyle='--')
plt.xlim([0,70])
# Out:
# 2020-03-30 18:43:41 :: unpicked an experiment instance <PerformanceExperiment at 0x7f09b9092a58 with PowerCC channel, configured>
# 2020-03-30 18:43:41 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:43:41 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:43:41 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:43:42 :: bootstrapped layer 'src' with SourcePassthrough
# 2020-03-30 18:43:42 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:43:42 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:43:42 :: bootstrapped layer 'io' with TimeValue
# (0, 70)

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# ## Analyse
#
# 1. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)
# Out:
# 2020-03-30 18:44:44 :: unpicked an experiment instance <PerformanceExperiment at 0x7f0994e1f7b8 with PowerCC channel, configured>
# 2020-03-30 18:44:45 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:44:45 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:44:45 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:44:45 :: bootstrapped layer 'src' with SourcePassthrough
# 2020-03-30 18:44:45 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:44:45 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:44:45 :: bootstrapped layer 'io' with TimeValue

# %% [markdown]
# 2. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "normal"

analysis_args = {
    "Sandy": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(),
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)]
        },
    ),
    "Haswell": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), 
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        },
    ),
}

phase_mappings = {
    "Haswell": {
        "normal": ["train", "eval"],
    },
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %% [markdown]
# 3. Calculate the performance metrics

# %%
del experiment.performance_metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        use_levensthein=True,
        **analysis_args[env],
    )
# Out:
# 2020-03-30 18:44:56 :: analysing performance for phases: train -> eval, environments ['Haswell']
# 2020-03-30 19:10:12 :: analysing performance for phases: train -> eval, environments ['Sandy']
# 2020-03-30 19:16:52 :: Analysing run pair for phase mapping: ('train', 'eval'), idx: 30, env: Sandy, rep: 1, failed! Error: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required by StandardScaler..

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#    phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  train                  Haswell       1.0            1           0
# 1   eval        train     Haswell       1.0            1           0
# 2  train                  Haswell       1.0            1           1
# 3   eval        train     Haswell       1.0            1           1
# 4  train                  Haswell       1.0            1           2
#
#    bit_error  symbol_error                                            matcher  \
# 0     0.0000        0.0000  <Matcher quantity='power', method='msr', value...
# 1     0.0000        0.0000  <Matcher quantity='power', method='msr', value...
# 2     0.0000        0.0000  <Matcher quantity='power', method='msr', value...
# 3     0.0002        0.0002  <Matcher quantity='power', method='msr', value...
# 4     0.0000        0.0000  <Matcher quantity='power', method='msr', value...
#
#     variable
# 0  power_msr
# 1  power_msr
# 2  power_msr
# 3  power_msr
# 4  power_msr

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#      phase trained_with environment  bit_rate  symbol_rate  \
# 0     eval        train     Haswell       1.0            1
# 1     eval        train     Haswell      10.0           10
# 2     eval        train     Haswell      20.0           20
# 3     eval        train     Haswell      30.0           30
# 4     eval        train     Haswell      40.0           40
# 5     eval        train     Haswell      50.0           50
# 6     eval        train     Haswell      60.0           60
# 7     eval        train     Haswell      70.0           70
# 8     eval        train     Haswell      80.0           80
# 9     eval        train     Haswell      90.0           90
# 10    eval        train     Haswell     100.0          100
# 11    eval        train     Haswell     110.0          110
# 12    eval        train     Haswell     120.0          120
# 13    eval        train     Haswell     130.0          130
# 14    eval        train     Haswell     140.0          140
# 15    eval        train     Haswell     150.0          150
# 16    eval        train     Haswell     160.0          160
# 17    eval        train     Haswell     170.0          170
# 18    eval        train     Haswell     180.0          180
# 19    eval        train     Haswell     190.0          190
# 20    eval        train     Haswell     200.0          200
# 21    eval        train     Haswell     210.0          210
# 22    eval        train     Haswell     220.0          220
# 23    eval        train     Haswell     230.0          230
# 24    eval        train     Haswell     240.0          240
# 25    eval        train     Haswell     250.0          250
# 26    eval        train     Haswell     260.0          260
# 27    eval        train     Haswell     270.0          270
# 28    eval        train     Haswell     280.0          280
# 29    eval        train     Haswell     290.0          290
# ..     ...          ...         ...       ...          ...
# 374  train                    Sandy     710.0          710
# 375  train                    Sandy     720.0          720
# 376  train                    Sandy     730.0          730
# 377  train                    Sandy     740.0          740
# 378  train                    Sandy     750.0          750
# 379  train                    Sandy     760.0          760
# 380  train                    Sandy     770.0          770
# 381  train                    Sandy     780.0          780
# 382  train                    Sandy     790.0          790
# 383  train                    Sandy     800.0          800
# 384  train                    Sandy     810.0          810
# 385  train                    Sandy     820.0          820
# 386  train                    Sandy     830.0          830
# 387  train                    Sandy     840.0          840
# 388  train                    Sandy     850.0          850
# 389  train                    Sandy     860.0          860
# 390  train                    Sandy     870.0          870
# 391  train                    Sandy     880.0          880
# 392  train                    Sandy     890.0          890
# 393  train                    Sandy     900.0          900
# 394  train                    Sandy     910.0          910
# 395  train                    Sandy     920.0          920
# 396  train                    Sandy     930.0          930
# 397  train                    Sandy     940.0          940
# 398  train                    Sandy     950.0          950
# 399  train                    Sandy     960.0          960
# 400  train                    Sandy     970.0          970
# 401  train                    Sandy     980.0          980
# 402  train                    Sandy     990.0          990
# 403  train                    Sandy    1000.0         1000
#
#                                                matcher   variable  bit_error  \
# 0    <Matcher quantity='power', method='msr', value...  power_msr   0.000067
# 1    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 2    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 3    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 4    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 5    <Matcher quantity='power', method='msr', value...  power_msr   0.000133
# 6    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 7    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 8    <Matcher quantity='power', method='msr', value...  power_msr   0.000133
# 9    <Matcher quantity='power', method='msr', value...  power_msr   0.000267
# 10   <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 11   <Matcher quantity='power', method='msr', value...  power_msr   0.000600
# 12   <Matcher quantity='power', method='msr', value...  power_msr   0.000667
# 13   <Matcher quantity='power', method='msr', value...  power_msr   0.000467
# 14   <Matcher quantity='power', method='msr', value...  power_msr   0.000267
# 15   <Matcher quantity='power', method='msr', value...  power_msr   0.000600
# 16   <Matcher quantity='power', method='msr', value...  power_msr   0.000933
# 17   <Matcher quantity='power', method='msr', value...  power_msr   0.001267
# 18   <Matcher quantity='power', method='msr', value...  power_msr   0.001800
# 19   <Matcher quantity='power', method='msr', value...  power_msr   0.001400
# 20   <Matcher quantity='power', method='msr', value...  power_msr   0.003267
# 21   <Matcher quantity='power', method='msr', value...  power_msr   0.009733
# 22   <Matcher quantity='power', method='msr', value...  power_msr   0.020067
# 23   <Matcher quantity='power', method='msr', value...  power_msr   0.033133
# 24   <Matcher quantity='power', method='msr', value...  power_msr   0.051400
# 25   <Matcher quantity='power', method='msr', value...  power_msr   0.003467
# 26   <Matcher quantity='power', method='msr', value...  power_msr   0.013867
# 27   <Matcher quantity='power', method='msr', value...  power_msr   0.019267
# 28   <Matcher quantity='power', method='msr', value...  power_msr   0.019200
# 29   <Matcher quantity='power', method='msr', value...  power_msr   0.033267
# ..                                                 ...        ...        ...
# 374  <Matcher quantity='power', method='msr', value...  power_msr   0.404996
# 375  <Matcher quantity='power', method='msr', value...  power_msr   0.166444
# 376  <Matcher quantity='power', method='msr', value...  power_msr   0.205367
# 377  <Matcher quantity='power', method='msr', value...  power_msr   0.772743
# 378  <Matcher quantity='power', method='msr', value...  power_msr   0.252889
# 379  <Matcher quantity='power', method='msr', value...  power_msr   0.524529
# 380  <Matcher quantity='power', method='msr', value...  power_msr   0.132000
# 381  <Matcher quantity='power', method='msr', value...  power_msr   0.384054
# 382  <Matcher quantity='power', method='msr', value...  power_msr   0.246444
# 383  <Matcher quantity='power', method='msr', value...  power_msr   0.285668
# 384  <Matcher quantity='power', method='msr', value...  power_msr   0.134000
# 385  <Matcher quantity='power', method='msr', value...  power_msr   0.454364
# 386  <Matcher quantity='power', method='msr', value...  power_msr   0.374463
# 387  <Matcher quantity='power', method='msr', value...  power_msr   0.476399
# 388  <Matcher quantity='power', method='msr', value...  power_msr   0.154000
# 389  <Matcher quantity='power', method='msr', value...  power_msr   0.522477
# 390  <Matcher quantity='power', method='msr', value...  power_msr   0.149778
# 391  <Matcher quantity='power', method='msr', value...  power_msr   0.434828
# 392  <Matcher quantity='power', method='msr', value...  power_msr   0.273778
# 393  <Matcher quantity='power', method='msr', value...  power_msr   0.187778
# 394  <Matcher quantity='power', method='msr', value...  power_msr   0.310509
# 395  <Matcher quantity='power', method='msr', value...  power_msr   0.305778
# 396  <Matcher quantity='power', method='msr', value...  power_msr   0.423298
# 397  <Matcher quantity='power', method='msr', value...  power_msr   0.252667
# 398  <Matcher quantity='power', method='msr', value...  power_msr   0.253333
# 399  <Matcher quantity='power', method='msr', value...  power_msr   0.392330
# 400  <Matcher quantity='power', method='msr', value...  power_msr   0.145333
# 401  <Matcher quantity='power', method='msr', value...  power_msr   0.486232
# 402  <Matcher quantity='power', method='msr', value...  power_msr   0.107111
# 403  <Matcher quantity='power', method='msr', value...  power_msr   0.231111
#
#      symbol_error
# 0        0.000067
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# 5        0.000133
# 6        0.000000
# 7        0.000000
# 8        0.000133
# 9        0.000267
# 10       0.000000
# 11       0.000600
# 12       0.000667
# 13       0.000467
# 14       0.000267
# 15       0.000600
# 16       0.000933
# 17       0.001267
# 18       0.001800
# 19       0.001400
# 20       0.003267
# 21       0.009733
# 22       0.020067
# 23       0.033133
# 24       0.051400
# 25       0.003467
# 26       0.013867
# 27       0.019267
# 28       0.019200
# 29       0.033267
# ..            ...
# 374      0.404996
# 375      0.166444
# 376      0.205367
# 377      0.772743
# 378      0.252889
# 379      0.524529
# 380      0.132000
# 381      0.384054
# 382      0.246444
# 383      0.285668
# 384      0.134000
# 385      0.454364
# 386      0.374463
# 387      0.476399
# 388      0.154000
# 389      0.522477
# 390      0.149778
# 391      0.434828
# 392      0.273778
# 393      0.187778
# 394      0.310509
# 395      0.305778
# 396      0.423298
# 397      0.252667
# 398      0.253333
# 399      0.392330
# 400      0.145333
# 401      0.486232
# 402      0.107111
# 403      0.231111
#
# [404 rows x 9 columns]

# %% [markdown]
# 4. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 5. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = ("interference" if "interference" in NB_EXPERIMENT else "baseline")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        experiment.path.joinpath("performance_{}_{}_{}.dat".format(PREFIX, NB_EXPERIMENT.split('_')[-1], 
                                                             env)),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 6. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
