# %%
# %pylab inline

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *

# %% [markdown]
# Parameters

# %%
NB_EXPERIMENT_TYPES = ["performance", "interference"]
NB_CHANNELS = ["ff", "fp", "fr"]
NB_CONFIGS = ["flush+flush", "flush+prefetch", "flush+reload"]

# %% [markdown]
# #### Notebook config

# %%
# Names to configure
NB_EXPERIMENT_TYPE = "interference"
NB_CONFIG = "flush+prefetch"

# Generated names
NB_EXPERIMENT = f"{NB_CONFIG}-cc_{NB_EXPERIMENT_TYPE}"
NB_CHANNEL = "f" + NB_CONFIG.split("+")[-1][0]

# %%
print("NB_CHANNEL         ", NB_CHANNEL)
print("NB_EXPERIMENT_TYPE ", NB_EXPERIMENT_TYPE)
print("NB_CONFIG          ", NB_CONFIG)
print("NB_EXPERIMENT      ", NB_EXPERIMENT)

# %%
assert NB_EXPERIMENT_TYPE in NB_EXPERIMENT_TYPES
assert NB_CHANNEL in NB_CHANNELS
assert NB_CONFIG in NB_CONFIGS

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

environments_to_execute = [
    "ARMv8",
    "Haswell"
]

phases = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
raise Exception("Are you sure?")

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = getattr(experiment, "_execution_status", {})

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    experiment.execute_in_environment(env, phases[env]['short'], resume=False)
    experiment.execute_in_environment(env, phases[env]['normal'], resume=False)
experiment.write()

# %% [markdown]
# ## Analyse

# %% [markdown]
# 1. Define which class of experiments to analyse (short of normal length)

# %%
SHORT = False

# %% [markdown]
# 2. Check data collection status

# %%
for _experiment in [NB_EXPERIMENT]:
    for _platform, _phase_mapping in phases.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0].strip(), "logs:", _logs[0].strip(), sep=" ")
# Out:
# experiment: flush+prefetch-cc_interference platform: ARMv8 phase: trainShortARMv8 folders: 13 logs: 52
# experiment: flush+prefetch-cc_interference platform: ARMv8 phase: evalShortARMv8 folders: 13 logs: 52
# experiment: flush+prefetch-cc_interference platform: ARMv8 phase: trainARMv8 folders: 25 logs: 250
# experiment: flush+prefetch-cc_interference platform: ARMv8 phase: evalARMv8 folders: 25 logs: 250
# experiment: flush+prefetch-cc_interference platform: Haswell phase: trainShortHaswell folders: 9 logs: 36
# experiment: flush+prefetch-cc_interference platform: Haswell phase: evalShortHaswell folders: 9 logs: 36
# experiment: flush+prefetch-cc_interference platform: Haswell phase: trainHaswell folders: 80 logs: 800
# experiment: flush+prefetch-cc_interference platform: Haswell phase: evalHaswell folders: 80 logs: 800

# %% [markdown]
# 3. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
# Out:
# 2019-09-10 14:18:09 :: unpicked an experiment instance <PerformanceExperiment at 0x7fb696caa080 with Cache channel, configured>
# 2019-09-10 14:18:09 :: git commit of unpickled experiment repo '89c78965' does not match the commit in which the unpickling was performed '50fd78bb'

# %% [markdown]
# 4. Specify the demo run and visualise

# %%
DEMO_PHASE = "trainShortARMv8"
DEMO_ID = 0
DEMO_ARM = "ARM" in DEMO_PHASE

# %%
ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]}
    if DEMO_ARM
    else {},
    io={
        "env": "ARMv8" if DEMO_ARM else "Haswell",
        "rep": 0,
        "matcher": exot.util.wrangle.Matcher("cache", NB_CHANNEL, ["access_time"], list(range(64))),
    },
)

# %%
demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

# %%
with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream(dim_count=2)
    plotter.plot_rdpstream(end=5.0, dim_count=2)
    plotter.plot_slicing(dim_count=2)
    plotter.plot_eye_diagram()
    plotter.plot_symbol_space()
    plotter.plot_error()
    plotter.plot_timing()

# %% [markdown]
# 5. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "short" if SHORT else "normal"

analysis_args = {
    "ARMv8": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]},
        io={
            "matcher": exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            )
        },
    ),
    "Haswell": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={
            "matcher": exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            )
        },
    ),
}

phase_mappings = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}

# %% [markdown]
# _Calculate the performance metrics_

# %%
del experiment.performance_metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        **analysis_args[env],
    )
# Out:
# 2019-09-10 14:19:04 :: analysing performance for phases: trainARMv8 -> evalARMv8
# 2019-09-10 14:19:05 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:19:12 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:19:19 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:19:26 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:19:33 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:19:40 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:19:48 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:19:55 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:02 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:09 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:17 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:24 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:32 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:39 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:47 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:20:54 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:02 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:10 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:18 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:25 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:32 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:41 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:48 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:21:56 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:22:03 :: \_ analysing performance for env: ARMv8
# 2019-09-10 14:22:11 :: analysing performance for phases: trainHaswell -> evalHaswell
# 2019-09-10 14:22:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:22:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:22:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:22:37 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:22:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:22:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:23:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:23:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:23:19 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:23:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:23:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:23:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:23:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:24:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:24:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:24:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:24:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:24:44 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:24:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:25:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:25:12 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:25:21 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:25:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:25:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:25:52 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:26:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:26:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:26:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:26:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:26:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:27:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:27:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:27:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:27:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:27:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:28:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:28:19 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:28:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:28:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:28:59 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:29:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:29:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:29:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:30:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:30:16 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:30:31 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:30:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:31:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:31:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:31:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:31:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:32:12 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:32:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:32:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:33:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:33:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:33:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:34:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:34:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:34:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:34:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:35:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:35:31 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:35:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:36:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:36:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:36:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:37:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:37:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:37:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:38:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:38:16 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:38:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:39:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:39:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:39:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:40:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:40:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:40:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 14:41:02 :: \_ analysing performance for env: Haswell

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#         phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  trainARMv8                    ARMv8    6400.0          100           0
# 1   evalARMv8   trainARMv8       ARMv8    6400.0          100           0
# 2  trainARMv8                    ARMv8    6400.0          100           1
# 3   evalARMv8   trainARMv8       ARMv8    6400.0          100           1
# 4  trainARMv8                    ARMv8    6400.0          100           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.046875      0.541667  <Matcher quantity='cache', method='fp', values...
# 1   0.007516      0.481013  <Matcher quantity='cache', method='fp', values...
# 2   0.007161      0.458333  <Matcher quantity='cache', method='fp', values...
# 3   0.007516      0.481013  <Matcher quantity='cache', method='fp', values...
# 4   0.081380      0.666667  <Matcher quantity='cache', method='fp', values...
#
#    variable
# 0  cache_fp
# 1  cache_fp
# 2  cache_fp
# 3  cache_fp
# 4  cache_fp

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#             phase  trained_with environment   bit_rate  symbol_rate  \
# 0       evalARMv8    trainARMv8       ARMv8     6400.0          100
# 1       evalARMv8    trainARMv8       ARMv8    16000.0          250
# 2       evalARMv8    trainARMv8       ARMv8    32000.0          500
# 3       evalARMv8    trainARMv8       ARMv8    48000.0          750
# 4       evalARMv8    trainARMv8       ARMv8    64000.0         1000
# 5       evalARMv8    trainARMv8       ARMv8    80000.0         1250
# 6       evalARMv8    trainARMv8       ARMv8    96000.0         1500
# 7       evalARMv8    trainARMv8       ARMv8   112000.0         1750
# 8       evalARMv8    trainARMv8       ARMv8   128000.0         2000
# 9       evalARMv8    trainARMv8       ARMv8   144000.0         2250
# 10      evalARMv8    trainARMv8       ARMv8   160000.0         2500
# 11      evalARMv8    trainARMv8       ARMv8   176000.0         2750
# 12      evalARMv8    trainARMv8       ARMv8   192000.0         3000
# 13      evalARMv8    trainARMv8       ARMv8   208000.0         3250
# 14      evalARMv8    trainARMv8       ARMv8   224000.0         3500
# 15      evalARMv8    trainARMv8       ARMv8   240000.0         3750
# 16      evalARMv8    trainARMv8       ARMv8   256000.0         4000
# 17      evalARMv8    trainARMv8       ARMv8   272000.0         4250
# 18      evalARMv8    trainARMv8       ARMv8   288000.0         4500
# 19      evalARMv8    trainARMv8       ARMv8   304000.0         4750
# 20      evalARMv8    trainARMv8       ARMv8   320000.0         5000
# 21      evalARMv8    trainARMv8       ARMv8   336000.0         5250
# 22      evalARMv8    trainARMv8       ARMv8   352000.0         5500
# 23      evalARMv8    trainARMv8       ARMv8   368000.0         5750
# 24      evalARMv8    trainARMv8       ARMv8   384000.0         6000
# 25    evalHaswell  trainHaswell     Haswell     6400.0          100
# 26    evalHaswell  trainHaswell     Haswell    64000.0         1000
# 27    evalHaswell  trainHaswell     Haswell   128000.0         2000
# 28    evalHaswell  trainHaswell     Haswell   192000.0         3000
# 29    evalHaswell  trainHaswell     Haswell   256000.0         4000
# ..            ...           ...         ...        ...          ...
# 180  trainHaswell                   Haswell  3200000.0        50000
# 181  trainHaswell                   Haswell  3264000.0        51000
# 182  trainHaswell                   Haswell  3328000.0        52000
# 183  trainHaswell                   Haswell  3392000.0        53000
# 184  trainHaswell                   Haswell  3456000.0        54000
# 185  trainHaswell                   Haswell  3520000.0        55000
# 186  trainHaswell                   Haswell  3584000.0        56000
# 187  trainHaswell                   Haswell  3648000.0        57000
# 188  trainHaswell                   Haswell  3712000.0        58000
# 189  trainHaswell                   Haswell  3776000.0        59000
# 190  trainHaswell                   Haswell  3840000.0        60000
# 191  trainHaswell                   Haswell  3904000.0        61000
# 192  trainHaswell                   Haswell  3968000.0        62000
# 193  trainHaswell                   Haswell  4032000.0        63000
# 194  trainHaswell                   Haswell  4096000.0        64000
# 195  trainHaswell                   Haswell  4160000.0        65000
# 196  trainHaswell                   Haswell  4224000.0        66000
# 197  trainHaswell                   Haswell  4288000.0        67000
# 198  trainHaswell                   Haswell  4352000.0        68000
# 199  trainHaswell                   Haswell  4416000.0        69000
# 200  trainHaswell                   Haswell  4480000.0        70000
# 201  trainHaswell                   Haswell  4544000.0        71000
# 202  trainHaswell                   Haswell  4608000.0        72000
# 203  trainHaswell                   Haswell  4672000.0        73000
# 204  trainHaswell                   Haswell  4736000.0        74000
# 205  trainHaswell                   Haswell  4800000.0        75000
# 206  trainHaswell                   Haswell  4864000.0        76000
# 207  trainHaswell                   Haswell  4928000.0        77000
# 208  trainHaswell                   Haswell  4992000.0        78000
# 209  trainHaswell                   Haswell  5000000.0        78125
#
#                                                matcher  variable  bit_error  \
# 0    <Matcher quantity='cache', method='fp', values...  cache_fp   0.008861
# 1    <Matcher quantity='cache', method='fp', values...  cache_fp   0.025672
# 2    <Matcher quantity='cache', method='fp', values...  cache_fp   0.080182
# 3    <Matcher quantity='cache', method='fp', values...  cache_fp   0.041930
# 4    <Matcher quantity='cache', method='fp', values...  cache_fp   0.139201
# 5    <Matcher quantity='cache', method='fp', values...  cache_fp   0.139478
# 6    <Matcher quantity='cache', method='fp', values...  cache_fp   0.165823
# 7    <Matcher quantity='cache', method='fp', values...  cache_fp   0.176068
# 8    <Matcher quantity='cache', method='fp', values...  cache_fp   0.217761
# 9    <Matcher quantity='cache', method='fp', values...  cache_fp   0.255142
# 10   <Matcher quantity='cache', method='fp', values...  cache_fp   0.271203
# 11   <Matcher quantity='cache', method='fp', values...  cache_fp   0.318631
# 12   <Matcher quantity='cache', method='fp', values...  cache_fp   0.211472
# 13   <Matcher quantity='cache', method='fp', values...  cache_fp   0.388449
# 14   <Matcher quantity='cache', method='fp', values...  cache_fp   0.300356
# 15   <Matcher quantity='cache', method='fp', values...  cache_fp   0.321598
# 16   <Matcher quantity='cache', method='fp', values...  cache_fp   0.345253
# 17   <Matcher quantity='cache', method='fp', values...  cache_fp   0.383465
# 18   <Matcher quantity='cache', method='fp', values...  cache_fp   0.326068
# 19   <Matcher quantity='cache', method='fp', values...  cache_fp   0.345055
# 20   <Matcher quantity='cache', method='fp', values...  cache_fp   0.381804
# 21   <Matcher quantity='cache', method='fp', values...  cache_fp   0.355617
# 22   <Matcher quantity='cache', method='fp', values...  cache_fp   0.362935
# 23   <Matcher quantity='cache', method='fp', values...  cache_fp   0.399446
# 24   <Matcher quantity='cache', method='fp', values...  cache_fp   0.426503
# 25   <Matcher quantity='cache', method='fp', values...  cache_fp   0.106052
# 26   <Matcher quantity='cache', method='fp', values...  cache_fp   0.023497
# 27   <Matcher quantity='cache', method='fp', values...  cache_fp   0.050237
# 28   <Matcher quantity='cache', method='fp', values...  cache_fp   0.105934
# 29   <Matcher quantity='cache', method='fp', values...  cache_fp   0.093948
# ..                                                 ...       ...        ...
# 180  <Matcher quantity='cache', method='fp', values...  cache_fp   0.454427
# 181  <Matcher quantity='cache', method='fp', values...  cache_fp   0.386849
# 182  <Matcher quantity='cache', method='fp', values...  cache_fp   0.419531
# 183  <Matcher quantity='cache', method='fp', values...  cache_fp   0.387891
# 184  <Matcher quantity='cache', method='fp', values...  cache_fp   0.419661
# 185  <Matcher quantity='cache', method='fp', values...  cache_fp   0.419661
# 186  <Matcher quantity='cache', method='fp', values...  cache_fp   0.434505
# 187  <Matcher quantity='cache', method='fp', values...  cache_fp   0.437760
# 188  <Matcher quantity='cache', method='fp', values...  cache_fp   0.437630
# 189  <Matcher quantity='cache', method='fp', values...  cache_fp   0.352865
# 190  <Matcher quantity='cache', method='fp', values...  cache_fp   0.407552
# 191  <Matcher quantity='cache', method='fp', values...  cache_fp   0.450260
# 192  <Matcher quantity='cache', method='fp', values...  cache_fp   0.389063
# 193  <Matcher quantity='cache', method='fp', values...  cache_fp   0.465755
# 194  <Matcher quantity='cache', method='fp', values...  cache_fp   0.446875
# 195  <Matcher quantity='cache', method='fp', values...  cache_fp   0.444401
# 196  <Matcher quantity='cache', method='fp', values...  cache_fp   0.415365
# 197  <Matcher quantity='cache', method='fp', values...  cache_fp   0.401562
# 198  <Matcher quantity='cache', method='fp', values...  cache_fp   0.406510
# 199  <Matcher quantity='cache', method='fp', values...  cache_fp   0.442057
# 200  <Matcher quantity='cache', method='fp', values...  cache_fp   0.469271
# 201  <Matcher quantity='cache', method='fp', values...  cache_fp   0.443620
# 202  <Matcher quantity='cache', method='fp', values...  cache_fp   0.448568
# 203  <Matcher quantity='cache', method='fp', values...  cache_fp   0.439453
# 204  <Matcher quantity='cache', method='fp', values...  cache_fp   0.416276
# 205  <Matcher quantity='cache', method='fp', values...  cache_fp   0.436068
# 206  <Matcher quantity='cache', method='fp', values...  cache_fp   0.462630
# 207  <Matcher quantity='cache', method='fp', values...  cache_fp   0.463932
# 208  <Matcher quantity='cache', method='fp', values...  cache_fp   0.463151
# 209  <Matcher quantity='cache', method='fp', values...  cache_fp   0.420443
#
#      symbol_error
# 0        0.483544
# 1        0.673418
# 2        0.569620
# 3        0.541772
# 4        0.792405
# 5        0.800000
# 6        0.863291
# 7        0.893671
# 8        0.964557
# 9        0.939241
# 10       0.977215
# 11       0.994937
# 12       0.994937
# 13       0.997468
# 14       0.994937
# 15       0.997468
# 16       1.000000
# 17       1.000000
# 18       0.997468
# 19       1.000000
# 20       1.000000
# 21       1.000000
# 22       1.000000
# 23       1.000000
# 24       1.000000
# 25       0.549367
# 26       0.551899
# 27       0.556962
# 28       0.640506
# 29       0.645570
# ..            ...
# 180      1.000000
# 181      1.000000
# 182      1.000000
# 183      1.000000
# 184      1.000000
# 185      1.000000
# 186      1.000000
# 187      1.000000
# 188      1.000000
# 189      1.000000
# 190      1.000000
# 191      1.000000
# 192      1.000000
# 193      1.000000
# 194      1.000000
# 195      1.000000
# 196      1.000000
# 197      1.000000
# 198      1.000000
# 199      1.000000
# 200      1.000000
# 201      1.000000
# 202      1.000000
# 203      0.991667
# 204      1.000000
# 205      1.000000
# 206      1.000000
# 207      1.000000
# 208      1.000000
# 209      1.000000
#
# [210 rows x 9 columns]

# %% [markdown]
# 7. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 8. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = NB_CHANNEL.upper() + ("_INT_" if NB_EXPERIMENT_TYPE == "interference" else "")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        "./data/BER_{}_{}_{}.dat".format(PREFIX, eval_phase, env),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 9. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
