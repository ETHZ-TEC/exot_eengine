# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM
import sklearn.ensemble             # RandomForestClassifier, VotingClassifier

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Tensorflow not available - excluding packets relying on it!

# %% [markdown]
# __Notebook config__

# %%
NB_EXPERIMENT = "power-cc_interference_h9"

environments_to_execute = [
    "Sandy"
]

phases = {
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = experiment._execution_status

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    for phase in phases[env].items():
         experiment.execute_in_environment(env, phase, resume=False)
experiment.write()

# %% [markdown]
# # Demo
# With the following cell you can visualise a single run from either platform and also have a look on the data histogram, to check whether the quantisation thresholds are defined correctly.

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)

DEMO_PHASE = "train"
DEMO_ID = 0

ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io=(
        {
            "env": "Sandy",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
    ),
)

demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream()
    plotter.plot_rdpstream(end=10)
    plotter.plot_slicing()
    plotter.plot_symstream()

quantisation_thresholds = experiment.environments_apps_zones[
    ingest_args['io']['env']]['snk']['zone_config'].power_thresholds[
    demo_run.i_rdpstream.columns[-1].split(':')[-2]]

plt.figure()
plt.hist(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'], bins='auto')
plt.xticks(np.arange(0, max(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'])+1, 1.0))
for threshold in quantisation_thresholds[1:]:
    plt.axvline(x=threshold, color='red', linestyle='--')
plt.xlim([0,70])
# Out:
# 2020-03-30 18:44:00 :: unpicked an experiment instance <PerformanceExperiment at 0x7fa4c2b79c18 with PowerCC channel, configured>
# 2020-03-30 18:44:01 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:44:01 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:44:01 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:44:01 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:44:01 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:44:01 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:44:01 :: bootstrapped layer 'io' with TimeValue
# (0, 70)

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# ## Analyse
#
# 1. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)
# Out:
# 2020-03-30 18:44:58 :: unpicked an experiment instance <PerformanceExperiment at 0x7fa4a13d4b70 with PowerCC channel, configured>
# 2020-03-30 18:44:58 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:44:59 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:44:59 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:44:59 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:44:59 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:44:59 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:44:59 :: bootstrapped layer 'io' with TimeValue

# %% [markdown]
# 2. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "normal"

analysis_args = {
    "Sandy": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(),
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)]
        },
    ),
}

phase_mappings = {
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %% [markdown]
# 3. Calculate the performance metrics

# %%
del experiment.performance_metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        use_levensthein=True,
        **analysis_args[env],
    )
# Out:
# 2020-03-30 18:45:12 :: analysing performance for phases: train -> eval, environments ['Sandy']
# 2020-03-30 18:58:32 :: Analysing run pair for phase mapping: ('train', 'eval'), idx: 85, env: Sandy, rep: 2, failed! Error: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required by StandardScaler..

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#    phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  train                    Sandy  3.222222            1           0
# 1   eval        train       Sandy  3.222222            1           0
# 2  train                    Sandy  3.222222            1           1
# 3   eval        train       Sandy  3.222222            1           1
# 4  train                    Sandy  3.222222            1           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.495833      0.820833  <Matcher quantity='power', method='msr', value...
# 1   0.524587      0.868173  <Matcher quantity='power', method='msr', value...
# 2   0.493750      0.818750  <Matcher quantity='power', method='msr', value...
# 3   0.520402      0.870684  <Matcher quantity='power', method='msr', value...
# 4   0.488194      0.820833  <Matcher quantity='power', method='msr', value...
#
#     variable
# 0  power_msr
# 1  power_msr
# 2  power_msr
# 3  power_msr
# 4  power_msr

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#      phase trained_with environment     bit_rate  symbol_rate  \
# 0     eval        train       Sandy     3.222222            1
# 1     eval        train       Sandy    32.222222           10
# 2     eval        train       Sandy    64.444444           20
# 3     eval        train       Sandy    96.666667           30
# 4     eval        train       Sandy   128.888889           40
# 5     eval        train       Sandy   161.111111           50
# 6     eval        train       Sandy   193.333333           60
# 7     eval        train       Sandy   225.555556           70
# 8     eval        train       Sandy   257.777778           80
# 9     eval        train       Sandy   290.000000           90
# 10    eval        train       Sandy   322.222222          100
# 11    eval        train       Sandy   354.444444          110
# 12    eval        train       Sandy   386.666667          120
# 13    eval        train       Sandy   418.888889          130
# 14    eval        train       Sandy   451.111111          140
# 15    eval        train       Sandy   483.333333          150
# 16    eval        train       Sandy   515.555556          160
# 17    eval        train       Sandy   547.777778          170
# 18    eval        train       Sandy   580.000000          180
# 19    eval        train       Sandy   612.222222          190
# 20    eval        train       Sandy   644.444444          200
# 21    eval        train       Sandy   676.666667          210
# 22    eval        train       Sandy   708.888889          220
# 23    eval        train       Sandy   741.111111          230
# 24    eval        train       Sandy   773.333333          240
# 25    eval        train       Sandy   805.555556          250
# 26    eval        train       Sandy   837.777778          260
# 27    eval        train       Sandy   870.000000          270
# 28    eval        train       Sandy   902.222222          280
# 29    eval        train       Sandy   934.444444          290
# ..     ...          ...         ...          ...          ...
# 172  train                    Sandy  2287.777778          710
# 173  train                    Sandy  2320.000000          720
# 174  train                    Sandy  2352.222222          730
# 175  train                    Sandy  2384.444444          740
# 176  train                    Sandy  2416.666667          750
# 177  train                    Sandy  2448.888889          760
# 178  train                    Sandy  2481.111111          770
# 179  train                    Sandy  2513.333333          780
# 180  train                    Sandy  2545.555556          790
# 181  train                    Sandy  2577.777778          800
# 182  train                    Sandy  2610.000000          810
# 183  train                    Sandy  2642.222222          820
# 184  train                    Sandy  2674.444444          830
# 185  train                    Sandy  2706.666667          840
# 186  train                    Sandy  2738.888889          850
# 187  train                    Sandy  2771.111111          860
# 188  train                    Sandy  2803.333333          870
# 189  train                    Sandy  2835.555556          880
# 190  train                    Sandy  2867.777778          890
# 191  train                    Sandy  2900.000000          900
# 192  train                    Sandy  2932.222222          910
# 193  train                    Sandy  2964.444444          920
# 194  train                    Sandy  2996.666667          930
# 195  train                    Sandy  3028.888889          940
# 196  train                    Sandy  3061.111111          950
# 197  train                    Sandy  3093.333333          960
# 198  train                    Sandy  3125.555556          970
# 199  train                    Sandy  3157.777778          980
# 200  train                    Sandy  3190.000000          990
# 201  train                    Sandy  3222.222222         1000
#
#                                                matcher   variable  bit_error  \
# 0    <Matcher quantity='power', method='msr', value...  power_msr   0.522285
# 1    <Matcher quantity='power', method='msr', value...  power_msr   0.311292
# 2    <Matcher quantity='power', method='msr', value...  power_msr   0.333155
# 3    <Matcher quantity='power', method='msr', value...  power_msr   2.772601
# 4    <Matcher quantity='power', method='msr', value...  power_msr   0.980099
# 5    <Matcher quantity='power', method='msr', value...  power_msr   2.427390
# 6    <Matcher quantity='power', method='msr', value...  power_msr   0.614369
# 7    <Matcher quantity='power', method='msr', value...  power_msr   0.391011
# 8    <Matcher quantity='power', method='msr', value...  power_msr   2.206608
# 9    <Matcher quantity='power', method='msr', value...  power_msr   0.451285
# 10   <Matcher quantity='power', method='msr', value...  power_msr   2.798695
# 11   <Matcher quantity='power', method='msr', value...  power_msr   1.378923
# 12   <Matcher quantity='power', method='msr', value...  power_msr   1.207513
# 13   <Matcher quantity='power', method='msr', value...  power_msr   2.024333
# 14   <Matcher quantity='power', method='msr', value...  power_msr   2.252352
# 15   <Matcher quantity='power', method='msr', value...  power_msr   0.324014
# 16   <Matcher quantity='power', method='msr', value...  power_msr   0.460300
# 17   <Matcher quantity='power', method='msr', value...  power_msr   0.325972
# 18   <Matcher quantity='power', method='msr', value...  power_msr   0.477081
# 19   <Matcher quantity='power', method='msr', value...  power_msr   1.528157
# 20   <Matcher quantity='power', method='msr', value...  power_msr   0.468371
# 21   <Matcher quantity='power', method='msr', value...  power_msr   2.922624
# 22   <Matcher quantity='power', method='msr', value...  power_msr   0.543766
# 23   <Matcher quantity='power', method='msr', value...  power_msr   0.789431
# 24   <Matcher quantity='power', method='msr', value...  power_msr   1.708673
# 25   <Matcher quantity='power', method='msr', value...  power_msr   3.207624
# 26   <Matcher quantity='power', method='msr', value...  power_msr   0.834208
# 27   <Matcher quantity='power', method='msr', value...  power_msr   0.493597
# 28   <Matcher quantity='power', method='msr', value...  power_msr   0.709629
# 29   <Matcher quantity='power', method='msr', value...  power_msr   0.498262
# ..                                                 ...        ...        ...
# 172  <Matcher quantity='power', method='msr', value...  power_msr   0.463848
# 173  <Matcher quantity='power', method='msr', value...  power_msr   0.326052
# 174  <Matcher quantity='power', method='msr', value...  power_msr   0.328694
# 175  <Matcher quantity='power', method='msr', value...  power_msr   0.317377
# 176  <Matcher quantity='power', method='msr', value...  power_msr   0.310458
# 177  <Matcher quantity='power', method='msr', value...  power_msr   0.312053
# 178  <Matcher quantity='power', method='msr', value...  power_msr   0.321118
# 179  <Matcher quantity='power', method='msr', value...  power_msr   0.303944
# 180  <Matcher quantity='power', method='msr', value...  power_msr   0.326648
# 181  <Matcher quantity='power', method='msr', value...  power_msr   0.313340
# 182  <Matcher quantity='power', method='msr', value...  power_msr   0.318101
# 183  <Matcher quantity='power', method='msr', value...  power_msr   0.313691
# 184  <Matcher quantity='power', method='msr', value...  power_msr   0.323325
# 185  <Matcher quantity='power', method='msr', value...  power_msr   0.304437
# 186  <Matcher quantity='power', method='msr', value...  power_msr   0.311203
# 187  <Matcher quantity='power', method='msr', value...  power_msr   0.321164
# 188  <Matcher quantity='power', method='msr', value...  power_msr   0.320020
# 189  <Matcher quantity='power', method='msr', value...  power_msr   0.311343
# 190  <Matcher quantity='power', method='msr', value...  power_msr   0.307924
# 191  <Matcher quantity='power', method='msr', value...  power_msr   0.356202
# 192  <Matcher quantity='power', method='msr', value...  power_msr   0.318967
# 193  <Matcher quantity='power', method='msr', value...  power_msr   0.325248
# 194  <Matcher quantity='power', method='msr', value...  power_msr   0.320723
# 195  <Matcher quantity='power', method='msr', value...  power_msr   0.307407
# 196  <Matcher quantity='power', method='msr', value...  power_msr   0.309028
# 197  <Matcher quantity='power', method='msr', value...  power_msr   0.308999
# 198  <Matcher quantity='power', method='msr', value...  power_msr   0.358185
# 199  <Matcher quantity='power', method='msr', value...  power_msr   0.309687
# 200  <Matcher quantity='power', method='msr', value...  power_msr   0.320522
# 201  <Matcher quantity='power', method='msr', value...  power_msr   0.306563
#
#      symbol_error
# 0        0.869429
# 1        0.843554
# 2        0.873822
# 3        3.116861
# 4        1.569691
# 5        2.845304
# 6        1.224594
# 7        0.890631
# 8        2.585958
# 9        0.877528
# 10       3.064882
# 11       1.896821
# 12       1.828807
# 13       2.452200
# 14       2.675888
# 15       0.874844
# 16       1.053184
# 17       0.867500
# 18       1.094675
# 19       2.109043
# 20       1.084779
# 21       3.255589
# 22       1.179654
# 23       1.401902
# 24       2.232381
# 25       3.433847
# 26       1.461859
# 27       1.129044
# 28       1.388724
# 29       1.154800
# ..            ...
# 172      0.832294
# 173      0.810321
# 174      0.819068
# 175      0.830908
# 176      0.823529
# 177      0.809820
# 178      0.816284
# 179      0.821206
# 180      0.818119
# 181      0.809425
# 182      0.821206
# 183      0.823243
# 184      0.815662
# 185      0.801932
# 186      0.795643
# 187      0.831933
# 188      0.813500
# 189      0.812500
# 190      0.813278
# 191      0.801109
# 192      0.801802
# 193      0.816355
# 194      0.827057
# 195      0.800694
# 196      0.816667
# 197      0.802342
# 198      0.800839
# 199      0.819763
# 200      0.798742
# 201      0.785513
#
# [202 rows x 9 columns]

# %% [markdown]
# 4. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 5. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = ("interference" if "interference" in NB_EXPERIMENT else "baseline")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        experiment.path.joinpath("performance_{}_{}_{}.dat".format(PREFIX, NB_EXPERIMENT.split('_')[-1], 
                                                             env)),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 6. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
