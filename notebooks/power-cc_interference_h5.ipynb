# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM
import sklearn.ensemble             # RandomForestClassifier, VotingClassifier

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Tensorflow not available - excluding packets relying on it!

# %% [markdown]
# __Notebook config__

# %%
NB_EXPERIMENT = "power-cc_interference_h5"

environments_to_execute = [
    "Haswell",
    "Sandy"
]

phases = {
    "Haswell": {
        "normal": ["train", "eval"],
    },
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = experiment._execution_status

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    for phase in phases[env].items():
         experiment.execute_in_environment(env, phase, resume=False)
experiment.write()

# %% [markdown]
# # Demo
# With the following cell you can visualise a single run from either platform and also have a look on the data histogram, to check whether the quantisation thresholds are defined correctly.

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)

DEMO_PHASE = "train"
DEMO_ID = 0
DEMO_SANDY = True #"" in DEMO_PHASE

ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io=(
        {
            "env": "Sandy",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
        if DEMO_SANDY
        else {
            "env": "Haswell",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
    ),
)

demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream()
    plotter.plot_rdpstream(end=10)
    plotter.plot_slicing()
    plotter.plot_symstream()

quantisation_thresholds = experiment.environments_apps_zones[
    ingest_args['io']['env']]['snk']['zone_config'].power_thresholds[
    demo_run.i_rdpstream.columns[-1].split(':')[-2]]

plt.figure()
plt.hist(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'], bins='auto')
plt.xticks(np.arange(0, max(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'])+1, 1.0))
for threshold in quantisation_thresholds[1:]:
    plt.axvline(x=threshold, color='red', linestyle='--')
plt.xlim([0,70])
# Out:
# 2020-03-30 18:44:06 :: unpicked an experiment instance <PerformanceExperiment at 0x7fdd1de980b8 with PowerCC channel, configured>
# 2020-03-30 18:44:06 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:44:07 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:44:07 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:44:07 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:44:07 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:44:07 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:44:07 :: bootstrapped layer 'io' with TimeValue
# (0, 70)

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# ## Analyse
#
# 1. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)
# Out:
# 2020-03-30 18:45:03 :: unpicked an experiment instance <PerformanceExperiment at 0x7fdcfa04a780 with PowerCC channel, configured>
# 2020-03-30 18:45:03 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:45:03 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:45:04 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:45:04 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:45:04 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:45:04 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:45:04 :: bootstrapped layer 'io' with TimeValue

# %% [markdown]
# 2. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "normal"

analysis_args = {
    "Sandy": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(),
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)]
        },
    ),
    "Haswell": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), 
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        },
    ),
}

phase_mappings = {
    "Haswell": {
        "normal": ["train", "eval"],
    },
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %% [markdown]
# 3. Calculate the performance metrics

# %%
del experiment.performance_metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        use_levensthein=True,
        **analysis_args[env],
    )
# Out:
# 2020-03-30 18:45:21 :: analysing performance for phases: train -> eval, environments ['Haswell']
# 2020-03-30 19:05:14 :: analysing performance for phases: train -> eval, environments ['Sandy']

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#    phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  train                  Haswell       2.4            1           0
# 1   eval        train     Haswell       2.4            1           0
# 2  train                  Haswell       2.4            1           1
# 3   eval        train     Haswell       2.4            1           1
# 4  train                  Haswell       2.4            1           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.534328      0.724138  <Matcher quantity='power', method='msr', value...
# 1   0.555356      0.745854  <Matcher quantity='power', method='msr', value...
# 2   0.535821      0.727136  <Matcher quantity='power', method='msr', value...
# 3   0.555356      0.745854  <Matcher quantity='power', method='msr', value...
# 4   0.535474      0.724138  <Matcher quantity='power', method='msr', value...
#
#     variable
# 0  power_msr
# 1  power_msr
# 2  power_msr
# 3  power_msr
# 4  power_msr

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#      phase trained_with environment  bit_rate  symbol_rate  \
# 0     eval        train     Haswell       2.4            1
# 1     eval        train     Haswell      24.0           10
# 2     eval        train     Haswell      48.0           20
# 3     eval        train     Haswell      72.0           30
# 4     eval        train     Haswell      96.0           40
# 5     eval        train     Haswell     120.0           50
# 6     eval        train     Haswell     144.0           60
# 7     eval        train     Haswell     168.0           70
# 8     eval        train     Haswell     192.0           80
# 9     eval        train     Haswell     216.0           90
# 10    eval        train     Haswell     240.0          100
# 11    eval        train     Haswell     264.0          110
# 12    eval        train     Haswell     288.0          120
# 13    eval        train     Haswell     312.0          130
# 14    eval        train     Haswell     336.0          140
# 15    eval        train     Haswell     360.0          150
# 16    eval        train     Haswell     384.0          160
# 17    eval        train     Haswell     408.0          170
# 18    eval        train     Haswell     432.0          180
# 19    eval        train     Haswell     456.0          190
# 20    eval        train     Haswell     480.0          200
# 21    eval        train     Haswell     504.0          210
# 22    eval        train     Haswell     528.0          220
# 23    eval        train     Haswell     552.0          230
# 24    eval        train     Haswell     576.0          240
# 25    eval        train     Haswell     600.0          250
# 26    eval        train     Haswell     624.0          260
# 27    eval        train     Haswell     648.0          270
# 28    eval        train     Haswell     672.0          280
# 29    eval        train     Haswell     696.0          290
# ..     ...          ...         ...       ...          ...
# 374  train                    Sandy    1704.0          710
# 375  train                    Sandy    1728.0          720
# 376  train                    Sandy    1752.0          730
# 377  train                    Sandy    1776.0          740
# 378  train                    Sandy    1800.0          750
# 379  train                    Sandy    1824.0          760
# 380  train                    Sandy    1848.0          770
# 381  train                    Sandy    1872.0          780
# 382  train                    Sandy    1896.0          790
# 383  train                    Sandy    1920.0          800
# 384  train                    Sandy    1944.0          810
# 385  train                    Sandy    1968.0          820
# 386  train                    Sandy    1992.0          830
# 387  train                    Sandy    2016.0          840
# 388  train                    Sandy    2040.0          850
# 389  train                    Sandy    2064.0          860
# 390  train                    Sandy    2088.0          870
# 391  train                    Sandy    2112.0          880
# 392  train                    Sandy    2136.0          890
# 393  train                    Sandy    2160.0          900
# 394  train                    Sandy    2184.0          910
# 395  train                    Sandy    2208.0          920
# 396  train                    Sandy    2232.0          930
# 397  train                    Sandy    2256.0          940
# 398  train                    Sandy    2280.0          950
# 399  train                    Sandy    2304.0          960
# 400  train                    Sandy    2328.0          970
# 401  train                    Sandy    2352.0          980
# 402  train                    Sandy    2376.0          990
# 403  train                    Sandy    2400.0         1000
#
#                                                matcher   variable  bit_error  \
# 0    <Matcher quantity='power', method='msr', value...  power_msr   0.555356
# 1    <Matcher quantity='power', method='msr', value...  power_msr   0.559524
# 2    <Matcher quantity='power', method='msr', value...  power_msr   2.428732
# 3    <Matcher quantity='power', method='msr', value...  power_msr   0.816180
# 4    <Matcher quantity='power', method='msr', value...  power_msr   0.768909
# 5    <Matcher quantity='power', method='msr', value...  power_msr   4.860812
# 6    <Matcher quantity='power', method='msr', value...  power_msr   0.956718
# 7    <Matcher quantity='power', method='msr', value...  power_msr   0.508276
# 8    <Matcher quantity='power', method='msr', value...  power_msr   2.692768
# 9    <Matcher quantity='power', method='msr', value...  power_msr   0.440947
# 10   <Matcher quantity='power', method='msr', value...  power_msr   0.499249
# 11   <Matcher quantity='power', method='msr', value...  power_msr   2.516950
# 12   <Matcher quantity='power', method='msr', value...  power_msr   0.392488
# 13   <Matcher quantity='power', method='msr', value...  power_msr   0.532056
# 14   <Matcher quantity='power', method='msr', value...  power_msr   0.929071
# 15   <Matcher quantity='power', method='msr', value...  power_msr   0.367601
# 16   <Matcher quantity='power', method='msr', value...  power_msr   2.357209
# 17   <Matcher quantity='power', method='msr', value...  power_msr   1.118647
# 18   <Matcher quantity='power', method='msr', value...  power_msr   0.565394
# 19   <Matcher quantity='power', method='msr', value...  power_msr   0.945644
# 20   <Matcher quantity='power', method='msr', value...  power_msr   0.525601
# 21   <Matcher quantity='power', method='msr', value...  power_msr   0.503632
# 22   <Matcher quantity='power', method='msr', value...  power_msr   0.502762
# 23   <Matcher quantity='power', method='msr', value...  power_msr   1.295982
# 24   <Matcher quantity='power', method='msr', value...  power_msr   1.094235
# 25   <Matcher quantity='power', method='msr', value...  power_msr   0.541772
# 26   <Matcher quantity='power', method='msr', value...  power_msr   0.577769
# 27   <Matcher quantity='power', method='msr', value...  power_msr   0.640731
# 28   <Matcher quantity='power', method='msr', value...  power_msr   0.362551
# 29   <Matcher quantity='power', method='msr', value...  power_msr   0.397107
# ..                                                 ...        ...        ...
# 374  <Matcher quantity='power', method='msr', value...  power_msr   0.473035
# 375  <Matcher quantity='power', method='msr', value...  power_msr   0.356158
# 376  <Matcher quantity='power', method='msr', value...  power_msr   0.505240
# 377  <Matcher quantity='power', method='msr', value...  power_msr   0.486979
# 378  <Matcher quantity='power', method='msr', value...  power_msr   0.445499
# 379  <Matcher quantity='power', method='msr', value...  power_msr   0.475460
# 380  <Matcher quantity='power', method='msr', value...  power_msr   0.479058
# 381  <Matcher quantity='power', method='msr', value...  power_msr   0.464726
# 382  <Matcher quantity='power', method='msr', value...  power_msr   0.494777
# 383  <Matcher quantity='power', method='msr', value...  power_msr   0.470470
# 384  <Matcher quantity='power', method='msr', value...  power_msr   0.496287
# 385  <Matcher quantity='power', method='msr', value...  power_msr   0.481035
# 386  <Matcher quantity='power', method='msr', value...  power_msr   0.504735
# 387  <Matcher quantity='power', method='msr', value...  power_msr   0.473462
# 388  <Matcher quantity='power', method='msr', value...  power_msr   0.452250
# 389  <Matcher quantity='power', method='msr', value...  power_msr   0.348278
# 390  <Matcher quantity='power', method='msr', value...  power_msr   0.476756
# 391  <Matcher quantity='power', method='msr', value...  power_msr   0.447492
# 392  <Matcher quantity='power', method='msr', value...  power_msr   0.498253
# 393  <Matcher quantity='power', method='msr', value...  power_msr   0.475765
# 394  <Matcher quantity='power', method='msr', value...  power_msr   0.509758
# 395  <Matcher quantity='power', method='msr', value...  power_msr   0.464128
# 396  <Matcher quantity='power', method='msr', value...  power_msr   0.489585
# 397  <Matcher quantity='power', method='msr', value...  power_msr   0.498677
# 398  <Matcher quantity='power', method='msr', value...  power_msr   0.502158
# 399  <Matcher quantity='power', method='msr', value...  power_msr   0.522220
# 400  <Matcher quantity='power', method='msr', value...  power_msr   0.401385
# 401  <Matcher quantity='power', method='msr', value...  power_msr   0.488168
# 402  <Matcher quantity='power', method='msr', value...  power_msr   0.507831
# 403  <Matcher quantity='power', method='msr', value...  power_msr   0.350070
#
#      symbol_error
# 0        0.745854
# 1        0.744385
# 2        2.278874
# 3        1.086027
# 4        1.009989
# 5        4.196657
# 6        1.144741
# 7        0.743033
# 8        2.350570
# 9        0.643735
# 10       0.707967
# 11       2.410068
# 12       0.639676
# 13       0.746429
# 14       1.134852
# 15       0.679470
# 16       2.232319
# 17       1.390115
# 18       0.796055
# 19       1.256335
# 20       0.757559
# 21       0.758495
# 22       0.729213
# 23       1.344465
# 24       1.194320
# 25       0.749667
# 26       0.770093
# 27       1.014641
# 28       0.594111
# 29       0.653616
# ..            ...
# 374      0.728955
# 375      0.693492
# 376      0.705589
# 377      0.703817
# 378      0.709517
# 379      0.690872
# 380      0.686099
# 381      0.715496
# 382      0.688557
# 383      0.681682
# 384      0.698555
# 385      0.688525
# 386      0.708583
# 387      0.680060
# 388      0.724242
# 389      0.714286
# 390      0.691692
# 391      0.694857
# 392      0.683607
# 393      0.690655
# 394      0.691321
# 395      0.663659
# 396      0.690972
# 397      0.703760
# 398      0.712259
# 399      0.723724
# 400      0.700711
# 401      0.694695
# 402      0.701807
# 403      0.700556
#
# [404 rows x 9 columns]

# %% [markdown]
# 4. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 5. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = ("interference" if "interference" in NB_EXPERIMENT else "baseline")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        experiment.path.joinpath("performance_{}_{}_{}.dat".format(PREFIX, NB_EXPERIMENT.split('_')[-1], 
                                                             env)),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 6. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
