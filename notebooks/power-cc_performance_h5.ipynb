# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM
import sklearn.ensemble             # RandomForestClassifier, VotingClassifier

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Tensorflow not available - excluding packets relying on it!

# %% [markdown]
# __Notebook config__

# %%
NB_EXPERIMENT = "power-cc_performance_h5"

environments_to_execute = [
    "Haswell",
    "Sandy"
]

phases = {
    "Haswell": {
        "normal": ["train", "eval"],
    },
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = experiment._execution_status

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    for phase in phases[env].items():
         experiment.execute_in_environment(env, phase, resume=False)
experiment.write()

# %% [markdown]
# # Demo
# With the following cell you can visualise a single run from either platform and also have a look on the data histogram, to check whether the quantisation thresholds are defined correctly.

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)

DEMO_PHASE = "eval"
DEMO_ID = 0
DEMO_SANDY = True #"" in DEMO_PHASE

ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io=(
        {
            "env": "Sandy",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
        if DEMO_SANDY
        else {
            "env": "Haswell",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        }
    ),
)

demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream()
    plotter.plot_rdpstream(end=10)
    plotter.plot_slicing()
    plotter.plot_symstream()

quantisation_thresholds = experiment.environments_apps_zones[
    ingest_args['io']['env']]['snk']['zone_config'].power_thresholds[
    demo_run.i_rdpstream.columns[-1].split(':')[-2]]

plt.figure()
plt.hist(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'], bins='auto')
plt.xticks(np.arange(0, max(demo_run.i_rdpstream['power_msr:rapl_domain:pp0:W'])+1, 1.0))
for threshold in quantisation_thresholds[1:]:
    plt.axvline(x=threshold, color='red', linestyle='--')
plt.xlim([0,70])
# Out:
# 2020-03-30 18:43:52 :: unpicked an experiment instance <PerformanceExperiment at 0x7f549c8d5b70 with PowerCC channel, configured>
# 2020-03-30 18:43:52 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:43:52 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:43:52 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:43:52 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:43:52 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:43:52 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:43:52 :: bootstrapped layer 'io' with TimeValue
# (0, 70)

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %% [markdown]
# ## Analyse
#
# 1. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=True)
# Out:
# 2020-03-30 18:44:52 :: unpicked an experiment instance <PerformanceExperiment at 0x7f54792c5c18 with PowerCC channel, configured>
# 2020-03-30 18:44:52 :: configs from pickle and directory differ at [{'path': ('save_path',), 'left': 'data', 'right': './data'}]
# 2020-03-30 18:44:53 :: environments from pickle and directory differ at [{'path': ('Sandy', 'host', 'power_thresholds', 'pp0'), 'left': [0.0, 35.0, 39.0, 43.0, 47.0, 50.5, 53.75, 57.5, 61.0], 'right': [0.0, 35.0, 40.0, 43.0, 47.0, 51.0, 55.0, 58.0, 62.0]}]
# 2020-03-30 18:44:53 :: git commit of unpickled experiment repo '72570632' does not match the commit in which the unpickling was performed 'b9fe78b3'
# 2020-03-30 18:44:53 :: bootstrapped layer 'src' with Huffman
# 2020-03-30 18:44:53 :: bootstrapped layer 'lne' with MedianLineCoding
# 2020-03-30 18:44:53 :: bootstrapped layer 'rdp' with QuantCoreActivation
# 2020-03-30 18:44:53 :: bootstrapped layer 'io' with TimeValue

# %% [markdown]
# 2. Display histogram to verify whether the quantisation thresholds fitting

# %%
THRESHOLD_PHASE = "eval"
THRESHOLD_ID = 0

ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io={
            "env": "Haswell",
            "rep": 0,
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
       },
)

hist_run = experiment.phases[THRESHOLD_PHASE][THRESHOLD_ID]
hist_run.ingest(**ingest_args)

quantisation_thresholds = experiment.environments_apps_zones[
    ingest_args['io']['env']]['snk']['zone_config'].power_thresholds[
    hist_run.i_rdpstream.columns[-1].split(':')[-2]]

plt.figure()
threshold_histogram = plt.hist(hist_run.i_rdpstream['power_msr:rapl_domain:pp0:W'], bins='auto')
plt.xticks(np.arange(0, max(hist_run.i_rdpstream['power_msr:rapl_domain:pp0:W'])+1, 1.0))
for threshold in quantisation_thresholds[1:]:
    plt.axvline(x=threshold, color='red', linestyle='--')
plt.xlim([0,70])

pd.DataFrame({"bin_center": threshold_histogram[1][:-1] + np.diff(threshold_histogram[1]), 
              "density": threshold_histogram[0] / threshold_histogram[0].max()}).to_csv(
    experiment.path.joinpath("histogram_haswell.dat"),
    sep=",",
    encoding="utf-8",
    index=False,
)

import scipy.interpolate

t_min=10
t_max=50

to_plot = copy(hist_run.i_rdpstream['power_msr:rapl_domain:pp0:W'].to_numpy())
# Median filter
window = 9
to_plot = scipy.signal.medfilt(to_plot, kernel_size=window)

ideal_values_interpolator  = scipy.interpolate.interp1d(
    hist_run.o_rdpstream.iloc[:,0].cumsum(),
    hist_run.o_rdpstream.iloc[:,1],
    axis=0,
    kind='next',
    bounds_error=False,
    fill_value="extrapolate",
)

resampled_ideal_values = ideal_values_interpolator(hist_run.i_rdpstream.iloc[:,0])
maskvals = np.unique(resampled_ideal_values)
for idx in range(len(quantisation_thresholds)):
    if idx == len(quantisation_thresholds)-1:
        quantval = quantisation_thresholds[idx] + (
            quantisation_thresholds[idx-1]-quantisation_thresholds[idx-2]) 
    else:
        quantval = (
            (quantisation_thresholds[idx+1] - quantisation_thresholds[idx]) / 2 + quantisation_thresholds[idx]
        )
    resampled_ideal_values[maskvals[idx] == resampled_ideal_values] = quantval

#fig, (ax1, ax2) = plt.subplots(2,1, sharex=True)
plt.figure()
plt.plot(hist_run.i_rdpstream.iloc[:,0], to_plot, label='rdpstream')
plt.plot(hist_run.i_rdpstream.iloc[:,0], resampled_ideal_values, label='ideal rdpstream')
for threshold in quantisation_thresholds[1:]:
    plt.axhline(y=threshold, color='red', linestyle='--')
plt.ylim([0,70])
plt.xlim([t_min,t_max])
plt.ylabel('Power [W]')
plt.xlabel('Time [s]')
None

idx_min = np.where(hist_run.i_rdpstream.iloc[:,0] >= t_min)[0][0]
idx_max = np.where(hist_run.i_rdpstream.iloc[:,0] <= t_max)[0][-1]+1

pd.DataFrame({"bin_center": threshold_histogram[1][:-1] + np.diff(threshold_histogram[1]), 
              "density": threshold_histogram[0] / threshold_histogram[0].max()}).to_csv(
    experiment.path.joinpath("thresholds_hist_haswell.dat"),
    sep=",",
    encoding="utf-8",
    index=False,
)

pd.DataFrame({"time [s]": hist_run.i_rdpstream.iloc[idx_min:idx_max,0], 
              "raw": to_plot[idx_min:idx_max],
              "ideal": resampled_ideal_values[idx_min:idx_max],
             }).to_csv(
    experiment.path.joinpath("thresholds_trace_haswell.dat"),
    sep=",",
    encoding="utf-8",
    index=False,
)

# %% [markdown]
# 3. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "normal"

analysis_args = {
    "Sandy": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(),
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)]
        },
    ),
    "Haswell": dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), 
            sklearn.ensemble.RandomForestClassifier(n_estimators=100, random_state=None)
        )
    },
        io={
            "matcher": [(exot.util.wrangle.Matcher("power", "msr", ["rapl_domain"], ['pp0']),None)],
        },
    ),
}

phase_mappings = {
    "Haswell": {
        "normal": ["train", "eval"],
    },
    "Sandy": {
        "normal": ["train", "eval"],
    },
}

# %% [markdown]
# 4. Calculate the performance metrics

# %%
del experiment.performance_metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        use_levensthein=True,
        **analysis_args[env],
    )
# Out:
# 2020-03-30 18:45:22 :: analysing performance for phases: train -> eval, environments ['Haswell']
# 2020-03-30 19:04:36 :: analysing performance for phases: train -> eval, environments ['Sandy']

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#    phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  train                  Haswell       2.4            1           0
# 1   eval        train     Haswell       2.4            1           0
# 2  train                  Haswell       2.4            1           1
# 3   eval        train     Haswell       2.4            1           1
# 4  train                  Haswell       2.4            1           2
#
#    bit_error  symbol_error                                            matcher  \
# 0     0.0000      0.000000  <Matcher quantity='power', method='msr', value...
# 1     0.0000      0.000000  <Matcher quantity='power', method='msr', value...
# 2     0.0000      0.000000  <Matcher quantity='power', method='msr', value...
# 3     0.0008      0.001796  <Matcher quantity='power', method='msr', value...
# 4     0.0000      0.000000  <Matcher quantity='power', method='msr', value...
#
#     variable
# 0  power_msr
# 1  power_msr
# 2  power_msr
# 3  power_msr
# 4  power_msr

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#      phase trained_with environment  bit_rate  symbol_rate  \
# 0     eval        train     Haswell       2.4            1
# 1     eval        train     Haswell      24.0           10
# 2     eval        train     Haswell      48.0           20
# 3     eval        train     Haswell      72.0           30
# 4     eval        train     Haswell      96.0           40
# 5     eval        train     Haswell     120.0           50
# 6     eval        train     Haswell     144.0           60
# 7     eval        train     Haswell     168.0           70
# 8     eval        train     Haswell     192.0           80
# 9     eval        train     Haswell     216.0           90
# 10    eval        train     Haswell     240.0          100
# 11    eval        train     Haswell     264.0          110
# 12    eval        train     Haswell     288.0          120
# 13    eval        train     Haswell     312.0          130
# 14    eval        train     Haswell     336.0          140
# 15    eval        train     Haswell     360.0          150
# 16    eval        train     Haswell     384.0          160
# 17    eval        train     Haswell     408.0          170
# 18    eval        train     Haswell     432.0          180
# 19    eval        train     Haswell     456.0          190
# 20    eval        train     Haswell     480.0          200
# 21    eval        train     Haswell     504.0          210
# 22    eval        train     Haswell     528.0          220
# 23    eval        train     Haswell     552.0          230
# 24    eval        train     Haswell     576.0          240
# 25    eval        train     Haswell     600.0          250
# 26    eval        train     Haswell     624.0          260
# 27    eval        train     Haswell     648.0          270
# 28    eval        train     Haswell     672.0          280
# 29    eval        train     Haswell     696.0          290
# ..     ...          ...         ...       ...          ...
# 374  train                    Sandy    1704.0          710
# 375  train                    Sandy    1728.0          720
# 376  train                    Sandy    1752.0          730
# 377  train                    Sandy    1776.0          740
# 378  train                    Sandy    1800.0          750
# 379  train                    Sandy    1824.0          760
# 380  train                    Sandy    1848.0          770
# 381  train                    Sandy    1872.0          780
# 382  train                    Sandy    1896.0          790
# 383  train                    Sandy    1920.0          800
# 384  train                    Sandy    1944.0          810
# 385  train                    Sandy    1968.0          820
# 386  train                    Sandy    1992.0          830
# 387  train                    Sandy    2016.0          840
# 388  train                    Sandy    2040.0          850
# 389  train                    Sandy    2064.0          860
# 390  train                    Sandy    2088.0          870
# 391  train                    Sandy    2112.0          880
# 392  train                    Sandy    2136.0          890
# 393  train                    Sandy    2160.0          900
# 394  train                    Sandy    2184.0          910
# 395  train                    Sandy    2208.0          920
# 396  train                    Sandy    2232.0          930
# 397  train                    Sandy    2256.0          940
# 398  train                    Sandy    2280.0          950
# 399  train                    Sandy    2304.0          960
# 400  train                    Sandy    2328.0          970
# 401  train                    Sandy    2352.0          980
# 402  train                    Sandy    2376.0          990
# 403  train                    Sandy    2400.0         1000
#
#                                                matcher   variable  bit_error  \
# 0    <Matcher quantity='power', method='msr', value...  power_msr   0.000267
# 1    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 2    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 3    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 4    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 5    <Matcher quantity='power', method='msr', value...  power_msr   0.000067
# 6    <Matcher quantity='power', method='msr', value...  power_msr   0.000000
# 7    <Matcher quantity='power', method='msr', value...  power_msr   0.000333
# 8    <Matcher quantity='power', method='msr', value...  power_msr   0.000067
# 9    <Matcher quantity='power', method='msr', value...  power_msr   0.000266
# 10   <Matcher quantity='power', method='msr', value...  power_msr   0.000200
# 11   <Matcher quantity='power', method='msr', value...  power_msr   0.000600
# 12   <Matcher quantity='power', method='msr', value...  power_msr   0.261562
# 13   <Matcher quantity='power', method='msr', value...  power_msr   0.001067
# 14   <Matcher quantity='power', method='msr', value...  power_msr   0.001599
# 15   <Matcher quantity='power', method='msr', value...  power_msr   0.004128
# 16   <Matcher quantity='power', method='msr', value...  power_msr   0.529461
# 17   <Matcher quantity='power', method='msr', value...  power_msr   0.003193
# 18   <Matcher quantity='power', method='msr', value...  power_msr   0.014526
# 19   <Matcher quantity='power', method='msr', value...  power_msr   0.014792
# 20   <Matcher quantity='power', method='msr', value...  power_msr   0.023721
# 21   <Matcher quantity='power', method='msr', value...  power_msr   0.033543
# 22   <Matcher quantity='power', method='msr', value...  power_msr   0.047989
# 23   <Matcher quantity='power', method='msr', value...  power_msr   0.060195
# 24   <Matcher quantity='power', method='msr', value...  power_msr   0.056442
# 25   <Matcher quantity='power', method='msr', value...  power_msr   3.838956
# 26   <Matcher quantity='power', method='msr', value...  power_msr   0.054349
# 27   <Matcher quantity='power', method='msr', value...  power_msr   0.073901
# 28   <Matcher quantity='power', method='msr', value...  power_msr   0.158852
# 29   <Matcher quantity='power', method='msr', value...  power_msr   0.069038
# ..                                                 ...        ...        ...
# 374  <Matcher quantity='power', method='msr', value...  power_msr   0.349154
# 375  <Matcher quantity='power', method='msr', value...  power_msr   0.345522
# 376  <Matcher quantity='power', method='msr', value...  power_msr   0.243960
# 377  <Matcher quantity='power', method='msr', value...  power_msr   0.242124
# 378  <Matcher quantity='power', method='msr', value...  power_msr   0.282103
# 379  <Matcher quantity='power', method='msr', value...  power_msr   0.191316
# 380  <Matcher quantity='power', method='msr', value...  power_msr   0.280224
# 381  <Matcher quantity='power', method='msr', value...  power_msr   0.422945
# 382  <Matcher quantity='power', method='msr', value...  power_msr   0.335139
# 383  <Matcher quantity='power', method='msr', value...  power_msr   0.509906
# 384  <Matcher quantity='power', method='msr', value...  power_msr   0.361418
# 385  <Matcher quantity='power', method='msr', value...  power_msr   0.356365
# 386  <Matcher quantity='power', method='msr', value...  power_msr   0.304483
# 387  <Matcher quantity='power', method='msr', value...  power_msr   0.200598
# 388  <Matcher quantity='power', method='msr', value...  power_msr   0.276233
# 389  <Matcher quantity='power', method='msr', value...  power_msr   0.294686
# 390  <Matcher quantity='power', method='msr', value...  power_msr   0.237757
# 391  <Matcher quantity='power', method='msr', value...  power_msr   0.302758
# 392  <Matcher quantity='power', method='msr', value...  power_msr   0.239927
# 393  <Matcher quantity='power', method='msr', value...  power_msr   0.399250
# 394  <Matcher quantity='power', method='msr', value...  power_msr   0.209805
# 395  <Matcher quantity='power', method='msr', value...  power_msr   0.297940
# 396  <Matcher quantity='power', method='msr', value...  power_msr   0.246586
# 397  <Matcher quantity='power', method='msr', value...  power_msr   0.295780
# 398  <Matcher quantity='power', method='msr', value...  power_msr   0.198681
# 399  <Matcher quantity='power', method='msr', value...  power_msr   0.208104
# 400  <Matcher quantity='power', method='msr', value...  power_msr   0.242946
# 401  <Matcher quantity='power', method='msr', value...  power_msr   0.270049
# 402  <Matcher quantity='power', method='msr', value...  power_msr   0.197680
# 403  <Matcher quantity='power', method='msr', value...  power_msr   0.300644
#
#      symbol_error
# 0        0.000599
# 1        0.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# 5        0.000150
# 6        0.000000
# 7        0.000452
# 8        0.000151
# 9        0.000449
# 10       0.000303
# 11       0.001058
# 12       0.492943
# 13       0.001935
# 14       0.002863
# 15       0.007703
# 16       0.721315
# 17       0.006459
# 18       0.028078
# 19       0.027803
# 20       0.044674
# 21       0.062378
# 22       0.084091
# 23       0.103318
# 24       0.097704
# 25       3.505200
# 26       0.094512
# 27       0.130012
# 28       0.216272
# 29       0.119589
# ..            ...
# 374      0.550249
# 375      0.635323
# 376      0.447475
# 377      0.454317
# 378      0.467069
# 379      0.338338
# 380      0.455772
# 381      0.639517
# 382      0.523881
# 383      0.705795
# 384      0.574242
# 385      0.684712
# 386      0.587253
# 387      0.371930
# 388      0.452663
# 389      0.488956
# 390      0.426311
# 391      0.491281
# 392      0.439122
# 393      0.693193
# 394      0.358519
# 395      0.473605
# 396      0.455690
# 397      0.572714
# 398      0.356578
# 399      0.380310
# 400      0.423653
# 401      0.452096
# 402      0.379658
# 403      0.563150
#
# [404 rows x 9 columns]

# %% [markdown]
# 5. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 6. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = ("interference" if "interference" in NB_EXPERIMENT else "baseline")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        experiment.path.joinpath("performance_{}_{}_{}.dat".format(PREFIX, NB_EXPERIMENT.split('_')[-1], 
                                                             env)),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 7. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
