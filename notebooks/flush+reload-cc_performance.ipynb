# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *

# %% [markdown]
# Parameters

# %%
NB_EXPERIMENT_TYPES = ["performance", "interference"]
NB_CHANNELS = ["ff", "fp", "fr"]
NB_CONFIGS = ["flush+flush", "flush+prefetch", "flush+reload"]

# %% [markdown]
# #### Notebook config

# %%
# Names to configure
NB_EXPERIMENT_TYPE = "performance"
NB_CONFIG = "flush+reload"

# Generated names
NB_EXPERIMENT = f"{NB_CONFIG}-cc_{NB_EXPERIMENT_TYPE}"
NB_CHANNEL = "f" + NB_CONFIG.split("+")[-1][0]

# %%
print("NB_CHANNEL         ", NB_CHANNEL)
print("NB_EXPERIMENT_TYPE ", NB_EXPERIMENT_TYPE)
print("NB_CONFIG          ", NB_CONFIG)
print("NB_EXPERIMENT      ", NB_EXPERIMENT)
# Out:
# NB_CHANNEL          fr
# NB_EXPERIMENT_TYPE  performance
# NB_CONFIG           flush+reload
# NB_EXPERIMENT       flush+reload-cc_performance

# %%
assert NB_EXPERIMENT_TYPE in NB_EXPERIMENT_TYPES
assert NB_CHANNEL in NB_CHANNELS
assert NB_CONFIG in NB_CONFIGS

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

environments_to_execute = [
    "ARMv8",
    "Haswell"
]

phases = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}
# Out:
# name = "flush+reload-cc_performance"
# save_path = "./data"
# backup_path = "./data/_backup"
# experiment_exists_action = "move"
#
# [EXPERIMENT]
# type = "PerformanceExperiment"
# channel = "Cache"
#
# [EXPERIMENT.GENERAL]
# latency = 10
# fan = true
# governors = "userspace"
# frequencies = "max"
# sampling_period = 2e-5
# delay_after_spawn = 5.0
# delay_after_auxiliary = 1.0
# active_wait = false
#
# [EXPERIMENT.PHASES.trainShortARMv8]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(500, 6001, 500)))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortARMv8]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(500, 6001, 500)))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainARMv8]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(250, 6001, 250)))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalARMv8]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(250, 6001, 250)))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.trainShortHaswell]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(10000, 78001, 10000)) + [78125])"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortHaswell]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(10000, 78001, 10000)) + [78125])"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainHaswell]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(1000, 78001, 1000))  + [78125])"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalHaswell]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(1000, 78001, 1000))  + [78125])"
# repetitions = 5
#
# [EXPERIMENT.LAYERS.src]
# name = "BitsetCoding"
#
# [EXPERIMENT.LAYERS.lne]
# name = "MultiN"
#
# [EXPERIMENT.LAYERS.rdp]
# name = "DirectActivation"
#
# [EXPERIMENT.LAYERS.io]
# name = "TimeValue"
#
# [EXPERIMENT.GENERAL.ARMv8]
# fan = "255"
# sampling_period = 0.000225
#
# [EXPERIMENT.LAYERS.src.params]
# bitset_length = 64
#
# [EXPERIMENT.LAYERS.lne.params]
# N = 64
#
# [EXPERIMENT.LAYERS.rdp.params]
#
# [EXPERIMENT.LAYERS.io.params]
# timebase = "ns"
#
# [ENVIRONMENTS.Haswell.APPS.snk]
# executable = "meter_cache_fr"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.APPS.src]
# executable = "generator_cache_read_st"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.src.generator]
# cpu_to_pin = 3
# cores = [ 0,]
# worker_policy = "round_robin"
# self_policy = "round_robin"
# worker_priority = 98
# self_priority = 97
# use_busy_sleep = true
# busy_sleep_yield = false
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 64
#
# [ENVIRONMENTS.Haswell.src.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = false
#
# [ENVIRONMENTS.Haswell.src.schedule_reader]
# reading_from_file = true
#
# [ENVIRONMENTS.Haswell.snk.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = true
# rotating_logs = false
# rotating_logs_count = 10
# rotating_logs_size = 104857600
# timestamp_files = false
#
# [ENVIRONMENTS.Haswell.snk.host]
# policy = "round_robin"
# pinning = 7
# priority = 95
# log_header = true
# start_immediately = false
# use_busy_sleep = true
# busy_sleep_yield = false
#
# [ENVIRONMENTS.Haswell.snk.cache]
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 64
#
# [ENVIRONMENTS.ARMv8.APPS.snk]
# executable = "meter_cache_fr"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.APPS.src]
# executable = "generator_cache_read_st"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.src.generator]
# cpu_to_pin = 2
# cores = [ 0,]
# worker_policy = "round_robin"
# self_policy = "round_robin"
# worker_priority = 98
# self_priority = 97
# use_busy_sleep = true
# busy_sleep_yield = false
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 16
#
# [ENVIRONMENTS.ARMv8.src.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = false
#
# [ENVIRONMENTS.ARMv8.src.schedule_reader]
# reading_from_file = true
#
# [ENVIRONMENTS.ARMv8.snk.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = true
# rotating_logs = false
# rotating_logs_count = 10
# rotating_logs_size = 104857600
# timestamp_files = false
#
# [ENVIRONMENTS.ARMv8.snk.host]
# policy = "round_robin"
# pinning = 3
# priority = 95
# log_header = true
# start_immediately = false
# use_busy_sleep = true
# busy_sleep_yield = false
#
# [ENVIRONMENTS.ARMv8.snk.cache]
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 16

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
raise Exception("Are you sure?")

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = getattr(experiment, "_execution_status", {})

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    experiment.execute_in_environment(env, phases[env]['short'], resume=False)
    experiment.execute_in_environment(env, phases[env]['normal'], resume=False)
experiment.write()

# %% [markdown]
# ## Analyse

# %% [markdown]
# 1. Define which class of experiments to analyse (short of normal length)

# %%
SHORT = False

# %% [markdown]
# 2. Check data collection status

# %%
for _experiment in [NB_EXPERIMENT]:
    for _platform, _phase_mapping in phases.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0].strip(), "logs:", _logs[0].strip(), sep=" ")
# Out:
# experiment: flush+reload-cc_performance platform: ARMv8 phase: trainShortARMv8 folders: 13 logs: 52
# experiment: flush+reload-cc_performance platform: ARMv8 phase: evalShortARMv8 folders: 13 logs: 52
# experiment: flush+reload-cc_performance platform: ARMv8 phase: trainARMv8 folders: 25 logs: 250
# experiment: flush+reload-cc_performance platform: ARMv8 phase: evalARMv8 folders: 25 logs: 250
# experiment: flush+reload-cc_performance platform: Haswell phase: trainShortHaswell folders: 9 logs: 36
# experiment: flush+reload-cc_performance platform: Haswell phase: evalShortHaswell folders: 9 logs: 36
# experiment: flush+reload-cc_performance platform: Haswell phase: trainHaswell folders: 80 logs: 800
# experiment: flush+reload-cc_performance platform: Haswell phase: evalHaswell folders: 80 logs: 800

# %% [markdown]
# 3. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
# Out:
# 2019-09-10 13:16:22 :: unpicked an experiment instance <PerformanceExperiment at 0x7f0a48f41a20 with Cache channel, configured>
# 2019-09-10 13:16:23 :: git commit of unpickled experiment repo '89c78965' does not match the commit in which the unpickling was performed '50fd78bb'

# %% [markdown]
# 4. Specify the demo run and visualise

# %%
DEMO_PHASE = "trainShortARMv8"
DEMO_ID = 0
DEMO_ARM = "ARM" in DEMO_PHASE

# %%
ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]}
    if DEMO_ARM
    else {},
    io={
        "env": "ARMv8" if DEMO_ARM else "Haswell",
        "rep": 0,
        "matcher": exot.util.wrangle.Matcher("cache", NB_CHANNEL, ["access_time"], list(range(64))),
    },
)

# %%
demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

# %%
with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream(dim_count=2)
    plotter.plot_rdpstream(end=5.0, dim_count=2)
    plotter.plot_slicing(dim_count=2)
    plotter.plot_eye_diagram()
    plotter.plot_symbol_space()
    plotter.plot_error()
    plotter.plot_timing()

# %% [markdown]
# 5. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "short" if SHORT else "normal"

analysis_args = {
    "ARMv8": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]},
        io={
            "matcher": exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            )
        },
    ),
    "Haswell": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={
            "matcher": exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            )
        },
    ),
}

phase_mappings = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}

# %% [markdown]
# _Calculate the performance metrics_

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        **analysis_args[env],
    )
# Out:
# 2019-09-10 13:30:45 :: analysing performance for phases: trainARMv8 -> evalARMv8
# 2019-09-10 13:30:45 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:30:51 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:30:59 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:05 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:11 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:17 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:22 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:28 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:33 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:40 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:47 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:31:53 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:00 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:06 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:12 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:19 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:28 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:35 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:42 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:48 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:54 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:00 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:07 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:14 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:20 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:26 :: analysing performance for phases: trainHaswell -> evalHaswell
# 2019-09-10 13:33:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:59 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:12 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:18 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:56 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:09 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:16 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:23 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:44 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:52 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:18 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:25 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:31 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:39 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:31 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:56 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:04 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:19 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:57 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:04 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:18 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:52 :: \_ analysing performance for env: Haswell

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#         phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  trainARMv8                    ARMv8    6400.0          100           0
# 1   evalARMv8   trainARMv8       ARMv8    6400.0          100           0
# 2  trainARMv8                    ARMv8    6400.0          100           1
# 3   evalARMv8   trainARMv8       ARMv8    6400.0          100           1
# 4  trainARMv8                    ARMv8    6400.0          100           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.007161      0.458333  <Matcher quantity='cache', method='fr', values...
# 1   0.007120      0.455696  <Matcher quantity='cache', method='fr', values...
# 2   0.007161      0.458333  <Matcher quantity='cache', method='fr', values...
# 3   0.007120      0.455696  <Matcher quantity='cache', method='fr', values...
# 4   0.007161      0.458333  <Matcher quantity='cache', method='fr', values...
#
#    variable
# 0  cache_fr
# 1  cache_fr
# 2  cache_fr
# 3  cache_fr
# 4  cache_fr

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#             phase  trained_with environment   bit_rate  symbol_rate  \
# 0       evalARMv8    trainARMv8       ARMv8     6400.0          100
# 1       evalARMv8    trainARMv8       ARMv8    16000.0          250
# 2       evalARMv8    trainARMv8       ARMv8    32000.0          500
# 3       evalARMv8    trainARMv8       ARMv8    48000.0          750
# 4       evalARMv8    trainARMv8       ARMv8    64000.0         1000
# 5       evalARMv8    trainARMv8       ARMv8    80000.0         1250
# 6       evalARMv8    trainARMv8       ARMv8    96000.0         1500
# 7       evalARMv8    trainARMv8       ARMv8   112000.0         1750
# 8       evalARMv8    trainARMv8       ARMv8   128000.0         2000
# 9       evalARMv8    trainARMv8       ARMv8   144000.0         2250
# 10      evalARMv8    trainARMv8       ARMv8   160000.0         2500
# 11      evalARMv8    trainARMv8       ARMv8   176000.0         2750
# 12      evalARMv8    trainARMv8       ARMv8   192000.0         3000
# 13      evalARMv8    trainARMv8       ARMv8   208000.0         3250
# 14      evalARMv8    trainARMv8       ARMv8   224000.0         3500
# 15      evalARMv8    trainARMv8       ARMv8   240000.0         3750
# 16      evalARMv8    trainARMv8       ARMv8   256000.0         4000
# 17      evalARMv8    trainARMv8       ARMv8   272000.0         4250
# 18      evalARMv8    trainARMv8       ARMv8   288000.0         4500
# 19      evalARMv8    trainARMv8       ARMv8   304000.0         4750
# 20      evalARMv8    trainARMv8       ARMv8   320000.0         5000
# 21      evalARMv8    trainARMv8       ARMv8   336000.0         5250
# 22      evalARMv8    trainARMv8       ARMv8   352000.0         5500
# 23      evalARMv8    trainARMv8       ARMv8   368000.0         5750
# 24      evalARMv8    trainARMv8       ARMv8   384000.0         6000
# 25    evalHaswell  trainHaswell     Haswell     6400.0          100
# 26    evalHaswell  trainHaswell     Haswell    64000.0         1000
# 27    evalHaswell  trainHaswell     Haswell   128000.0         2000
# 28    evalHaswell  trainHaswell     Haswell   192000.0         3000
# 29    evalHaswell  trainHaswell     Haswell   256000.0         4000
# ..            ...           ...         ...        ...          ...
# 180  trainHaswell                   Haswell  3200000.0        50000
# 181  trainHaswell                   Haswell  3264000.0        51000
# 182  trainHaswell                   Haswell  3328000.0        52000
# 183  trainHaswell                   Haswell  3392000.0        53000
# 184  trainHaswell                   Haswell  3456000.0        54000
# 185  trainHaswell                   Haswell  3520000.0        55000
# 186  trainHaswell                   Haswell  3584000.0        56000
# 187  trainHaswell                   Haswell  3648000.0        57000
# 188  trainHaswell                   Haswell  3712000.0        58000
# 189  trainHaswell                   Haswell  3776000.0        59000
# 190  trainHaswell                   Haswell  3840000.0        60000
# 191  trainHaswell                   Haswell  3904000.0        61000
# 192  trainHaswell                   Haswell  3968000.0        62000
# 193  trainHaswell                   Haswell  4032000.0        63000
# 194  trainHaswell                   Haswell  4096000.0        64000
# 195  trainHaswell                   Haswell  4160000.0        65000
# 196  trainHaswell                   Haswell  4224000.0        66000
# 197  trainHaswell                   Haswell  4288000.0        67000
# 198  trainHaswell                   Haswell  4352000.0        68000
# 199  trainHaswell                   Haswell  4416000.0        69000
# 200  trainHaswell                   Haswell  4480000.0        70000
# 201  trainHaswell                   Haswell  4544000.0        71000
# 202  trainHaswell                   Haswell  4608000.0        72000
# 203  trainHaswell                   Haswell  4672000.0        73000
# 204  trainHaswell                   Haswell  4736000.0        74000
# 205  trainHaswell                   Haswell  4800000.0        75000
# 206  trainHaswell                   Haswell  4864000.0        76000
# 207  trainHaswell                   Haswell  4928000.0        77000
# 208  trainHaswell                   Haswell  4992000.0        78000
# 209  trainHaswell                   Haswell  5000000.0        78125
#
#                                                matcher  variable  bit_error  \
# 0    <Matcher quantity='cache', method='fr', values...  cache_fr   0.007120
# 1    <Matcher quantity='cache', method='fr', values...  cache_fr   0.007041
# 2    <Matcher quantity='cache', method='fr', values...  cache_fr   0.009810
# 3    <Matcher quantity='cache', method='fr', values...  cache_fr   0.008030
# 4    <Matcher quantity='cache', method='fr', values...  cache_fr   0.035912
# 5    <Matcher quantity='cache', method='fr', values...  cache_fr   0.073161
# 6    <Matcher quantity='cache', method='fr', values...  cache_fr   0.099684
# 7    <Matcher quantity='cache', method='fr', values...  cache_fr   0.125752
# 8    <Matcher quantity='cache', method='fr', values...  cache_fr   0.144541
# 9    <Matcher quantity='cache', method='fr', values...  cache_fr   0.232634
# 10   <Matcher quantity='cache', method='fr', values...  cache_fr   0.225712
# 11   <Matcher quantity='cache', method='fr', values...  cache_fr   0.258782
# 12   <Matcher quantity='cache', method='fr', values...  cache_fr   0.301842
# 13   <Matcher quantity='cache', method='fr', values...  cache_fr   0.296717
# 14   <Matcher quantity='cache', method='fr', values...  cache_fr   0.272607
# 15   <Matcher quantity='cache', method='fr', values...  cache_fr   0.266930
# 16   <Matcher quantity='cache', method='fr', values...  cache_fr   0.255582
# 17   <Matcher quantity='cache', method='fr', values...  cache_fr   0.252927
# 18   <Matcher quantity='cache', method='fr', values...  cache_fr   0.294877
# 19   <Matcher quantity='cache', method='fr', values...  cache_fr   0.341289
# 20   <Matcher quantity='cache', method='fr', values...  cache_fr   0.333089
# 21   <Matcher quantity='cache', method='fr', values...  cache_fr   0.323556
# 22   <Matcher quantity='cache', method='fr', values...  cache_fr   0.354015
# 23   <Matcher quantity='cache', method='fr', values...  cache_fr   0.342939
# 24   <Matcher quantity='cache', method='fr', values...  cache_fr   0.359652
# 25   <Matcher quantity='cache', method='fr', values...  cache_fr   0.005142
# 26   <Matcher quantity='cache', method='fr', values...  cache_fr   0.003956
# 27   <Matcher quantity='cache', method='fr', values...  cache_fr   0.004786
# 28   <Matcher quantity='cache', method='fr', values...  cache_fr   0.004351
# 29   <Matcher quantity='cache', method='fr', values...  cache_fr   0.003956
# ..                                                 ...       ...        ...
# 180  <Matcher quantity='cache', method='fr', values...  cache_fr   0.343555
# 181  <Matcher quantity='cache', method='fr', values...  cache_fr   0.367318
# 182  <Matcher quantity='cache', method='fr', values...  cache_fr   0.355859
# 183  <Matcher quantity='cache', method='fr', values...  cache_fr   0.396810
# 184  <Matcher quantity='cache', method='fr', values...  cache_fr   0.425977
# 185  <Matcher quantity='cache', method='fr', values...  cache_fr   0.346094
# 186  <Matcher quantity='cache', method='fr', values...  cache_fr   0.339909
# 187  <Matcher quantity='cache', method='fr', values...  cache_fr   0.400977
# 188  <Matcher quantity='cache', method='fr', values...  cache_fr   0.335742
# 189  <Matcher quantity='cache', method='fr', values...  cache_fr   0.387044
# 190  <Matcher quantity='cache', method='fr', values...  cache_fr   0.331120
# 191  <Matcher quantity='cache', method='fr', values...  cache_fr   0.334831
# 192  <Matcher quantity='cache', method='fr', values...  cache_fr   0.369141
# 193  <Matcher quantity='cache', method='fr', values...  cache_fr   0.387500
# 194  <Matcher quantity='cache', method='fr', values...  cache_fr   0.457617
# 195  <Matcher quantity='cache', method='fr', values...  cache_fr   0.357747
# 196  <Matcher quantity='cache', method='fr', values...  cache_fr   0.410091
# 197  <Matcher quantity='cache', method='fr', values...  cache_fr   0.381120
# 198  <Matcher quantity='cache', method='fr', values...  cache_fr   0.344271
# 199  <Matcher quantity='cache', method='fr', values...  cache_fr   0.356185
# 200  <Matcher quantity='cache', method='fr', values...  cache_fr   0.420312
# 201  <Matcher quantity='cache', method='fr', values...  cache_fr   0.398076
# 202  <Matcher quantity='cache', method='fr', values...  cache_fr   0.392708
# 203  <Matcher quantity='cache', method='fr', values...  cache_fr   0.370768
# 204  <Matcher quantity='cache', method='fr', values...  cache_fr   0.360742
# 205  <Matcher quantity='cache', method='fr', values...  cache_fr   0.395378
# 206  <Matcher quantity='cache', method='fr', values...  cache_fr   0.396224
# 207  <Matcher quantity='cache', method='fr', values...  cache_fr   0.400716
# 208  <Matcher quantity='cache', method='fr', values...  cache_fr   0.434310
# 209  <Matcher quantity='cache', method='fr', values...  cache_fr   0.398828
#
#      symbol_error
# 0        0.455696
# 1        0.443038
# 2        0.549367
# 3        0.501266
# 4        0.748644
# 5        0.844304
# 6        0.896203
# 7        0.967089
# 8        0.941772
# 9        1.000000
# 10       1.000000
# 11       1.000000
# 12       1.000000
# 13       1.000000
# 14       1.000000
# 15       1.000000
# 16       1.000000
# 17       1.000000
# 18       1.000000
# 19       1.000000
# 20       1.000000
# 21       0.994937
# 22       1.000000
# 23       1.000000
# 24       1.000000
# 25       0.329114
# 26       0.253165
# 27       0.306329
# 28       0.278481
# 29       0.253165
# ..            ...
# 180      1.000000
# 181      1.000000
# 182      1.000000
# 183      1.000000
# 184      1.000000
# 185      1.000000
# 186      1.000000
# 187      1.000000
# 188      0.991667
# 189      1.000000
# 190      0.991667
# 191      1.000000
# 192      1.000000
# 193      1.000000
# 194      1.000000
# 195      0.991667
# 196      1.000000
# 197      1.000000
# 198      1.000000
# 199      1.000000
# 200      1.000000
# 201      1.000000
# 202      1.000000
# 203      1.000000
# 204      1.000000
# 205      1.000000
# 206      1.000000
# 207      1.000000
# 208      1.000000
# 209      1.000000
#
# [210 rows x 9 columns]

# %% [markdown]
# 7. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 8. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = NB_CHANNEL.upper() + ("_INT_" if NB_EXPERIMENT_TYPE == "interference" else "")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        "./data/BER_{}_{}_{}.dat".format(PREFIX, eval_phase, env),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 9. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
