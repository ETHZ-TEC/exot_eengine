# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *

# %% [markdown]
# Parameters

# %%
NB_EXPERIMENT_TYPES = ["performance", "interference"]

# %% [markdown]
# __Notebook config__

# %%
# Names to configure
NB_EXPERIMENT_TYPE = "interference"
NB_CONFIG = "thermal"

# Generated names
NB_EXPERIMENT = f"{NB_CONFIG}-cc_{NB_EXPERIMENT_TYPE}"
NB_CHANNEL = "f" + NB_CONFIG.split("+")[-1][0]

# %%
print("NB_EXPERIMENT_TYPE ", NB_EXPERIMENT_TYPE)
print("NB_CONFIG          ", NB_CONFIG)
print("NB_EXPERIMENT      ", NB_EXPERIMENT)
# Out:
# NB_EXPERIMENT_TYPE  interference
# NB_CONFIG           thermal
# NB_EXPERIMENT       thermal-cc_interference

# %%
assert NB_EXPERIMENT_TYPE in NB_EXPERIMENT_TYPES

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

environments_to_execute = [
    "ARMv8",
    "Haswell"
]

phases = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}
# Out:
# name = "thermal-cc_interference"
# save_path = "./data"
# backup_path = "./data/_backup"
# experiment_exists_action = "move"
#
# [EXPERIMENT]
# type = "PerformanceExperiment"
# channel = "Thermal"
#
# [EXPERIMENT.GENERAL]
# latency = 10
# fan = true
# governors = "userspace"
# frequencies = "max"
# sampling_period = 0.001
# delay_after_spawn = 30.0
# delay_after_auxiliary = 1.0
# active_wait = false
#
# [EXPERIMENT.PHASES.trainShortARMv8]
# bit_count = 150
# symbol_rates = "list(range(1, 11, 2))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortARMv8]
# bit_count = 500
# symbol_rates = "list(range(1, 11, 2))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainARMv8]
# bit_count = 1500
# symbol_rates = "list(arange(1, 21, 1))"
# repetitions = 3
#
# [EXPERIMENT.PHASES.evalARMv8]
# bit_count = 5000
# symbol_rates = "list(arange(1, 21, 1))"
# repetitions = 3
#
# [EXPERIMENT.PHASES.trainShortHaswell]
# bit_count = 500
# symbol_rates = "list(range(10, 201, 10))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortHaswell]
# bit_count = 1000
# symbol_rates = "list(range(10, 201, 10))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainHaswell]
# bit_count = 1500
# symbol_rates = "list(range(5, 301, 5))"
# repetitions = 3
#
# [EXPERIMENT.PHASES.evalHaswell]
# bit_count = 5000
# symbol_rates = "list(range(5, 301, 5))"
# repetitions = 3
#
# [EXPERIMENT.LAYERS.src]
# name = "SourcePassthrough"
#
# [EXPERIMENT.LAYERS.lne]
# name = "ManchesterLineCoding"
#
# [EXPERIMENT.LAYERS.rdp]
# name = "CoreActivation"
#
# [EXPERIMENT.LAYERS.io]
# name = "TimeValue"
#
# [EXPERIMENT.GENERAL.ARMv8]
# fan = "255"
# delay_after_spawn = 120.0
#
# [EXPERIMENT.LAYERS.src.params]
#
# [EXPERIMENT.LAYERS.lne.params]
#
# [EXPERIMENT.LAYERS.rdp.params]
#
# [EXPERIMENT.LAYERS.io.params]
# timebase = "ns"
#
# [ENVIRONMENTS.Haswell.APPS.snk]
# executable = "meter_thermal_msr"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.APPS.src]
# executable = "generator_utilisation_mt"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.APPS.ffmpeg]
# executable = "ffmpeg"
# type = "standalone"
# start_individually = true
# zone = "host"
# args = [ "-y", "-loglevel", "error", "-stream_loop", "-1", "-i", "media/video.mp4", "-c:v", "libx264", "-b:v", "1000k", "-f", "null", "/dev/null",]
#
# [ENVIRONMENTS.Haswell.src.generator]
# cpu_to_pin = 0
# cores = [ 1, 3, 5, 7,]
# policy = "round_robin"
# priority = 99
# worker_priority = 98
# start_check_period = 25
#
# [ENVIRONMENTS.Haswell.src.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.Haswell.src.schedule_reader]
# input_file = ""
# reading_from_file = true
#
# [ENVIRONMENTS.Haswell.snk.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.Haswell.snk.thermal_msr]
# cores = [ 0, 2, 4, 6,]
# package = false
#
# [ENVIRONMENTS.Haswell.snk.host]
# period = 0.001
# policy = "round_robin"
# pinning = 0
# priority = 90
# log_header = true
# start_immediately = false
# start_check_period = 25
#
# [ENVIRONMENTS.ARMv8.APPS.snk]
# executable = "meter_thermal_sysfs"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.APPS.src]
# executable = "generator_utilisation_mt"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.APPS.ffmpeg]
# executable = "ffmpeg"
# type = "standalone"
# start_individually = true
# zone = "combined"
# args = [ "-y", "-loglevel", "error", "-stream_loop", "-1", "-i", "media/video.mp4", "-c:v", "libx264", "-b:v", "1000k", "-f", "null", "/dev/null",]
#
# [ENVIRONMENTS.ARMv8.src.generator]
# cpu_to_pin = 5
# cores = [ 0, 1, 2, 3, 4,]
# policy = "round_robin"
# priority = 99
# worker_priority = 98
# start_check_period = 25
#
# [ENVIRONMENTS.ARMv8.src.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.ARMv8.src.schedule_reader]
# input_file = ""
# reading_from_file = true
#
# [ENVIRONMENTS.ARMv8.snk.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.ARMv8.snk.thermal_sysfs]
# zones = [ 0, 1, 2, 3, 4, 5, 6, 7,]
#
# [ENVIRONMENTS.ARMv8.snk.host]
# period = 0.001
# policy = "round_robin"
# pinning = 5
# priority = 90
# log_header = true
# start_immediately = false
# start_check_period = 25

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
raise Exception("Are you sure?")

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = experiment._execution_status

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    experiment.execute_in_environment(env, phases[env]['short'], resume=False)
    experiment.execute_in_environment(env, phases[env]['normal'], resume=False)
experiment.write()

# %% [markdown]
# ## Analyse

# %% [markdown]
# 1. Define which class of experiments to analyse (short of normal length)

# %%
SHORT = False

# %% [markdown]
# 2. Check data collection status

# %%
for _experiment in [NB_EXPERIMENT]:
    for _platform, _phase_mapping in phases.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0].strip(), "logs:", _logs[0].strip(), sep=" ")
# Out:
# experiment: thermal-cc_interference platform: ARMv8 phase: trainShortARMv8 folders: 0 logs: 0
# experiment: thermal-cc_interference platform: ARMv8 phase: evalShortARMv8 folders: 0 logs: 0
# experiment: thermal-cc_interference platform: ARMv8 phase: trainARMv8 folders: 20 logs: 120
# experiment: thermal-cc_interference platform: ARMv8 phase: evalARMv8 folders: 20 logs: 120
# experiment: thermal-cc_interference platform: Haswell phase: trainShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_interference platform: Haswell phase: evalShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_interference platform: Haswell phase: trainHaswell folders: 60 logs: 360
# experiment: thermal-cc_interference platform: Haswell phase: evalHaswell folders: 60 logs: 360

# %% [markdown]
# 3. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
# Out:
# 2019-09-11 07:24:03 :: unpicked an experiment instance <PerformanceExperiment at 0x7f7ba6e18a20 with Thermal channel, configured>
# 2019-09-11 07:24:03 :: git commit of unpickled experiment repo '4a0bdefb' does not match the commit in which the unpickling was performed 'eb068d1e'

# %% [markdown]
# 4. Specify the demo run and visualise

# %%
DEMO_PHASE = "trainHaswell"
DEMO_ID = 0
DEMO_ARM = "ARM" in DEMO_PHASE

# %%
ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io=(
        {
            "env": "ARMv8",
            "rep": 0,
            "matcher": exot.util.wrangle.Matcher("thermal", "sysfs", ["zone"], [0]),
        }
        if DEMO_ARM
        else {
            "env": "Haswell",
            "rep": 0,
            "matcher": exot.util.wrangle.Matcher("thermal", "msr", ["core"], [0, 2, 4, 6]),
            "combine": "max",
        }
    ),
)

# %%
demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream()
    plotter.plot_rdpstream(end=10)
    plotter.plot_slicing()
    plotter.plot_symstream()
    plotter.plot_eye_diagram()
    plotter.plot_symbol_space()
    plotter.plot_error()

# %% [markdown]
# 5. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "short" if SHORT else "normal"

analysis_args = {
    "ARMv8": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={"matcher": exot.util.wrangle.Matcher("thermal", "sysfs", ["zone"], [0])},
    ),
    "Haswell": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={
            "matcher": exot.util.wrangle.Matcher("thermal", "msr", ["core"], [0, 2, 4, 6]),
            "combine": "max",
        },
    ),
}

phase_mappings = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}

# %% [markdown]
# 6. Calculate the performance metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        **analysis_args[env],
    )
# Out:
# 2019-09-11 07:25:21 :: analysing performance for phases: trainARMv8 -> evalARMv8
# 2019-09-11 07:25:21 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:26:04 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:26:25 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:26:41 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:26:54 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:27:11 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:27:20 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:27:30 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:27:39 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:27:52 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:28:01 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:28:10 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:28:18 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:28:26 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:28:37 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:28:47 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:28:55 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:29:01 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:29:09 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:29:16 :: \_ analysing performance for env: ARMv8
# 2019-09-11 07:29:22 :: analysing performance for phases: trainHaswell -> evalHaswell
# 2019-09-11 07:29:23 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:29:36 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:29:48 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:30:18 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:30:45 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:30:59 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:31:11 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:31:19 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:31:28 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:31:37 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:31:47 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:01 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:07 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:19 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:24 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:29 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:34 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:39 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:44 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:49 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:54 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:32:59 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:04 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:13 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:20 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:37 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:42 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:47 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:52 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:33:57 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:02 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:08 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:13 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:26 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:33 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:37 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:43 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:49 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:34:53 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:00 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:17 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:22 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:28 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:37 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:43 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:52 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:35:58 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:18 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:24 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:28 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:34 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:38 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:42 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:49 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:53 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:36:59 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:37:03 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:37:08 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:37:14 :: \_ analysing performance for env: Haswell
# 2019-09-11 07:37:20 :: \_ analysing performance for env: Haswell

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#         phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  trainARMv8                    ARMv8       1.0            1           0
# 1   evalARMv8   trainARMv8       ARMv8       1.0            1           0
# 2  trainARMv8                    ARMv8       1.0            1           1
# 3   evalARMv8   trainARMv8       ARMv8       1.0            1           1
# 4  trainARMv8                    ARMv8       1.0            1           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.036667      0.036667  <Matcher quantity='thermal', method='sysfs', v...
# 1   0.040600      0.040600  <Matcher quantity='thermal', method='sysfs', v...
# 2   0.030667      0.030667  <Matcher quantity='thermal', method='sysfs', v...
# 3   0.035000      0.035000  <Matcher quantity='thermal', method='sysfs', v...
# 4   0.032000      0.032000  <Matcher quantity='thermal', method='sysfs', v...
#
#         variable
# 0  thermal_sysfs
# 1  thermal_sysfs
# 2  thermal_sysfs
# 3  thermal_sysfs
# 4  thermal_sysfs

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
<Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 1    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 2    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 3    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 4    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 5    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 6    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 7    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 8    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 9    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 10   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 11   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 12   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 13   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 14   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 15   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 16   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 17   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 18   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 19   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 20   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 21   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 22   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 23   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 24   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 25   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 26   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 27   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 28   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 29   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# ..                                                 ...            ...
# 130  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 131  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 132  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 133  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 134  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 135  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 136  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 137  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 138  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 139  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 140  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 141  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 142  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 143  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 144  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 145  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 146  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 147  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 148  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 149  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 150  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 151  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 152  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 153  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 154  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 155  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 156  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 157  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 158  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 159  <Matcher quantity='thermal', method='msr', val...    thermal_msr
#
#      bit_error  symbol_error
# 0     0.038067      0.038067
# 1     0.084267      0.084267
# 2     0.153933      0.153933
# 3     0.218467      0.218467
# 4     0.273733      0.273733
# 5     0.294733      0.294733
# 6     0.332867      0.332867
# 7     0.362800      0.362800
# 8     0.381267      0.381267
# 9     0.400400      0.400400
# 10    0.429000      0.429000
# 11    0.451067      0.451067
# 12    0.446600      0.446600
# 13    0.454133      0.454133
# 14    0.461667      0.461667
# 15    0.468467      0.468467
# 16    0.466000      0.466000
# 17    0.472533      0.472533
# 18    0.476400      0.476400
# 19    0.481067      0.481067
# 20    0.191600      0.191600
# 21    0.260933      0.260933
# 22    0.268467      0.268467
# 23    0.247800      0.247800
# 24    0.259400      0.259400
# 25    0.295333      0.295333
# 26    0.313800      0.313800
# 27    0.345467      0.345467
# 28    0.364733      0.364733
# 29    0.387000      0.387000
# ..         ...           ...
# 130   0.467778      0.467778
# 131   0.464000      0.464000
# 132   0.460000      0.460000
# 133   0.464667      0.464667
# 134   0.481333      0.481333
# 135   0.472000      0.472000
# 136   0.471556      0.471556
# 137   0.487556      0.487556
# 138   0.472000      0.472000
# 139   0.456000      0.456000
# 140   0.464444      0.464444
# 141   0.476889      0.476889
# 142   0.476222      0.476222
# 143   0.475111      0.475111
# 144   0.471556      0.471556
# 145   0.488667      0.488667
# 146   0.476000      0.476000
# 147   0.474222      0.474222
# 148   0.472889      0.472889
# 149   0.472222      0.472222
# 150   0.465778      0.465778
# 151   0.484000      0.484000
# 152   0.480000      0.480000
# 153   0.482000      0.482000
# 154   0.476444      0.476444
# 155   0.479333      0.479333
# 156   0.483778      0.483778
# 157   0.463333      0.463333
# 158   0.481556      0.481556
# 159   0.483556      0.483556
#
# [160 rows x 9 columns]

# %% [markdown]
# 7. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 8. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = "TH" + ("_INT_" if NB_EXPERIMENT_TYPE == "interference" else "")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        "./data/BER_{}_{}_{}.dat".format(PREFIX, eval_phase, env),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 9. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
