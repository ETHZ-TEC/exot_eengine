# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *

# %% [markdown]
# Parameters

# %%
NB_EXPERIMENT_TYPES = ["performance", "interference"]
NB_CHANNELS = ["ff", "fp", "fr"]
NB_CONFIGS = ["flush+flush", "flush+prefetch", "flush+reload"]

# %% [markdown]
# #### Notebook config

# %%
# Names to configure
NB_EXPERIMENT_TYPE = "performance"
NB_CONFIG = "flush+prefetch"

# Generated names
NB_EXPERIMENT = f"{NB_CONFIG}-cc_{NB_EXPERIMENT_TYPE}"
NB_CHANNEL = "f" + NB_CONFIG.split("+")[-1][0]

# %%
print("NB_CHANNEL         ", NB_CHANNEL)
print("NB_EXPERIMENT_TYPE ", NB_EXPERIMENT_TYPE)
print("NB_CONFIG          ", NB_CONFIG)
print("NB_EXPERIMENT      ", NB_EXPERIMENT)
# Out:
# NB_CHANNEL          fp
# NB_EXPERIMENT_TYPE  performance
# NB_CONFIG           flush+prefetch
# NB_EXPERIMENT       flush+prefetch-cc_performance

# %%
assert NB_EXPERIMENT_TYPE in NB_EXPERIMENT_TYPES
assert NB_CHANNEL in NB_CHANNELS
assert NB_CONFIG in NB_CONFIGS

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

environments_to_execute = [
    "ARMv8",
    "Haswell"
]

phases = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}
# Out:
# name = "flush+prefetch-cc_performance"
# save_path = "./data"
# backup_path = "./data/_backup"
# experiment_exists_action = "move"
#
# [EXPERIMENT]
# type = "PerformanceExperiment"
# channel = "Cache"
#
# [EXPERIMENT.GENERAL]
# latency = 10
# fan = true
# governors = "userspace"
# frequencies = "max"
# sampling_period = 2e-5
# delay_after_spawn = 5.0
# delay_after_auxiliary = 1.0
# active_wait = false
#
# [EXPERIMENT.PHASES.trainShortARMv8]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(500, 6001, 500)))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortARMv8]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(500, 6001, 500)))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainARMv8]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(250, 6001, 250)))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalARMv8]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(250, 6001, 250)))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.trainShortHaswell]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(10000, 78001, 10000)) + [78125])"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortHaswell]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(10000, 78001, 10000)) + [78125])"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainHaswell]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(1000, 78001, 1000))  + [78125])"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalHaswell]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(1000, 78001, 1000))  + [78125])"
# repetitions = 5
#
# [EXPERIMENT.LAYERS.src]
# name = "BitsetCoding"
#
# [EXPERIMENT.LAYERS.lne]
# name = "MultiN"
#
# [EXPERIMENT.LAYERS.rdp]
# name = "DirectActivation"
#
# [EXPERIMENT.LAYERS.io]
# name = "TimeValue"
#
# [EXPERIMENT.GENERAL.ARMv8]
# fan = "255"
# sampling_period = 0.000225
#
# [EXPERIMENT.LAYERS.src.params]
# bitset_length = 64
#
# [EXPERIMENT.LAYERS.lne.params]
# N = 64
#
# [EXPERIMENT.LAYERS.rdp.params]
#
# [EXPERIMENT.LAYERS.io.params]
# timebase = "ns"
#
# [ENVIRONMENTS.Haswell.APPS.snk]
# executable = "meter_cache_fp"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.APPS.src]
# executable = "generator_cache_read_st"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.src.generator]
# cpu_to_pin = 3
# cores = [ 0,]
# worker_policy = "round_robin"
# self_policy = "round_robin"
# worker_priority = 98
# self_priority = 97
# use_busy_sleep = true
# busy_sleep_yield = false
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 64
#
# [ENVIRONMENTS.Haswell.src.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = false
#
# [ENVIRONMENTS.Haswell.src.schedule_reader]
# reading_from_file = true
#
# [ENVIRONMENTS.Haswell.snk.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = true
# rotating_logs = false
# rotating_logs_count = 10
# rotating_logs_size = 104857600
# timestamp_files = false
#
# [ENVIRONMENTS.Haswell.snk.host]
# policy = "round_robin"
# pinning = 7
# priority = 95
# log_header = true
# start_immediately = false
# use_busy_sleep = true
# busy_sleep_yield = false
#
# [ENVIRONMENTS.Haswell.snk.cache]
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 64
#
# [ENVIRONMENTS.ARMv8.APPS.snk]
# executable = "meter_cache_fp"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.APPS.src]
# executable = "generator_cache_read_st"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.src.generator]
# cpu_to_pin = 2
# cores = [ 0,]
# worker_policy = "round_robin"
# self_policy = "round_robin"
# worker_priority = 98
# self_priority = 97
# use_busy_sleep = true
# busy_sleep_yield = false
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 16
#
# [ENVIRONMENTS.ARMv8.src.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = false
#
# [ENVIRONMENTS.ARMv8.src.schedule_reader]
# reading_from_file = true
#
# [ENVIRONMENTS.ARMv8.snk.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = true
# rotating_logs = false
# rotating_logs_count = 10
# rotating_logs_size = 104857600
# timestamp_files = false
#
# [ENVIRONMENTS.ARMv8.snk.host]
# policy = "round_robin"
# pinning = 3
# priority = 95
# log_header = true
# start_immediately = false
# use_busy_sleep = true
# busy_sleep_yield = false
#
# [ENVIRONMENTS.ARMv8.snk.cache]
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 16

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
raise Exception("Are you sure?")

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = getattr(experiment, "_execution_status", {})

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    experiment.execute_in_environment(env, phases[env]['short'], resume=False)
    experiment.execute_in_environment(env, phases[env]['normal'], resume=False)
experiment.write()

# %% [markdown]
# ## Analyse

# %% [markdown]
# 1. Define which class of experiments to analyse (short of normal length)

# %%
SHORT = False

# %% [markdown]
# 2. Check data collection status

# %%
for _experiment in [NB_EXPERIMENT]:
    for _platform, _phase_mapping in phases.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0].strip(), "logs:", _logs[0].strip(), sep=" ")
# Out:
# experiment: flush+prefetch-cc_performance platform: ARMv8 phase: trainShortARMv8 folders: 13 logs: 52
# experiment: flush+prefetch-cc_performance platform: ARMv8 phase: evalShortARMv8 folders: 13 logs: 52
# experiment: flush+prefetch-cc_performance platform: ARMv8 phase: trainARMv8 folders: 25 logs: 250
# experiment: flush+prefetch-cc_performance platform: ARMv8 phase: evalARMv8 folders: 25 logs: 250
# experiment: flush+prefetch-cc_performance platform: Haswell phase: trainShortHaswell folders: 9 logs: 36
# experiment: flush+prefetch-cc_performance platform: Haswell phase: evalShortHaswell folders: 9 logs: 36
# experiment: flush+prefetch-cc_performance platform: Haswell phase: trainHaswell folders: 80 logs: 800
# experiment: flush+prefetch-cc_performance platform: Haswell phase: evalHaswell folders: 80 logs: 800

# %% [markdown]
# 3. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
# Out:
# 2019-09-10 13:31:28 :: unpicked an experiment instance <PerformanceExperiment at 0x7fbde8e12588 with Cache channel, configured>
# 2019-09-10 13:31:29 :: git commit of unpickled experiment repo '89c78965' does not match the commit in which the unpickling was performed '50fd78bb'

# %% [markdown]
# 4. Specify the demo run and visualise

# %%
DEMO_PHASE = "trainShortARMv8"
DEMO_ID = 0
DEMO_ARM = "ARM" in DEMO_PHASE

# %%
ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]}
    if DEMO_ARM
    else {},
    io={
        "env": "ARMv8" if DEMO_ARM else "Haswell",
        "rep": 0,
        "matcher": exot.util.wrangle.Matcher("cache", NB_CHANNEL, ["access_time"], list(range(64))),
    },
)

# %%
demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

# %%
with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream(dim_count=2)
    plotter.plot_rdpstream(end=5.0, dim_count=2)
    plotter.plot_slicing(dim_count=2)
    plotter.plot_eye_diagram()
    plotter.plot_symbol_space()
    plotter.plot_error()
    plotter.plot_timing()

# %% [markdown]
# 5. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "short" if SHORT else "normal"

analysis_args = {
    "ARMv8": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]},
        io={
            "matcher": exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            )
        },
    ),
    "Haswell": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={
            "matcher": exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            )
        },
    ),
}

phase_mappings = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}

# %% [markdown]
# _Calculate the performance metrics_

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        **analysis_args[env],
    )
# Out:
# 2019-09-10 13:32:47 :: analysing performance for phases: trainARMv8 -> evalARMv8
# 2019-09-10 13:32:47 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:32:54 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:00 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:08 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:16 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:23 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:29 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:35 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:41 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:49 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:33:56 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:02 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:10 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:17 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:24 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:32 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:39 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:46 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:53 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:34:59 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:35:06 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:35:13 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:35:20 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:35:27 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:35:33 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:35:41 :: analysing performance for phases: trainHaswell -> evalHaswell
# 2019-09-10 13:35:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:52 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:59 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:57 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:25 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:39 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:59 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:09 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:18 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:31 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:25 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:57 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:04 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:19 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:44 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:52 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:59 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:44:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:44:16 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:44:23 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:44:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:44:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:44:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:45:04 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:45:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:45:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:45:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:45:44 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:45:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:46:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:46:13 :: \_ analysing performance for env: Haswell

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#         phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  trainARMv8                    ARMv8    6400.0          100           0
# 1   evalARMv8   trainARMv8       ARMv8    6400.0          100           0
# 2  trainARMv8                    ARMv8    6400.0          100           1
# 3   evalARMv8   trainARMv8       ARMv8    6400.0          100           1
# 4  trainARMv8                    ARMv8    6400.0          100           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.007812      0.500000  <Matcher quantity='cache', method='fp', values...
# 1   0.008505      0.544304  <Matcher quantity='cache', method='fp', values...
# 2   0.007812      0.500000  <Matcher quantity='cache', method='fp', values...
# 3   0.008505      0.544304  <Matcher quantity='cache', method='fp', values...
# 4   0.007812      0.500000  <Matcher quantity='cache', method='fp', values...
#
#    variable
# 0  cache_fp
# 1  cache_fp
# 2  cache_fp
# 3  cache_fp
# 4  cache_fp

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#             phase  trained_with environment   bit_rate  symbol_rate  \
# 0       evalARMv8    trainARMv8       ARMv8     6400.0          100
# 1       evalARMv8    trainARMv8       ARMv8    16000.0          250
# 2       evalARMv8    trainARMv8       ARMv8    32000.0          500
# 3       evalARMv8    trainARMv8       ARMv8    48000.0          750
# 4       evalARMv8    trainARMv8       ARMv8    64000.0         1000
# 5       evalARMv8    trainARMv8       ARMv8    80000.0         1250
# 6       evalARMv8    trainARMv8       ARMv8    96000.0         1500
# 7       evalARMv8    trainARMv8       ARMv8   112000.0         1750
# 8       evalARMv8    trainARMv8       ARMv8   128000.0         2000
# 9       evalARMv8    trainARMv8       ARMv8   144000.0         2250
# 10      evalARMv8    trainARMv8       ARMv8   160000.0         2500
# 11      evalARMv8    trainARMv8       ARMv8   176000.0         2750
# 12      evalARMv8    trainARMv8       ARMv8   192000.0         3000
# 13      evalARMv8    trainARMv8       ARMv8   208000.0         3250
# 14      evalARMv8    trainARMv8       ARMv8   224000.0         3500
# 15      evalARMv8    trainARMv8       ARMv8   240000.0         3750
# 16      evalARMv8    trainARMv8       ARMv8   256000.0         4000
# 17      evalARMv8    trainARMv8       ARMv8   272000.0         4250
# 18      evalARMv8    trainARMv8       ARMv8   288000.0         4500
# 19      evalARMv8    trainARMv8       ARMv8   304000.0         4750
# 20      evalARMv8    trainARMv8       ARMv8   320000.0         5000
# 21      evalARMv8    trainARMv8       ARMv8   336000.0         5250
# 22      evalARMv8    trainARMv8       ARMv8   352000.0         5500
# 23      evalARMv8    trainARMv8       ARMv8   368000.0         5750
# 24      evalARMv8    trainARMv8       ARMv8   384000.0         6000
# 25    evalHaswell  trainHaswell     Haswell     6400.0          100
# 26    evalHaswell  trainHaswell     Haswell    64000.0         1000
# 27    evalHaswell  trainHaswell     Haswell   128000.0         2000
# 28    evalHaswell  trainHaswell     Haswell   192000.0         3000
# 29    evalHaswell  trainHaswell     Haswell   256000.0         4000
# ..            ...           ...         ...        ...          ...
# 180  trainHaswell                   Haswell  3200000.0        50000
# 181  trainHaswell                   Haswell  3264000.0        51000
# 182  trainHaswell                   Haswell  3328000.0        52000
# 183  trainHaswell                   Haswell  3392000.0        53000
# 184  trainHaswell                   Haswell  3456000.0        54000
# 185  trainHaswell                   Haswell  3520000.0        55000
# 186  trainHaswell                   Haswell  3584000.0        56000
# 187  trainHaswell                   Haswell  3648000.0        57000
# 188  trainHaswell                   Haswell  3712000.0        58000
# 189  trainHaswell                   Haswell  3776000.0        59000
# 190  trainHaswell                   Haswell  3840000.0        60000
# 191  trainHaswell                   Haswell  3904000.0        61000
# 192  trainHaswell                   Haswell  3968000.0        62000
# 193  trainHaswell                   Haswell  4032000.0        63000
# 194  trainHaswell                   Haswell  4096000.0        64000
# 195  trainHaswell                   Haswell  4160000.0        65000
# 196  trainHaswell                   Haswell  4224000.0        66000
# 197  trainHaswell                   Haswell  4288000.0        67000
# 198  trainHaswell                   Haswell  4352000.0        68000
# 199  trainHaswell                   Haswell  4416000.0        69000
# 200  trainHaswell                   Haswell  4480000.0        70000
# 201  trainHaswell                   Haswell  4544000.0        71000
# 202  trainHaswell                   Haswell  4608000.0        72000
# 203  trainHaswell                   Haswell  4672000.0        73000
# 204  trainHaswell                   Haswell  4736000.0        74000
# 205  trainHaswell                   Haswell  4800000.0        75000
# 206  trainHaswell                   Haswell  4864000.0        76000
# 207  trainHaswell                   Haswell  4928000.0        77000
# 208  trainHaswell                   Haswell  4992000.0        78000
# 209  trainHaswell                   Haswell  5000000.0        78125
#
#                                                matcher  variable  bit_error  \
# 0    <Matcher quantity='cache', method='fp', values...  cache_fp   0.008505
# 1    <Matcher quantity='cache', method='fp', values...  cache_fp   0.009375
# 2    <Matcher quantity='cache', method='fp', values...  cache_fp   0.008742
# 3    <Matcher quantity='cache', method='fp', values...  cache_fp   0.008900
# 4    <Matcher quantity='cache', method='fp', values...  cache_fp   0.012342
# 5    <Matcher quantity='cache', method='fp', values...  cache_fp   0.095372
# 6    <Matcher quantity='cache', method='fp', values...  cache_fp   0.072271
# 7    <Matcher quantity='cache', method='fp', values...  cache_fp   0.143078
# 8    <Matcher quantity='cache', method='fp', values...  cache_fp   0.136076
# 9    <Matcher quantity='cache', method='fp', values...  cache_fp   0.219304
# 10   <Matcher quantity='cache', method='fp', values...  cache_fp   0.250791
# 11   <Matcher quantity='cache', method='fp', values...  cache_fp   0.220688
# 12   <Matcher quantity='cache', method='fp', values...  cache_fp   0.268434
# 13   <Matcher quantity='cache', method='fp', values...  cache_fp   0.264082
# 14   <Matcher quantity='cache', method='fp', values...  cache_fp   0.269976
# 15   <Matcher quantity='cache', method='fp', values...  cache_fp   0.264715
# 16   <Matcher quantity='cache', method='fp', values...  cache_fp   0.302650
# 17   <Matcher quantity='cache', method='fp', values...  cache_fp   0.331764
# 18   <Matcher quantity='cache', method='fp', values...  cache_fp   0.313014
# 19   <Matcher quantity='cache', method='fp', values...  cache_fp   0.358386
# 20   <Matcher quantity='cache', method='fp', values...  cache_fp   0.332199
# 21   <Matcher quantity='cache', method='fp', values...  cache_fp   0.369146
# 22   <Matcher quantity='cache', method='fp', values...  cache_fp   0.299723
# 23   <Matcher quantity='cache', method='fp', values...  cache_fp   0.354826
# 24   <Matcher quantity='cache', method='fp', values...  cache_fp   0.342445
# 25   <Matcher quantity='cache', method='fp', values...  cache_fp   0.004153
# 26   <Matcher quantity='cache', method='fp', values...  cache_fp   0.005340
# 27   <Matcher quantity='cache', method='fp', values...  cache_fp   0.006329
# 28   <Matcher quantity='cache', method='fp', values...  cache_fp   0.003362
# 29   <Matcher quantity='cache', method='fp', values...  cache_fp   0.004351
# ..                                                 ...       ...        ...
# 180  <Matcher quantity='cache', method='fp', values...  cache_fp   0.276302
# 181  <Matcher quantity='cache', method='fp', values...  cache_fp   0.345443
# 182  <Matcher quantity='cache', method='fp', values...  cache_fp   0.390625
# 183  <Matcher quantity='cache', method='fp', values...  cache_fp   0.350000
# 184  <Matcher quantity='cache', method='fp', values...  cache_fp   0.372917
# 185  <Matcher quantity='cache', method='fp', values...  cache_fp   0.357682
# 186  <Matcher quantity='cache', method='fp', values...  cache_fp   0.332682
# 187  <Matcher quantity='cache', method='fp', values...  cache_fp   0.335417
# 188  <Matcher quantity='cache', method='fp', values...  cache_fp   0.307031
# 189  <Matcher quantity='cache', method='fp', values...  cache_fp   0.424479
# 190  <Matcher quantity='cache', method='fp', values...  cache_fp   0.390755
# 191  <Matcher quantity='cache', method='fp', values...  cache_fp   0.336068
# 192  <Matcher quantity='cache', method='fp', values...  cache_fp   0.393880
# 193  <Matcher quantity='cache', method='fp', values...  cache_fp   0.342578
# 194  <Matcher quantity='cache', method='fp', values...  cache_fp   0.380729
# 195  <Matcher quantity='cache', method='fp', values...  cache_fp   0.439193
# 196  <Matcher quantity='cache', method='fp', values...  cache_fp   0.341016
# 197  <Matcher quantity='cache', method='fp', values...  cache_fp   0.310286
# 198  <Matcher quantity='cache', method='fp', values...  cache_fp   0.380208
# 199  <Matcher quantity='cache', method='fp', values...  cache_fp   0.392057
# 200  <Matcher quantity='cache', method='fp', values...  cache_fp   0.376953
# 201  <Matcher quantity='cache', method='fp', values...  cache_fp   0.386458
# 202  <Matcher quantity='cache', method='fp', values...  cache_fp   0.386719
# 203  <Matcher quantity='cache', method='fp', values...  cache_fp   0.374740
# 204  <Matcher quantity='cache', method='fp', values...  cache_fp   0.384245
# 205  <Matcher quantity='cache', method='fp', values...  cache_fp   0.399089
# 206  <Matcher quantity='cache', method='fp', values...  cache_fp   0.345833
# 207  <Matcher quantity='cache', method='fp', values...  cache_fp   0.415104
# 208  <Matcher quantity='cache', method='fp', values...  cache_fp   0.398307
# 209  <Matcher quantity='cache', method='fp', values...  cache_fp   0.431510
#
#      symbol_error
# 0        0.544304
# 1        0.582278
# 2        0.506329
# 3        0.445570
# 4        0.625316
# 5        0.913924
# 6        0.878481
# 7        0.974684
# 8        0.944304
# 9        1.000000
# 10       1.000000
# 11       0.992405
# 12       1.000000
# 13       1.000000
# 14       0.997468
# 15       1.000000
# 16       0.997468
# 17       0.997468
# 18       1.000000
# 19       1.000000
# 20       1.000000
# 21       1.000000
# 22       1.000000
# 23       1.000000
# 24       1.000000
# 25       0.265823
# 26       0.341772
# 27       0.405063
# 28       0.215190
# 29       0.278481
# ..            ...
# 180      1.000000
# 181      1.000000
# 182      1.000000
# 183      1.000000
# 184      1.000000
# 185      1.000000
# 186      1.000000
# 187      0.991667
# 188      1.000000
# 189      1.000000
# 190      1.000000
# 191      1.000000
# 192      1.000000
# 193      1.000000
# 194      1.000000
# 195      1.000000
# 196      1.000000
# 197      1.000000
# 198      1.000000
# 199      1.000000
# 200      1.000000
# 201      1.000000
# 202      1.000000
# 203      1.000000
# 204      1.000000
# 205      1.000000
# 206      0.991667
# 207      1.000000
# 208      1.000000
# 209      1.000000
#
# [210 rows x 9 columns]

# %% [markdown]
# 7. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 8. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = NB_CHANNEL.upper() + ("_INT_" if NB_EXPERIMENT_TYPE == "interference" else "")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        "./data/BER_{}_{}_{}.dat".format(PREFIX, eval_phase, env),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 9. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
