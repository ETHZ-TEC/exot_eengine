# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *
# Out:
# Tensorflow not available - excluding packets relying on it!

# %% [markdown]
# Parameters

# %%
NB_EXPERIMENT_TYPES = ["performance", "interference"]
NB_CHANNELS = ["ff", "fp", "fr"]
NB_CONFIGS = ["flush+flush", "flush+prefetch", "flush+reload"]

# %% [markdown]
# #### Notebook config

# %%
# Names to configure
NB_EXPERIMENT_TYPE = "performance"
NB_CONFIG = "flush+prefetch"

# Generated names
NB_EXPERIMENT = f"{NB_CONFIG}-cc_{NB_EXPERIMENT_TYPE}"
NB_CHANNEL = "f" + NB_CONFIG.split("+")[-1][0]

# %%
print("NB_CHANNEL         ", NB_CHANNEL)
print("NB_EXPERIMENT_TYPE ", NB_EXPERIMENT_TYPE)
print("NB_CONFIG          ", NB_CONFIG)
print("NB_EXPERIMENT      ", NB_EXPERIMENT)
# Out:
# NB_CHANNEL          fp
# NB_EXPERIMENT_TYPE  performance
# NB_CONFIG           flush+prefetch
# NB_EXPERIMENT       flush+prefetch-cc_performance

# %%
assert NB_EXPERIMENT_TYPE in NB_EXPERIMENT_TYPES
assert NB_CHANNEL in NB_CHANNELS
assert NB_CONFIG in NB_CONFIGS

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

environments_to_execute = [
    "ARMv8",
    "Haswell"
]

phases = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}
# Out:
# name = "flush+prefetch-cc_performance"
# save_path = "./data"
# backup_path = "./data/_backup"
# experiment_exists_action = "move"
#
# [EXPERIMENT]
# type = "PerformanceExperiment"
# channel = "FlushPrefetchCC"
#
# [EXPERIMENT.GENERAL]
# latency = 10
# fan = true
# governors = "userspace"
# frequencies = "max"
# sampling_period = 2e-5
# delay_after_spawn = 5.0
# delay_after_auxiliary = 1.0
# active_wait = false
#
# [EXPERIMENT.PHASES.trainShortARMv8]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(500, 6001, 500)))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortARMv8]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(500, 6001, 500)))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainARMv8]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(250, 6001, 250)))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalARMv8]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(250, 6001, 250)))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.trainShortHaswell]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(10000, 78001, 10000)) + [78125])"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortHaswell]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(10000, 78001, 10000)) + [78125])"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainHaswell]
# bit_count = 1500
# symbol_rates = "[100] + (list(range(1000, 78001, 1000))  + [78125])"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalHaswell]
# bit_count = 5000
# symbol_rates = "[100] + (list(range(1000, 78001, 1000))  + [78125])"
# repetitions = 5
#
# [EXPERIMENT.LAYERS.src]
# name = "BitsetCoding"
#
# [EXPERIMENT.LAYERS.lne]
# name = "MultiN"
#
# [EXPERIMENT.LAYERS.rdp]
# name = "DirectActivation"
#
# [EXPERIMENT.LAYERS.io]
# name = "TimeValue"
#
# [EXPERIMENT.GENERAL.ARMv8]
# fan = "255"
# sampling_period = 0.000225
#
# [EXPERIMENT.LAYERS.src.params]
# bitset_length = 64
#
# [EXPERIMENT.LAYERS.lne.params]
# N = 64
#
# [EXPERIMENT.LAYERS.rdp.params]
#
# [EXPERIMENT.LAYERS.io.params]
# timebase = "ns"
#
# [ENVIRONMENTS.Haswell.APPS.snk]
# executable = "meter_cache_fp"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.APPS.src]
# executable = "generator_cache_read_st"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.src.generator]
# host_pinning = 3
# should_pin_host = true
# cores = [ 0,]
# should_pin_workers = true
# worker_policy = "round_robin"
# host_policy = "round_robin"
# worker_priority = 98
# host_priority = 97
# use_busy_sleep = true
# busy_sleep_yield = false
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 64
#
# [ENVIRONMENTS.Haswell.src.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = false
#
# [ENVIRONMENTS.Haswell.src.schedule_reader]
# reading_from_file = true
#
# [ENVIRONMENTS.Haswell.snk.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = true
# rotating_logs = false
# rotating_logs_count = 10
# rotating_logs_size = 104857600
# timestamp_files = false
#
# [ENVIRONMENTS.Haswell.snk.meter]
# host_policy = "round_robin"
# host_pinning = 7
# should_pin_host = true
# host_priority = 95
# log_header = true
# start_immediately = false
# use_busy_sleep = true
# busy_sleep_yield = false
#
# [ENVIRONMENTS.Haswell.snk.cache]
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 64
#
# [ENVIRONMENTS.ARMv8.APPS.snk]
# executable = "meter_cache_fp"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.APPS.src]
# executable = "generator_cache_read_st"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.src.generator]
# host_pinning = 2
# should_pin_host = true
# cores = [ 0,]
# should_pin_workers = true
# worker_policy = "round_robin"
# host_policy = "round_robin"
# worker_priority = 98
# host_priority = 97
# use_busy_sleep = true
# busy_sleep_yield = false
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 16
#
# [ENVIRONMENTS.ARMv8.src.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = false
#
# [ENVIRONMENTS.ARMv8.src.schedule_reader]
# reading_from_file = true
#
# [ENVIRONMENTS.ARMv8.snk.logging]
# append_governor_to_files = false
# async = true
# async_size = 4096
# log_level = "debug"
# provide_platform_identification = true
# rotating_logs = false
# rotating_logs_count = 10
# rotating_logs_size = 104857600
# timestamp_files = false
#
# [ENVIRONMENTS.ARMv8.snk.meter]
# host_policy = "round_robin"
# host_pinning = 3
# should_pin_host = true
# host_priority = 95
# log_header = true
# start_immediately = false
# use_busy_sleep = true
# busy_sleep_yield = false
#
# [ENVIRONMENTS.ARMv8.snk.cache]
# use_huge_pages = true
# shm_file = "/dev/hugepages/8"
# set_count = 64
# set_increment = 16

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
raise Exception("Are you sure?")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-9-3b995dcc0236> in <module>
# ----> 1 raise Exception("Are you sure?")
#
# Exception: Are you sure?

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()
# Out:
# 2020-04-27 12:03:07 :: bootstrapped layer 'src' with BitsetCoding
# 2020-04-27 12:03:07 :: bootstrapped layer 'lne' with MultiN
# 2020-04-27 12:03:07 :: bootstrapped layer 'rdp' with DirectActivation
# 2020-04-27 12:03:07 :: bootstrapped layer 'io' with TimeValue
# 2020-04-27 12:03:07 :: symbol rates in phase 'trainShortARMv8' given as a str, will be evaluated
# 2020-04-27 12:03:09 :: symbol rates in phase 'evalShortARMv8' given as a str, will be evaluated
# 2020-04-27 12:03:11 :: symbol rates in phase 'trainARMv8' given as a str, will be evaluated
# 2020-04-27 12:03:14 :: symbol rates in phase 'evalARMv8' given as a str, will be evaluated
# 2020-04-27 12:03:18 :: symbol rates in phase 'trainShortHaswell' given as a str, will be evaluated
# 2020-04-27 12:03:19 :: symbol rates in phase 'evalShortHaswell' given as a str, will be evaluated
# 2020-04-27 12:03:21 :: symbol rates in phase 'trainHaswell' given as a str, will be evaluated
# 2020-04-27 12:03:32 :: symbol rates in phase 'evalHaswell' given as a str, will be evaluated
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the trainShortARMv8 phase is 0:01:28.388954
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the evalShortARMv8 phase is 0:01:29.280307
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the trainARMv8 phase is 0:02:40.602492
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the evalARMv8 phase is 0:02:41.983203
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the trainShortHaswell phase is 0:01:04.246530
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the evalShortHaswell phase is 0:01:04.811495
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the trainHaswell phase is 0:08:10.358875
# 2020-04-27 12:03:44 :: Estimated duration of a single repetition of the evalHaswell phase is 0:08:11.181297
# 2020-04-27 12:03:44 :: This results in a total estimated duration of 1:58:54.083904 for all repetitions.

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()
# Out:
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the trainShortARMv8 phase is 0:01:28.388954
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the evalShortARMv8 phase is 0:01:29.280307
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the trainARMv8 phase is 0:02:40.602492
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the evalARMv8 phase is 0:02:41.983203
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the trainShortHaswell phase is 0:01:04.246530
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the evalShortHaswell phase is 0:01:04.811495
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the trainHaswell phase is 0:08:10.358875
# 2020-04-27 12:04:31 :: Estimated duration of a single repetition of the evalHaswell phase is 0:08:11.181297
# 2020-04-27 12:04:31 :: This results in a total estimated duration of 1:58:54.083904 for all repetitions.

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = getattr(experiment, "_execution_status", {})

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    experiment.execute_in_environment(env, phases[env]['short'], resume=False)
    experiment.execute_in_environment(env, phases[env]['normal'], resume=False)
experiment.write()

# %% [markdown]
# ## Analyse

# %% [markdown]
# 1. Define which class of experiments to analyse (short of normal length)

# %%
SHORT = False

# %% [markdown]
# 2. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, diff_and_replace=False)
# Out:
# 2020-04-29 15:47:10 :: unpicked an experiment instance <PerformanceExperiment at 0x7f9c764a28d0 with FlushPrefetchCC channel, configured>
# 2020-04-29 15:47:11 :: git commit of unpickled experiment repo '2d2e43a7' does not match the commit in which the unpickling was performed 'a674d5dd'
# 2020-04-29 15:47:11 :: unpickling in a dirty git repository

# %% [markdown]
# 3. Specify the demo run and visualise

# %%
DEMO_PHASE = "trainARMv8"
DEMO_ID = 0
DEMO_ARM = "ARM" in DEMO_PHASE

# %%
ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]}
    if DEMO_ARM
    else {},
    io={
        "env": "ARMv8" if DEMO_ARM else "Haswell",
        "rep": 0,
        "matcher": [(exot.util.wrangle.Matcher("cache", NB_CHANNEL, ["access_time"], list(range(64))),None)]
    },
)

# %%
demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

# %%
with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream(dim_count=2)
    plotter.plot_rdpstream(end=5.0, dim_count=2)
    plotter.plot_slicing(dim_count=2)
    plotter.plot_eye_diagram()
    plotter.plot_symbol_space()
    plotter.plot_error()
    plotter.plot_timing()

# %% [markdown]
# 4. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "short" if SHORT else "normal"

analysis_args = {
    "ARMv8": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        rdp={"sampling_period": experiment.environment_config_general("ARMv8")["sampling_period"]},
        io={
            "matcher": [(exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            ),None)]
        },
    ),
    "Haswell": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={
            "matcher": [(exot.util.wrangle.Matcher(
                "cache", NB_CHANNEL, ["access_time"], list(range(64))
            ),None)]
        },
    ),
}

phase_mappings = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}

# %% [markdown]
# _Calculate the performance metrics_

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        **analysis_args[env],
    )
# Out:
# 2020-04-29 15:47:34 :: analysing performance for phases: trainARMv8 -> evalARMv8, environments ['ARMv8']
# 2020-04-29 15:50:44 :: analysing performance for phases: trainHaswell -> evalHaswell, environments ['Haswell']

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#         phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  trainARMv8                    ARMv8  144000.0         2250           0
# 1   evalARMv8   trainARMv8       ARMv8  144000.0         2250           0
# 2  trainARMv8                    ARMv8  144000.0         2250           1
# 3   evalARMv8   trainARMv8       ARMv8  144000.0         2250           1
# 4  trainARMv8                    ARMv8  144000.0         2250           2
#
#    bit_error  symbol_error                                            matcher  \
# 0   0.268880      1.000000  <Matcher quantity='cache', method='fp', values...
# 1   0.379351      1.000000  <Matcher quantity='cache', method='fp', values...
# 2   0.147786      0.875000  <Matcher quantity='cache', method='fp', values...
# 3   0.338608      1.000000  <Matcher quantity='cache', method='fp', values...
# 4   0.081380      0.666667  <Matcher quantity='cache', method='fp', values...
#
#    variable
# 0  cache_fp
# 1  cache_fp
# 2  cache_fp
# 3  cache_fp
# 4  cache_fp

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
#             phase  trained_with environment   bit_rate  symbol_rate  \
# 0       evalARMv8    trainARMv8       ARMv8     6400.0          100
# 1       evalARMv8    trainARMv8       ARMv8    16000.0          250
# 2       evalARMv8    trainARMv8       ARMv8    32000.0          500
# 3       evalARMv8    trainARMv8       ARMv8    48000.0          750
# 4       evalARMv8    trainARMv8       ARMv8    64000.0         1000
# 5       evalARMv8    trainARMv8       ARMv8    80000.0         1250
# 6       evalARMv8    trainARMv8       ARMv8    96000.0         1500
# 7       evalARMv8    trainARMv8       ARMv8   112000.0         1750
# 8       evalARMv8    trainARMv8       ARMv8   128000.0         2000
# 9       evalARMv8    trainARMv8       ARMv8   144000.0         2250
# 10      evalARMv8    trainARMv8       ARMv8   160000.0         2500
# 11      evalARMv8    trainARMv8       ARMv8   176000.0         2750
# 12      evalARMv8    trainARMv8       ARMv8   192000.0         3000
# 13      evalARMv8    trainARMv8       ARMv8   208000.0         3250
# 14      evalARMv8    trainARMv8       ARMv8   224000.0         3500
# 15      evalARMv8    trainARMv8       ARMv8   240000.0         3750
# 16      evalARMv8    trainARMv8       ARMv8   256000.0         4000
# 17      evalARMv8    trainARMv8       ARMv8   272000.0         4250
# 18      evalARMv8    trainARMv8       ARMv8   288000.0         4500
# 19      evalARMv8    trainARMv8       ARMv8   304000.0         4750
# 20      evalARMv8    trainARMv8       ARMv8   320000.0         5000
# 21      evalARMv8    trainARMv8       ARMv8   336000.0         5250
# 22      evalARMv8    trainARMv8       ARMv8   352000.0         5500
# 23      evalARMv8    trainARMv8       ARMv8   368000.0         5750
# 24      evalARMv8    trainARMv8       ARMv8   384000.0         6000
# 25    evalHaswell  trainHaswell     Haswell     6400.0          100
# 26    evalHaswell  trainHaswell     Haswell    64000.0         1000
# 27    evalHaswell  trainHaswell     Haswell   128000.0         2000
# 28    evalHaswell  trainHaswell     Haswell   192000.0         3000
# 29    evalHaswell  trainHaswell     Haswell   256000.0         4000
# ..            ...           ...         ...        ...          ...
# 180  trainHaswell                   Haswell  3200000.0        50000
# 181  trainHaswell                   Haswell  3264000.0        51000
# 182  trainHaswell                   Haswell  3328000.0        52000
# 183  trainHaswell                   Haswell  3392000.0        53000
# 184  trainHaswell                   Haswell  3456000.0        54000
# 185  trainHaswell                   Haswell  3520000.0        55000
# 186  trainHaswell                   Haswell  3584000.0        56000
# 187  trainHaswell                   Haswell  3648000.0        57000
# 188  trainHaswell                   Haswell  3712000.0        58000
# 189  trainHaswell                   Haswell  3776000.0        59000
# 190  trainHaswell                   Haswell  3840000.0        60000
# 191  trainHaswell                   Haswell  3904000.0        61000
# 192  trainHaswell                   Haswell  3968000.0        62000
# 193  trainHaswell                   Haswell  4032000.0        63000
# 194  trainHaswell                   Haswell  4096000.0        64000
# 195  trainHaswell                   Haswell  4160000.0        65000
# 196  trainHaswell                   Haswell  4224000.0        66000
# 197  trainHaswell                   Haswell  4288000.0        67000
# 198  trainHaswell                   Haswell  4352000.0        68000
# 199  trainHaswell                   Haswell  4416000.0        69000
# 200  trainHaswell                   Haswell  4480000.0        70000
# 201  trainHaswell                   Haswell  4544000.0        71000
# 202  trainHaswell                   Haswell  4608000.0        72000
# 203  trainHaswell                   Haswell  4672000.0        73000
# 204  trainHaswell                   Haswell  4736000.0        74000
# 205  trainHaswell                   Haswell  4800000.0        75000
# 206  trainHaswell                   Haswell  4864000.0        76000
# 207  trainHaswell                   Haswell  4928000.0        77000
# 208  trainHaswell                   Haswell  4992000.0        78000
# 209  trainHaswell                   Haswell  5000000.0        78125
#
#                                                matcher  variable  bit_error  \
# 0    <Matcher quantity='cache', method='fp', values...  cache_fp   0.008307
# 1    <Matcher quantity='cache', method='fp', values...  cache_fp   0.008267
# 2    <Matcher quantity='cache', method='fp', values...  cache_fp   0.012104
# 3    <Matcher quantity='cache', method='fp', values...  cache_fp   0.011709
# 4    <Matcher quantity='cache', method='fp', values...  cache_fp   0.024328
# 5    <Matcher quantity='cache', method='fp', values...  cache_fp   0.037542
# 6    <Matcher quantity='cache', method='fp', values...  cache_fp   0.073220
# 7    <Matcher quantity='cache', method='fp', values...  cache_fp   0.076839
# 8    <Matcher quantity='cache', method='fp', values...  cache_fp   0.086739
# 9    <Matcher quantity='cache', method='fp', values...  cache_fp   0.196875
# 10   <Matcher quantity='cache', method='fp', values...  cache_fp   0.220688
# 11   <Matcher quantity='cache', method='fp', values...  cache_fp   0.224565
# 12   <Matcher quantity='cache', method='fp', values...  cache_fp   0.220451
# 13   <Matcher quantity='cache', method='fp', values...  cache_fp   0.228956
# 14   <Matcher quantity='cache', method='fp', values...  cache_fp   0.241100
# 15   <Matcher quantity='cache', method='fp', values...  cache_fp   0.312982
# 16   <Matcher quantity='cache', method='fp', values...  cache_fp   0.307011
# 17   <Matcher quantity='cache', method='fp', values...  cache_fp   0.367628
# 18   <Matcher quantity='cache', method='fp', values...  cache_fp   0.281685
# 19   <Matcher quantity='cache', method='fp', values...  cache_fp   0.308974
# 20   <Matcher quantity='cache', method='fp', values...  cache_fp   0.357199
# 21   <Matcher quantity='cache', method='fp', values...  cache_fp   0.283814
# 22   <Matcher quantity='cache', method='fp', values...  cache_fp   0.353806
# 23   <Matcher quantity='cache', method='fp', values...  cache_fp   0.312579
# 24   <Matcher quantity='cache', method='fp', values...  cache_fp   0.381891
# 25   <Matcher quantity='cache', method='fp', values...  cache_fp   0.006131
# 26   <Matcher quantity='cache', method='fp', values...  cache_fp   0.005142
# 27   <Matcher quantity='cache', method='fp', values...  cache_fp   0.003956
# 28   <Matcher quantity='cache', method='fp', values...  cache_fp   0.010297
# 29   <Matcher quantity='cache', method='fp', values...  cache_fp   0.007125
# ..                                                 ...       ...        ...
# 180  <Matcher quantity='cache', method='fp', values...  cache_fp   0.335858
# 181  <Matcher quantity='cache', method='fp', values...  cache_fp   0.387274
# 182  <Matcher quantity='cache', method='fp', values...  cache_fp   0.319712
# 183  <Matcher quantity='cache', method='fp', values...  cache_fp   0.455293
# 184  <Matcher quantity='cache', method='fp', values...  cache_fp   0.386498
# 185  <Matcher quantity='cache', method='fp', values...  cache_fp   0.373370
# 186  <Matcher quantity='cache', method='fp', values...  cache_fp   0.314176
# 187  <Matcher quantity='cache', method='fp', values...  cache_fp   0.402027
# 188  <Matcher quantity='cache', method='fp', values...  cache_fp   0.395109
# 189  <Matcher quantity='cache', method='fp', values...  cache_fp   0.363157
# 190  <Matcher quantity='cache', method='fp', values...  cache_fp   0.454829
# 191  <Matcher quantity='cache', method='fp', values...  cache_fp   0.415767
# 192  <Matcher quantity='cache', method='fp', values...  cache_fp   0.362834
# 193  <Matcher quantity='cache', method='fp', values...  cache_fp   0.385105
# 194  <Matcher quantity='cache', method='fp', values...  cache_fp   0.383033
# 195  <Matcher quantity='cache', method='fp', values...  cache_fp   0.471813
# 196  <Matcher quantity='cache', method='fp', values...  cache_fp   0.370992
# 197  <Matcher quantity='cache', method='fp', values...  cache_fp   0.400611
# 198  <Matcher quantity='cache', method='fp', values...  cache_fp   0.422626
# 199  <Matcher quantity='cache', method='fp', values...  cache_fp   0.431669
# 200  <Matcher quantity='cache', method='fp', values...  cache_fp   0.440953
# 201  <Matcher quantity='cache', method='fp', values...  cache_fp   0.493735
# 202  <Matcher quantity='cache', method='fp', values...  cache_fp   0.444401
# 203  <Matcher quantity='cache', method='fp', values...  cache_fp   0.396552
# 204  <Matcher quantity='cache', method='fp', values...  cache_fp   0.400374
# 205  <Matcher quantity='cache', method='fp', values...  cache_fp   0.447464
# 206  <Matcher quantity='cache', method='fp', values...  cache_fp   0.465212
# 207  <Matcher quantity='cache', method='fp', values...  cache_fp   0.484188
# 208  <Matcher quantity='cache', method='fp', values...  cache_fp   0.445448
# 209  <Matcher quantity='cache', method='fp', values...  cache_fp   0.457091
#
#      symbol_error
# 0        0.531646
# 1        0.518987
# 2        0.486076
# 3        0.612658
# 4        0.607595
# 5        0.607205
# 6        0.837975
# 7        0.820870
# 8        0.846154
# 9        0.908861
# 10       0.969620
# 11       0.984810
# 12       0.997468
# 13       0.997468
# 14       1.000000
# 15       1.010256
# 16       1.012821
# 17       1.012821
# 18       0.994937
# 19       1.012821
# 20       1.000000
# 21       1.012821
# 22       1.012821
# 23       0.994937
# 24       1.012821
# 25       0.392405
# 26       0.329114
# 27       0.253165
# 28       0.335930
# 29       0.294450
# ..            ...
# 180      0.991667
# 181      1.017391
# 182      1.009058
# 183      1.017391
# 184      1.026087
# 185      1.043478
# 186      1.008696
# 187      1.026087
# 188      1.043478
# 189      1.026087
# 190      1.017391
# 191      1.026087
# 192      1.017391
# 193      1.026087
# 194      1.034783
# 195      1.035573
# 196      1.017391
# 197      1.017391
# 198      1.045963
# 199      1.034783
# 200      1.044269
# 201      1.054658
# 202      1.034783
# 203      1.008696
# 204      1.017391
# 205      1.026087
# 206      1.044269
# 207      1.034783
# 208      1.062451
# 209      1.044269
#
# [210 rows x 9 columns]

# %% [markdown]
# 5. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 6. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = ("jammer_" if NB_EXPERIMENT_TYPE == "interference" else "") + NB_CHANNEL.upper()

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        experiment.path.joinpath("ber_{}_{}.dat".format(PREFIX, env)),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 7. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
