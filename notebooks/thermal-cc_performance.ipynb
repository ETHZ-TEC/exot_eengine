# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Set the notebook parameters, the path to the key file and change working-directory to the root directory of the dataprocessing framework.

# %%
import os
base_dir = '/local/scratch/toolkit/'
os.environ['EXOT_ACCESS_DIR'] = str(base_dir + "benchmark_platforms_access/")
os.chdir(base_dir + 'datapro')
print("Working directory: " + str(os.getcwd()))
print("Key directory set to: " + str(os.environ['EXOT_ACCESS_DIR']))
# Out:
# Working directory: /local/scratch/toolkit/datapro
# Key directory set to: /local/scratch/toolkit/benchmark_platforms_access/

# %% [markdown]
# Import all necessary packages.

# %%
np.set_printoptions(linewidth=120)
plt.rcParams["figure.figsize"] = (18,10)
plt.rcParams["legend.loc"] = "lower right"

import toml    as TOML              # TOML library to handle config files
import pandas  as pd                # Pandas for data manipulation
import seaborn as sb                # Statistical data visualisation
import pathlib as PATH              # Used to convert strings to path objects for (de-)serialisation
import types   as tp                # Library used for online method development

# scikit-learn packets
import sklearn.base                 #
import sklearn.svm                  # LinearSVC, SVC
import sklearn.pipeline             # make_pipeline
import sklearn.preprocessing        # StandardScaler
import sklearn.decomposition        # PCA
import sklearn.naive_bayes          # GaussianNB
import sklearn.metrics              # CM

# Toolkit packets
import exot                       # Dataprocessing
import exot.experiment            # Experiment for execution
import exot.util                  # General utilities
import exot.layer                 # Data manipulation layers
from exot.util       import *
from exot.layer      import *
from exot.channel    import *
from exot.experiment import *

# Plotting
from exot.plotting.experiment_plotter import *
from exot.plotting.run_plotter        import *

# %% [markdown]
# Parameters

# %%
NB_EXPERIMENT_TYPES = ["performance", "interference"]

# %% [markdown]
# __Notebook config__

# %%
# Names to configure
NB_EXPERIMENT_TYPE = "performance"
NB_CONFIG = "thermal"

# Generated names
NB_EXPERIMENT = f"{NB_CONFIG}-cc_{NB_EXPERIMENT_TYPE}"
NB_CHANNEL = "f" + NB_CONFIG.split("+")[-1][0]

# %%
print("NB_EXPERIMENT_TYPE ", NB_EXPERIMENT_TYPE)
print("NB_CONFIG          ", NB_CONFIG)
print("NB_EXPERIMENT      ", NB_EXPERIMENT)
# Out:
# NB_EXPERIMENT_TYPE  performance
# NB_CONFIG           thermal
# NB_EXPERIMENT       thermal-cc_performance

# %%
assert NB_EXPERIMENT_TYPE in NB_EXPERIMENT_TYPES

# %% [markdown]
# # Generate Experiment
# 1. Load the configuration and define phases and environments

# %%
config = TOML.load(f"configurations/{NB_EXPERIMENT}.toml")
print(TOML.dumps(config))

environments_to_execute = [
    "ARMv8",
    "Haswell"
]

phases = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}
# Out:
# name = "thermal-cc_performance"
# save_path = "./data"
# backup_path = "./data/_backup"
# experiment_exists_action = "move"
#
# [EXPERIMENT]
# type = "PerformanceExperiment"
# channel = "Thermal"
#
# [EXPERIMENT.GENERAL]
# latency = 10
# fan = true
# governors = "userspace"
# frequencies = "max"
# sampling_period = 0.001
# delay_after_spawn = 30.0
# delay_after_auxiliary = 1.0
# active_wait = false
#
# [EXPERIMENT.PHASES.trainShortARMv8]
# bit_count = 150
# symbol_rates = "list(range(1, 11, 2))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortARMv8]
# bit_count = 500
# symbol_rates = "list(range(1, 11, 2))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainARMv8]
# bit_count = 1500
# symbol_rates = "list(arange(1, 20.1, 1))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalARMv8]
# bit_count = 5000
# symbol_rates = "list(arange(1, 20.1, 1))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.trainShortHaswell]
# bit_count = 500
# symbol_rates = "list(range(10, 201, 10))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.evalShortHaswell]
# bit_count = 1000
# symbol_rates = "list(range(10, 201, 10))"
# repetitions = 2
#
# [EXPERIMENT.PHASES.trainHaswell]
# bit_count = 1500
# symbol_rates = "list(range(5, 301, 1))"
# repetitions = 5
#
# [EXPERIMENT.PHASES.evalHaswell]
# bit_count = 5000
# symbol_rates = "list(range(5, 301, 1))"
# repetitions = 5
#
# [EXPERIMENT.LAYERS.src]
# name = "SourcePassthrough"
#
# [EXPERIMENT.LAYERS.lne]
# name = "ManchesterLineCoding"
#
# [EXPERIMENT.LAYERS.rdp]
# name = "CoreActivation"
#
# [EXPERIMENT.LAYERS.io]
# name = "TimeValue"
#
# [EXPERIMENT.GENERAL.ARMv8]
# fan = "255"
# delay_after_spawn = 120.0
#
# [EXPERIMENT.LAYERS.src.params]
#
# [EXPERIMENT.LAYERS.lne.params]
#
# [EXPERIMENT.LAYERS.rdp.params]
#
# [EXPERIMENT.LAYERS.io.params]
# timebase = "ns"
#
# [ENVIRONMENTS.Haswell.APPS.snk]
# executable = "meter_thermal_msr"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.APPS.src]
# executable = "generator_utilisation_mt"
# zone = "host"
#
# [ENVIRONMENTS.Haswell.src.generator]
# cpu_to_pin = 0
# cores = [ 1, 3, 5, 7,]
# policy = "round_robin"
# priority = 99
# worker_priority = 98
# start_check_period = 25
#
# [ENVIRONMENTS.Haswell.src.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.Haswell.src.schedule_reader]
# input_file = ""
# reading_from_file = true
#
# [ENVIRONMENTS.Haswell.snk.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.Haswell.snk.thermal_msr]
# cores = [ 0, 2, 4, 6,]
# package = false
#
# [ENVIRONMENTS.Haswell.snk.host]
# period = 0.001
# policy = "round_robin"
# pinning = 0
# priority = 90
# log_header = true
# start_immediately = false
# start_check_period = 25
#
# [ENVIRONMENTS.ARMv8.APPS.snk]
# executable = "meter_thermal_sysfs"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.APPS.src]
# executable = "generator_utilisation_mt"
# zone = "combined"
#
# [ENVIRONMENTS.ARMv8.src.generator]
# cpu_to_pin = 5
# cores = [ 0, 1, 2, 3, 4,]
# policy = "round_robin"
# priority = 99
# worker_priority = 98
# start_check_period = 25
#
# [ENVIRONMENTS.ARMv8.src.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.ARMv8.src.schedule_reader]
# input_file = ""
# reading_from_file = true
#
# [ENVIRONMENTS.ARMv8.snk.logging]
# debug_log_filename = ""
# app_log_filename = ""
# log_level = "info"
#
# [ENVIRONMENTS.ARMv8.snk.thermal_sysfs]
# zones = [ 0, 1, 2, 3, 4, 5, 6, 7,]
#
# [ENVIRONMENTS.ARMv8.snk.host]
# period = 0.001
# policy = "round_robin"
# pinning = 5
# priority = 90
# log_header = true
# start_immediately = false
# start_check_period = 25

# %% [markdown]
# 2. Instantiate, generate and write the experiment

# %%
raise Exception("Are you sure?")

# %%
channel = ChannelFactory()(config["EXPERIMENT"]["channel"])
experiment = ExperimentFactory()(config["EXPERIMENT"]["type"], config=config, channel=channel)

experiment.generate()
experiment.print_duration()

# If exists...
if PATH.Path(f"data/{NB_EXPERIMENT}/").exists():
    # First move...
    experiment.config.experiment_exists_action = "move"
    experiment.write()

# Then set to update mode.
experiment.config.experiment_exists_action = "update"
experiment.write()

# %% [markdown]
# ## Execute
#
# Running `execute` will execute in all environments present in the configuration.

# %% [markdown]
# Show phases' durations.

# %%
experiment.print_duration()

# %% [markdown]
# _Optionally_ peek at execution status. The execution status can be modified manually or via `_modify_execution_status`. If a modification has been made, push it to run instances with `_push_execution_status`. To rerun or resume execution, set the _resume_ argument to `True`.

# %%
execution_status = experiment._execution_status

for _platform in phases:
    for phase, runs in execution_status.items():
        for run, statuses in runs.items():
            for platform, status in statuses:
                if _platform == platform and _platform in phase:
                    print(
                        "{}Phase: {:>20s} Run: {:3d} Platform: {:>8s} Status: {}".format(
                            "✓ " if any(status) else "✗ ", phase, run, platform, status
                        )
                    )

# %% [markdown]
# Finally, execute sequentially in all environments.

# %%
raise Exception("Are you sure?")

# %%
for env in environments_to_execute:
    experiment.execute_in_environment(env, phases[env]['short'], resume=False)
    experiment.execute_in_environment(env, phases[env]['normal'], resume=False)
experiment.write()

# %% [markdown]
# ## Analyse

# %% [markdown]
# 1. Define which class of experiments to analyse (short of normal length)

# %%
SHORT = False

# %% [markdown]
# 2. Check data collection status

# %%
for _experiment in [NB_EXPERIMENT]:
    for _platform, _phase_mapping in phases.items():
        for _class, _phases in _phase_mapping.items():
            for _phase in _phases:
                _log_folders = !ls -d data/$_experiment/$_phase*/$_platform 2>/dev/null | wc -l
                _logs = !ls -d data/$_experiment/$_phase*/$_platform/**.csv 2>/dev/null | wc -l
                print("experiment:", _experiment, "platform:", _platform, "phase:", _phase,
                      "folders:", _log_folders[0].strip(), "logs:", _logs[0].strip(), sep=" ")
# Out:
# experiment: thermal-cc_performance platform: ARMv8 phase: trainShortARMv8 folders: 0 logs: 0
# experiment: thermal-cc_performance platform: ARMv8 phase: evalShortARMv8 folders: 0 logs: 0
# experiment: thermal-cc_performance platform: ARMv8 phase: trainARMv8 folders: 20 logs: 200
# experiment: thermal-cc_performance platform: ARMv8 phase: evalARMv8 folders: 20 logs: 200
# experiment: thermal-cc_performance platform: Haswell phase: trainShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_performance platform: Haswell phase: evalShortHaswell folders: 0 logs: 0
# experiment: thermal-cc_performance platform: Haswell phase: trainHaswell folders: 296 logs: 2960
# experiment: thermal-cc_performance platform: Haswell phase: evalHaswell folders: 296 logs: 2960

# %% [markdown]
# 3. Deserialisation

# %%
path_to_serialised_experiment = PATH.Path(f"data/{NB_EXPERIMENT}/_experiment.pickle")
experiment = PerformanceExperiment.read(path_to_serialised_experiment, replace=False)
# Out:
# 2019-09-10 13:00:36 :: unpicked an experiment instance <PerformanceExperiment at 0x7f5f1a659ba8 with Thermal channel, configured>
# 2019-09-10 13:00:36 :: git commit of unpickled experiment repo 'f0846ce4' does not match the commit in which the unpickling was performed '50fd78bb'

# %% [markdown]
# 4. Specify the demo run and visualise

# %%
DEMO_PHASE = "trainHaswell"
DEMO_ID = 0
DEMO_ARM = "ARM" in DEMO_PHASE

# %%
ingest_args = dict(
    lne={
        "decision_device": sklearn.pipeline.make_pipeline(
            sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
        )
    },
    io=(
        {
            "env": "ARMv8",
            "rep": 0,
            "matcher": exot.util.wrangle.Matcher("thermal", "sysfs", ["zone"], [0]),
        }
        if DEMO_ARM
        else {
            "env": "Haswell",
            "rep": 0,
            "matcher": exot.util.wrangle.Matcher("thermal", "msr", ["core"], [0, 2, 4, 6]),
            "combine": "max",
        }
    ),
)

# %%
demo_run = experiment.phases[DEMO_PHASE][DEMO_ID]
demo_run.ingest(**ingest_args)

with PerformanceRunPlotter(demo_run) as plotter:
    plotter.plot_rawstream()
    plotter.plot_rdpstream(end=10)
    plotter.plot_slicing()
    plotter.plot_symstream()
    plotter.plot_eye_diagram()
    plotter.plot_symbol_space()
    plotter.plot_error()

# %% [markdown]
# 5. Analyse the experiment
#
# _Define the analysis arguments and phase mappings_

# %%
to_evaluate = "short" if SHORT else "normal"

analysis_args = {
    "ARMv8": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={"matcher": exot.util.wrangle.Matcher("thermal", "sysfs", ["zone"], [0])},
    ),
    "Haswell": dict(
        lne={
            "decision_device": sklearn.pipeline.make_pipeline(
                sklearn.preprocessing.StandardScaler(), sklearn.svm.LinearSVC()
            )
        },
        io={
            "matcher": exot.util.wrangle.Matcher("thermal", "msr", ["core"], [0, 2, 4, 6]),
            "combine": "max",
        },
    ),
}

phase_mappings = {
    "ARMv8": {
        "short": ["trainShortARMv8", "evalShortARMv8"],
        "normal": ["trainARMv8", "evalARMv8"],
    },
    "Haswell": {
        "short": ["trainShortHaswell", "evalShortHaswell"],
        "normal": ["trainHaswell", "evalHaswell"],
    },
}

# %% [markdown]
# 6. Calculate the performance metrics

# %%
del experiment.performance_metrics

# %%
for env in phase_mappings:
    experiment.calculate_performance_metrics(
        phase_mapping=dict([tuple(phase_mappings[env][to_evaluate])]),
        envs=[env],
        reps=[],
        **analysis_args[env],
    )
# Out:
# 2019-09-10 13:02:20 :: analysing performance for phases: trainARMv8 -> evalARMv8
# 2019-09-10 13:02:21 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:03:47 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:04:29 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:04:56 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:05:21 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:05:40 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:06:00 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:06:15 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:06:31 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:06:46 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:06:59 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:07:12 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:07:27 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:07:39 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:07:50 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:08:01 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:08:12 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:08:22 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:08:32 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:08:44 :: \_ analysing performance for env: ARMv8
# 2019-09-10 13:08:54 :: analysing performance for phases: trainHaswell -> evalHaswell
# 2019-09-10 13:08:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:09:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:09:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:09:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:09:44 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:09:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:10:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:10:16 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:10:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:10:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:10:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:10:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:11:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:11:12 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:11:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:11:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:11:37 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:11:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:11:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:09 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:12:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:21 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:13:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:21 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:14:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:15:57 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:19 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:16:57 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:17:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:21 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:18:56 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:18 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:25 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:19:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:21 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:20:56 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:23 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:21:56 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:09 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:16 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:23 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:22:57 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:04 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:18 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:25 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:39 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:23:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:39 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:24:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:37 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:25:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:26:53 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:12 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:27:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:28:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:04 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:31 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:29:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:30:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:39 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:31:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:32:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:17 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:23 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:36 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:43 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:50 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:33:58 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:04 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:11 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:18 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:25 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:32 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:38 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:51 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:34:57 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:03 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:10 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:16 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:23 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:30 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:37 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:44 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:52 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:35:59 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:05 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:12 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:19 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:36:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:21 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:28 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:37:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:00 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:19 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:24 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:31 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:37 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:45 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:38:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:21 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:40 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:46 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:52 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:39:59 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:06 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:13 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:26 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:34 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:48 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:40:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:15 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:22 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:29 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:35 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:42 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:49 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:41:55 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:02 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:08 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:33 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:41 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:47 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:42:54 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:01 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:07 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:14 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:20 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:27 :: \_ analysing performance for env: Haswell
# 2019-09-10 13:43:33 :: \_ analysing performance for env: Haswell

# %% [markdown]
# _Show the performance metrics..._

# %%
experiment.performance_metrics.head()
# Out:
#         phase trained_with environment  bit_rate  symbol_rate  repetition  \
# 0  trainARMv8                    ARMv8       1.0          1.0           0
# 1   evalARMv8   trainARMv8       ARMv8       1.0          1.0           0
# 2  trainARMv8                    ARMv8       1.0          1.0           1
# 3   evalARMv8   trainARMv8       ARMv8       1.0          1.0           1
# 4  trainARMv8                    ARMv8       1.0          1.0           2
#
#    bit_error  symbol_error                                            matcher  \
# 0        0.0           0.0  <Matcher quantity='thermal', method='sysfs', v...
# 1        0.0           0.0  <Matcher quantity='thermal', method='sysfs', v...
# 2        0.0           0.0  <Matcher quantity='thermal', method='sysfs', v...
# 3        0.0           0.0  <Matcher quantity='thermal', method='sysfs', v...
# 4        0.0           0.0  <Matcher quantity='thermal', method='sysfs', v...
#
#         variable
# 0  thermal_sysfs
# 1  thermal_sysfs
# 2  thermal_sysfs
# 3  thermal_sysfs
# 4  thermal_sysfs

# %% [markdown]
# _...and the aggregated performance metrics (mean of repetitions)_

# %%
experiment.aggregate_performance_metrics()
# Out:
<Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 1    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 2    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 3    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 4    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 5    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 6    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 7    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 8    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 9    <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 10   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 11   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 12   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 13   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 14   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 15   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 16   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 17   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 18   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 19   <Matcher quantity='thermal', method='sysfs', v...  thermal_sysfs
# 20   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 21   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 22   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 23   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 24   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 25   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 26   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 27   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 28   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 29   <Matcher quantity='thermal', method='msr', val...    thermal_msr
# ..                                                 ...            ...
# 602  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 603  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 604  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 605  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 606  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 607  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 608  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 609  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 610  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 611  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 612  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 613  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 614  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 615  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 616  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 617  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 618  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 619  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 620  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 621  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 622  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 623  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 624  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 625  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 626  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 627  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 628  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 629  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 630  <Matcher quantity='thermal', method='msr', val...    thermal_msr
# 631  <Matcher quantity='thermal', method='msr', val...    thermal_msr
#
#      bit_error  symbol_error
# 0     0.000000      0.000000
# 1     0.000000      0.000000
# 2     0.000000      0.000000
# 3     0.000080      0.000080
# 4     0.001840      0.001840
# 5     0.019800      0.019800
# 6     0.048520      0.048520
# 7     0.097480      0.097480
# 8     0.157960      0.157960
# 9     0.232800      0.232800
# 10    0.294560      0.294560
# 11    0.325480      0.325480
# 12    0.336200      0.336200
# 13    0.368040      0.368040
# 14    0.381160      0.381160
# 15    0.371040      0.371040
# 16    0.393640      0.393640
# 17    0.406480      0.406480
# 18    0.409760      0.409760
# 19    0.418560      0.418560
# 20    0.000000      0.000000
# 21    0.000000      0.000000
# 22    0.000000      0.000000
# 23    0.000080      0.000080
# 24    0.000000      0.000000
# 25    0.000000      0.000000
# 26    0.000000      0.000000
# 27    0.000080      0.000080
# 28    0.000000      0.000000
# 29    0.000000      0.000000
# ..         ...           ...
# 602   0.274400      0.274400
# 603   0.266000      0.266000
# 604   0.270400      0.270400
# 605   0.265067      0.265067
# 606   0.288400      0.288400
# 607   0.261467      0.261467
# 608   0.269600      0.269600
# 609   0.272800      0.272800
# 610   0.290400      0.290400
# 611   0.262000      0.262000
# 612   0.274133      0.274133
# 613   0.289467      0.289467
# 614   0.284267      0.284267
# 615   0.266667      0.266667
# 616   0.280267      0.280267
# 617   0.288533      0.288533
# 618   0.285600      0.285600
# 619   0.268400      0.268400
# 620   0.270933      0.270933
# 621   0.277733      0.277733
# 622   0.289067      0.289067
# 623   0.286800      0.286800
# 624   0.280667      0.280667
# 625   0.288400      0.288400
# 626   0.302400      0.302400
# 627   0.300933      0.300933
# 628   0.275200      0.275200
# 629   0.297067      0.297067
# 630   0.295733      0.295733
# 631   0.303467      0.303467
#
# [632 rows x 9 columns]

# %% [markdown]
# 7. Serialise the experiment with the calculated performance metrics

# %%
experiment.write()

# %% [markdown]
# 8. Get aggregated performance metrics for each environment and phase and output as CSV

# %%
for env in phase_mappings:
    eval_phase = phase_mappings[env][to_evaluate][-1]
    BERs = wrangle.filter_data(
        experiment.aggregate_performance_metrics(), environment=env, phase=eval_phase
    )

    PREFIX = "TH" + ("_INT_" if NB_EXPERIMENT_TYPE == "interference" else "")

    pd.DataFrame({"bit_rate": BERs["bit_rate"], "bit_error": BERs["bit_error"]}).to_csv(
        "./data/BER_{}_{}_{}.dat".format(PREFIX, eval_phase, env),
        sep=",",
        encoding="utf-8",
        index=False,
    )

# %% [markdown]
# 9. Plot performance metrics

# %%
with PerformanceExperimentPlotter(experiment) as plotter:
    plotter.plot_performance_metrics()
